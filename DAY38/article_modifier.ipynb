# %%
# 使用三連詞 trigrams 練習簡易文件產生器
from __future__ import print_function, division
from future.utils import iteritems
from builtins import range
import nltk
import random
import numpy as np
nltk.download('punkt')

from bs4 import BeautifulSoup
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# load the reviews
positive_reviews = BeautifulSoup(open('./positive.review', encoding='ISO-8859-1').read(), "lxml")
positive_reviews = positive_reviews.findAll('review_text')

# %%
# 提出 三連詞 並置入字典
# (w1, w3) 當作 key, [ w2 ] 當作值
pentagrams = {}
for review in positive_reviews:
    s = review.text.lower()
    tokens = nltk.tokenize.word_tokenize(s)
    for i in range(len(tokens) - 4):
        k = (tokens[i], tokens[i+1], tokens[i+3], tokens[i+4])
        if k not in pentagrams:
            pentagrams[k] = []
        pentagrams[k].append(tokens[i+2])

# %%
pentagrams
# Out:
# {('i', 'purchased', 'unit', 'due'): ['this'],
#  ('purchased', 'this', 'due', 'to'): ['unit'],
#  ('this', 'unit', 'to', 'frequent'): ['due'],
#  ('unit', 'due', 'frequent', 'blackouts'): ['to'],
#  ('due', 'to', 'blackouts', 'in'): ['frequent'],
#  ('to', 'frequent', 'in', 'my'): ['blackouts'],
#  ('frequent', 'blackouts', 'my', 'area'): ['in'],
#  ('blackouts', 'in', 'area', 'and'): ['my'],
#  ('in', 'my', 'and', '2'): ['area'],
#  ('my', 'area', '2', 'power'): ['and'],
#  ('area', 'and', 'power', 'supplies'): ['2'],
#  ('and', '2', 'supplies', 'going'): ['power'],
#  ('2', 'power', 'going', 'bad'): ['supplies'],
#  ('power', 'supplies', 'bad', '.'): ['going'],
#  ('supplies', 'going', '.', 'it'): ['bad'],
#  ('going', 'bad', 'it', 'will'): ['.'],
#  ('bad', '.', 'will', 'run'): ['it'],
#  ('.', 'it', 'run', 'my'): ['will'],
#  ('it', 'will', 'my', 'cable'): ['run'],
#  ('will', 'run', 'cable', 'modem'): ['my'],
#  ('run', 'my', 'modem', ','): ['cable'],
#  ('my', 'cable', ',', 'router'): ['modem'],
#  ('cable', 'modem', 'router', ','): [','],
#  ('modem', ',', ',', 'pc'): ['router'],
#  (',', 'router', 'pc', ','): [','],
#  ('router', ',', ',', 'and'): ['pc'],
#  (',', 'pc', 'and', 'lcd'): [','],
#  ('pc', ',', 'lcd', 'monitor'): ['and'],
#  (',', 'and', 'monitor', 'for'): ['lcd'],
#  ('and', 'lcd', 'for', '5'): ['monitor'],
#  ('lcd', 'monitor', '5', 'minutes'): ['for'],
#  ('monitor', 'for', 'minutes', '.'): ['5'],
#  ('for', '5', '.', 'this'): ['minutes'],
#  ('5', 'minutes', 'this', 'is'): ['.'],
#  ('minutes', '.', 'is', 'more'): ['this'],
#  ('.', 'this', 'more', 'than'): ['is'],
#  ('this', 'is', 'than', 'enough'): ['more'],
#  ('is', 'more', 'enough', 'time'): ['than'],
#  ('more', 'than', 'time', 'to'): ['enough'],
#  ('than', 'enough', 'to', 'save'): ['time'],
#  ('enough', 'time', 'save', 'work'): ['to'],
#  ('time', 'to', 'work', 'and'): ['save'],
#  ('to', 'save', 'and', 'shut'): ['work'],
#  ('save', 'work', 'shut', 'down'): ['and'],
#  ('work', 'and', 'down', '.'): ['shut'],
#  ('and', 'shut', '.', 'equally'): ['down'],
#  ('shut', 'down', 'equally', 'important'): ['.'],
#  ('down', '.', 'important', ','): ['equally'],
#  ('.', 'equally', ',', 'i'): ['important'],
#  ('equally', 'important', 'i', 'know'): [','],
#  ('important', ',', 'know', 'that'): ['i'],
#  (',', 'i', 'that', 'my'): ['know'],
#  ('i', 'know', 'my', 'electronics'): ['that'],
#  ('know', 'that', 'electronics', 'are'): ['my'],
#  ('that', 'my', 'are', 'receiving'): ['electronics'],
#  ('my', 'electronics', 'receiving', 'clean'): ['are'],
#  ('electronics', 'are', 'clean', 'power'): ['receiving'],
#  ('are', 'receiving', 'power', '.'): ['clean'],
#  ('receiving', 'clean', '.', 'i'): ['power'],
#  ('clean', 'power', 'i', 'feel'): ['.'],
#  ('power', '.', 'feel', 'that'): ['i'],
#  ('.', 'i', 'that', 'this'): ['feel'],
#  ('i', 'feel', 'this', 'investment'): ['that'],
#  ('feel', 'that', 'investment', 'is'): ['this'],
#  ('that', 'this', 'is', 'minor'): ['investment'],
#  ('this', 'investment', 'minor', 'compared'): ['is'],
#  ('investment', 'is', 'compared', 'to'): ['minor'],
#  ('is', 'minor', 'to', 'the'): ['compared'],
#  ('minor', 'compared', 'the', 'loss'): ['to'],
#  ('compared', 'to', 'loss', 'of'): ['the'],
#  ('to', 'the', 'of', 'valuable'): ['loss'],
#  ('the', 'loss', 'valuable', 'data'): ['of'],
#  ('loss', 'of', 'data', 'or'): ['valuable'],
#  ('of', 'valuable', 'or', 'the'): ['data'],
#  ('valuable', 'data', 'the', 'failure'): ['or'],
#  ('data', 'or', 'failure', 'of'): ['the'],
#  ('or', 'the', 'of', 'equipment'): ['failure'],
#  ('the', 'failure', 'equipment', 'due'): ['of'],
#  ('failure', 'of', 'due', 'to'): ['equipment'],
#  ('of', 'equipment', 'to', 'a'): ['due'],
#  ('equipment', 'due', 'a', 'power'): ['to'],
#  ('due', 'to', 'power', 'spike'): ['a'],
#  ('to', 'a', 'spike', 'or'): ['power'],
#  ('a', 'power', 'or', 'an'): ['spike'],
#  ('power', 'spike', 'an', 'irregular'): ['or'],
#  ('spike', 'or', 'irregular', 'power'): ['an'],
#  ('or', 'an', 'power', 'supply'): ['irregular'],
#  ('an', 'irregular', 'supply', '.'): ['power'],
#  ('irregular', 'power', '.', 'as'): ['supply'],
#  ('power', 'supply', 'as', 'always'): ['.'],
#  ('supply', '.', 'always', ','): ['as'],
#  ('.', 'as', ',', 'amazon'): ['always'],
#  ('as', 'always', 'amazon', 'had'): [','],
#  ('always', ',', 'had', 'it'): ['amazon'],
#  (',', 'amazon', 'it', 'to'): ['had'],
#  ('amazon', 'had', 'to', 'me'): ['it'],
#  ('had', 'it', 'me', 'in'): ['to'],
#  ('it', 'to', 'in', '<'): ['me'],
#  ('to', 'me', '<', '2'): ['in'],
#  ('me', 'in', '2', 'business'): ['<'],
#  ('in', '<', 'business', 'days'): ['2'],
#  ('i', 'ordered', 'apc', 'back-ups'): ['3'],
#  ('ordered', '3', 'back-ups', 'es'): ['apc'],
#  ('3', 'apc', 'es', '500s'): ['back-ups'],
#  ('apc', 'back-ups', '500s', 'on'): ['es'],
#  ('back-ups', 'es', 'on', 'the'): ['500s'],
#  ('es', '500s', 'the', 'recommendation'): ['on'],
#  ('500s', 'on', 'recommendation', 'of'): ['the'],
#  ('on', 'the', 'of', 'an'): ['recommendation'],
#  ('the', 'recommendation', 'an', 'employee'): ['of'],
#  ('recommendation', 'of', 'employee', 'of'): ['an'],
#  ('of', 'an', 'of', 'mine'): ['employee'],
#  ('an', 'employee', 'mine', 'who'): ['of'],
#  ('employee', 'of', 'who', 'used'): ['mine'],
#  ('of', 'mine', 'used', 'to'): ['who'],
#  ('mine', 'who', 'to', 'work'): ['used'],
#  ('who', 'used', 'work', 'at'): ['to'],
#  ('used', 'to', 'at', 'apc'): ['work'],
#  ('to', 'work', 'apc', '.'): ['at'],
#  ('work', 'at', '.', 'i'): ['apc'],
#  ('at', 'apc', 'i', "'ve"): ['.'],
#  ('apc', '.', "'ve", 'had'): ['i'],
#  ('.', 'i', 'had', 'them'): ["'ve"],
#  ('i', "'ve", 'them', 'for'): ['had', 'used'],
#  ("'ve", 'had', 'for', 'about'): ['them', 'it', 'it'],
#  ('had', 'them', 'about', 'a'): ['for'],
#  ('them', 'for', 'a', 'month'): ['about'],
#  ('for', 'about', 'month', 'now'): ['a', 'a', 'a'],
#  ('about', 'a', 'now', 'without'): ['month'],
#  ('a', 'month', 'without', 'any'): ['now'],
#  ('month', 'now', 'any', 'problems'): ['without'],
#  ('now', 'without', 'problems', '.'): ['any'],
#  ('without', 'any', '.', 'they'): ['problems'],
#  ('any', 'problems', 'they', "'ve"): ['.'],
#  ('problems', '.', "'ve", 'functioned'): ['they'],
#  ('.', 'they', 'functioned', 'properly'): ["'ve"],
#  ('they', "'ve", 'properly', 'through'): ['functioned'],
#  ("'ve", 'functioned', 'through', 'a'): ['properly'],
#  ('functioned', 'properly', 'a', 'few'): ['through'],
#  ('properly', 'through', 'few', 'unexpected'): ['a'],
#  ('through', 'a', 'unexpected', 'power'): ['few'],
#  ('a', 'few', 'power', 'interruptions'): ['unexpected'],
#  ('few', 'unexpected', 'interruptions', '.'): ['power'],
#  ('unexpected', 'power', '.', 'i'): ['interruptions'],
#  ('power', 'interruptions', 'i', "'ll"): ['.'],
#  ('interruptions', '.', "'ll", 'gladly'): ['i'],
#  ('.', 'i', 'gladly', 'order'): ["'ll"],
#  ('i', "'ll", 'order', 'more'): ['gladly'],
#  ("'ll", 'gladly', 'more', 'if'): ['order'],
#  ('gladly', 'order', 'if', 'the'): ['more'],
#  ('order', 'more', 'the', 'need'): ['if'],
#  ('more', 'if', 'need', 'arises'): ['the'],
#  ('if', 'the', 'arises', '.'): ['need'],
#  ('the', 'need', '.', 'pros'): ['arises'],
#  ('need', 'arises', 'pros', ':'): ['.'],
#  ('arises', '.', ':', '-'): ['pros'],
#  ('.', 'pros', '-', 'large'): [':'],
#  ('pros', ':', 'large', 'plug'): ['-'],
#  (':', '-', 'plug', 'spacing'): ['large'],
#  ('-', 'large', 'spacing', ','): ['plug'],
#  ('large', 'plug', ',', 'good'): ['spacing'],
#  ('plug', 'spacing', 'good', 'for'): [','],
#  ('spacing', ',', 'for', 'power'): ['good'],
#  (',', 'good', 'power', 'adapters'): ['for'],
#  ('good', 'for', 'adapters', '-'): ['power'],
#  ('for', 'power', '-', 'simple'): ['adapters'],
#  ('power', 'adapters', 'simple', 'design'): ['-'],
#  ('adapters', '-', 'design', '-'): ['simple'],
#  ('-', 'simple', '-', 'long'): ['design'],
#  ('simple', 'design', 'long', 'cord'): ['-'],
#  ('design', '-', 'cord', 'cons'): ['long'],
#  ('-', 'long', 'cons', ':'): ['cord'],
#  ('long', 'cord', ':', '-'): ['cons'],
#  ('cord', 'cons', '-', 'no'): [':'],
#  ('cons', ':', 'no', 'line'): ['-'],
#  (':', '-', 'line', 'conditioning'): ['no'],
#  ('-', 'no', 'conditioning', '('): ['line'],
#  ('no', 'line', '(', 'usually'): ['conditioning'],
#  ('line', 'conditioning', 'usually', 'an'): ['('],
#  ('conditioning', '(', 'an', 'expensive'): ['usually'],
#  ('(', 'usually', 'expensive', 'option'): ['an'],
#  ('wish', 'the', 'had', 'a'): ['unit'],
#  ('the', 'unit', 'a', 'separate'): ['had'],
#  ('unit', 'had', 'separate', 'online/offline'): ['a'],
#  ('had', 'a', 'online/offline', 'light'): ['separate'],
#  ('a', 'separate', 'light', '.'): ['online/offline'],
#  ('separate', 'online/offline', '.', 'when'): ['light'],
#  ('online/offline', 'light', 'when', 'power'): ['.'],
#  ('light', '.', 'power', 'to'): ['when'],
#  ('.', 'when', 'to', 'the'): ['power'],
#  ('when', 'power', 'the', 'unit'): ['to'],
#  ('power', 'to', 'unit', 'is'): ['the'],
#  ('to', 'the', 'is', 'missing'): ['unit'],
#  ('the', 'unit', 'missing', ','): ['is'],
#  ('unit', 'is', ',', 'the'): ['missing'],
#  ('is', 'missing', 'the', 'single'): [','],
#  ('missing', ',', 'single', 'red'): ['the'],
#  (',', 'the', 'red', 'light'): ['single'],
#  ('the', 'single', 'light', 'turns'): ['red'],
#  ('single', 'red', 'turns', 'off'): ['light'],
#  ('red', 'light', 'off', 'only'): ['turns'],
#  ('light', 'turns', 'only', 'when'): ['off'],
#  ('turns', 'off', 'when', 'the'): ['only'],
#  ('off', 'only', 'the', 'warning'): ['when'],
#  ('only', 'when', 'warning', 'sounds'): ['the'],
#  ('when', 'the', 'sounds', '.'): ['warning'],
#  ('the', 'warning', '.', 'the'): ['sounds'],
#  ('warning', 'sounds', 'the', 'warning'): ['.'],
#  ('sounds', '.', 'warning', 'sound'): ['the'],
#  ('.', 'the', 'sound', 'is'): ['warning'],
#  ('the', 'warning', 'is', 'like'): ['sound'],
#  ('warning', 'sound', 'like', 'a'): ['is'],
#  ('sound', 'is', 'a', 'lot'): ['like'],
#  ('is', 'like', 'lot', 'of'): ['a'],
#  ('like', 'a', 'of', 'sounds'): ['lot'],
#  ('a', 'lot', 'sounds', 'you'): ['of'],
#  ('lot', 'of', 'you', 'hear'): ['sounds'],
#  ('of', 'sounds', 'hear', 'in'): ['you'],
#  ('sounds', 'you', 'in', 'the'): ['hear'],
#  ('you', 'hear', 'the', 'house'): ['in'],
#  ('hear', 'in', 'house', 'so'): ['the'],
#  ('in', 'the', 'so', 'it'): ['house'],
#  ('the', 'house', 'it', 'is'): ['so'],
#  ('house', 'so', 'is', "n't"): ['it'],
#  ('so', 'it', "n't", 'always'): ['is'],
#  ('it', 'is', 'always', 'easy'): ["n't"],
#  ('is', "n't", 'easy', 'to'): ['always', 'that'],
#  ("n't", 'always', 'to', 'tell'): ['easy'],
#  ('always', 'easy', 'tell', 'what'): ['to'],
#  ('easy', 'to', 'what', 'is'): ['tell'],
#  ('to', 'tell', 'is', 'happening'): ['what'],
#  ('cheaper', 'than', 'cd', 'cases'): ['thick'],
#  ('than', 'thick', 'cases', 'and'): ['cd'],
#  ('thick', 'cd', 'and', 'less'): ['cases'],
#  ('cd', 'cases', 'less', 'prone'): ['and'],
#  ('cases', 'and', 'prone', 'to'): ['less'],
#  ('and', 'less', 'to', 'breakage'): ['prone'],
#  ('less', 'prone', 'breakage', ','): ['to'],
#  ('prone', 'to', ',', 'these'): ['breakage'],
#  ('to', 'breakage', 'these', '``'): [','],
#  ('breakage', ',', '``', 'slim'): ['these'],
#  (',', 'these', 'slim', "''"): ['``'],
#  ('these', '``', "''", 'cases'): ['slim'],
#  ('``', 'slim', 'cases', 'by'): ["''"],
#  ('slim', "''", 'by', 'memorex'): ['cases'],
#  ("''", 'cases', 'memorex', 'protect'): ['by'],
#  ('cases', 'by', 'protect', 'your'): ['memorex'],
#  ('by', 'memorex', 'your', 'cds'): ['protect'],
#  ('memorex', 'protect', 'cds', '.'): ['your'],
#  ('protect', 'your', '.', 'most'): ['cds'],
#  ('your', 'cds', 'most', 'buyers'): ['.'],
#  ('cds', '.', 'buyers', 'will'): ['most'],
#  ('.', 'most', 'will', 'get'): ['buyers'],
#  ('most', 'buyers', 'get', 'them'): ['will'],
#  ('buyers', 'will', 'them', 'for'): ['get'],
#  ('will', 'get', 'for', 'use'): ['them'],
#  ('get', 'them', 'use', 'in'): ['for'],
#  ('them', 'for', 'in', 'cd'): ['use'],
#  ('for', 'use', 'cd', 'or'): ['in'],
#  ('use', 'in', 'or', 'dvd'): ['cd'],
#  ('in', 'cd', 'dvd', 'burning'): ['or'],
#  ('cd', 'or', 'burning', ','): ['dvd'],
#  ('or', 'dvd', ',', 'and'): ['burning'],
#  ('dvd', 'burning', 'and', 'these'): [','],
#  ('burning', ',', 'these', 'are'): ['and'],
#  (',', 'and', 'are', 'an'): ['these'],
#  ('and', 'these', 'an', 'affordable'): ['are'],
#  ('these', 'are', 'affordable', 'choice'): ['an'],
#  ('are', 'an', 'choice', 'from'): ['affordable'],
#  ('an', 'affordable', 'from', 'a'): ['choice'],
#  ('affordable', 'choice', 'a', 'quality'): ['from'],
#  ('choice', 'from', 'quality', 'company'): ['a'],
#  ('from', 'a', 'company', 'for'): ['quality'],
#  ('a', 'quality', 'for', 'that'): ['company'],
#  ('quality', 'company', 'that', 'purpose'): ['for'],
#  ('company', 'for', 'purpose', '.'): ['that'],
#  ('for', 'that', '.', 'you'): ['purpose'],
#  ('that', 'purpose', 'you', 'may'): ['.'],
#  ('purpose', '.', 'may', 'want'): ['you'],
#  ('.', 'you', 'want', 'to'): ['may', 'may'],
#  ('you', 'may', 'to', 'consider'): ['want'],
#  ('may', 'want', 'consider', 'larger'): ['to'],
#  ('want', 'to', 'larger', 'cases'): ['consider'],
#  ('to', 'consider', 'cases', 'depending'): ['larger'],
#  ('consider', 'larger', 'depending', 'on'): ['cases'],
#  ('larger', 'cases', 'on', 'your'): ['depending'],
#  ('cases', 'depending', 'your', 'tastes'): ['on'],
#  ('depending', 'on', 'tastes', ','): ['your'],
#  ('on', 'your', ',', 'but'): ['tastes'],
#  ('your', 'tastes', 'but', 'otherwise'): [','],
#  ('tastes', ',', 'otherwise', 'these'): ['but'],
#  (',', 'but', 'these', 'will'): ['otherwise'],
#  ('but', 'otherwise', 'will', 'probably'): ['these'],
#  ('otherwise', 'these', 'probably', 'satisfy'): ['will'],
#  ('these', 'will', 'satisfy', 'your'): ['probably'],
#  ('will', 'probably', 'your', 'needs'): ['satisfy'],
#  ('hi', 'i', '256', 'mb'): ['brought'],
#  ('i', 'brought', 'mb', 'kingston'): ['256'],
#  ('brought', '256', 'kingston', 'sd'): ['mb'],
#  ('256', 'mb', 'sd', 'card'): ['kingston', 'kingston'],
#  ('mb', 'kingston', 'card', 'from'): ['sd'],
#  ('kingston', 'sd', 'from', 'amazon.com'): ['card'],
#  ('sd', 'card', 'amazon.com', 'recently'): ['from'],
#  ('card', 'from', 'recently', '.'): ['amazon.com'],
#  ('from', 'amazon.com', '.', 'according'): ['recently'],
#  ('amazon.com', 'recently', 'according', 'to'): ['.'],
#  ('recently', '.', 'to', 'my'): ['according'],
#  ('.', 'according', 'my', 'openion'): ['to'],
#  ('according', 'to', 'openion', 'amazon'): ['my'],
#  ('to', 'my', 'amazon', 'is'): ['openion'],
#  ('my', 'openion', 'is', 'one'): ['amazon'],
#  ('openion', 'amazon', 'one', 'of'): ['is'],
#  ('amazon', 'is', 'of', 'the'): ['one'],
#  ('is', 'one', 'the', 'best'): ['of', 'of', 'of'],
#  ('one', 'of', 'best', 'online'): ['the'],
#  ('of', 'the', 'online', 'shopping'): ['best'],
#  ('the', 'best', 'shopping', 'market'): ['online'],
#  ('best', 'online', 'market', ','): ['shopping'],
#  ('online', 'shopping', ',', 'they'): ['market'],
#  ('shopping', 'market', 'they', 'deliver'): [','],
#  ('market', ',', 'deliver', 'the'): ['they'],
#  (',', 'they', 'the', 'products'): ['deliver'],
#  ('they', 'deliver', 'products', 'intime'): ['the'],
#  ('deliver', 'the', 'intime', 'and'): ['products'],
#  ('the', 'products', 'and', 'the'): ['intime'],
#  ('products', 'intime', 'the', 'items'): ['and'],
#  ('intime', 'and', 'items', 'i'): ['the'],
#  ('and', 'the', 'i', 'brought'): ['items'],
#  ('the', 'items', 'brought', 'so'): ['i'],
#  ('items', 'i', 'so', 'far'): ['brought'],
#  ('i', 'brought', 'far', 'are'): ['so'],
#  ('brought', 'so', 'are', 'working'): ['far'],
#  ('so', 'far', 'working', 'very'): ['are'],
#  ('far', 'are', 'very', 'well'): ['working'],
#  ('are', 'working', 'well', '.'): ['very'],
#  ('working', 'very', '.', '256'): ['well'],
#  ('very', 'well', '256', 'mb'): ['.'],
#  ('well', '.', 'mb', 'kingston'): ['256'],
#  ('.', '256', 'kingston', 'sd'): ['mb'],
#  ('mb', 'kingston', 'card', 'working'): ['sd'],
#  ('kingston', 'sd', 'working', 'very'): ['card'],
#  ('sd', 'card', 'very', 'good'): ['working'],
#  ('card', 'working', 'good', 'with'): ['very'],
#  ('working', 'very', 'with', 'out'): ['good'],
#  ('very', 'good', 'out', 'giving'): ['with'],
#  ('good', 'with', 'giving', 'any'): ['out'],
#  ('with', 'out', 'any', 'problem'): ['giving'],
#  ('out', 'giving', 'problem', '.'): ['any'],
#  ('giving', 'any', '.', 'one'): ['problem'],
#  ('any', 'problem', 'one', 'can'): ['.'],
#  ('problem', '.', 'can', 'always'): ['one'],
#  ('.', 'one', 'always', 'go'): ['can'],
#  ('one', 'can', 'go', 'to'): ['always'],
#  ('can', 'always', 'to', 'amazon'): ['go'],
#  ('always', 'go', 'amazon', 'for'): ['to'],
#  ('go', 'to', 'for', 'online'): ['amazon'],
#  ('to', 'amazon', 'online', 'shopping'): ['for'],
#  ('amazon', 'for', 'shopping', '.'): ['online'],
#  ('for', 'online', '.', 'bye'): ['shopping'],
#  ('online', 'shopping', 'bye', 'kira'): ['.'],
#  ('this', 'product', 'perfect', '.'): ['was'],
#  ('product', 'was', '.', 'it'): ['perfect'],
#  ('was', 'perfect', 'it', "'s"): ['.'],
#  ('perfect', '.', "'s", 'a'): ['it'],
#  ('.', 'it', 'a', 'sturdy'): ["'s"],
#  ('it', "'s", 'sturdy', 'case'): ['a'],
#  ("'s", 'a', 'case', 'that'): ['sturdy', 'rubber', 'great'],
#  ('a', 'sturdy', 'that', 'holds'): ['case'],
#  ('sturdy', 'case', 'holds', 'my'): ['that'],
#  ('case', 'that', 'my', 'large'): ['holds'],
#  ('that', 'holds', 'large', 'collection'): ['my'],
#  ('holds', 'my', 'collection', 'of'): ['large'],
#  ('my', 'large', 'of', 'cd'): ['collection'],
#  ('large', 'collection', 'cd', "'s"): ['of'],
#  ('collection', 'of', "'s", 'and'): ['cd'],
#  ('of', 'cd', 'and', 'dvd'): ["'s"],
#  ('cd', "'s", 'dvd', "'s"): ['and'],
#  ("'s", 'and', "'s", '.'): ['dvd'],
#  ('and', 'dvd', '.', 'my'): ["'s"],
#  ('dvd', "'s", 'my', 'other'): ['.'],
#  ("'s", '.', 'other', 'cases'): ['my'],
#  ('.', 'my', 'cases', 'were'): ['other'],
#  ('my', 'other', 'were', 'flimsy'): ['cases'],
#  ('other', 'cases', 'flimsy', 'and'): ['were'],
#  ('cases', 'were', 'and', 'wore'): ['flimsy'],
#  ('were', 'flimsy', 'wore', 'out'): ['and'],
#  ('flimsy', 'and', 'out', 'fast'): ['wore'],
#  ('and', 'wore', 'fast', '.'): ['out'],
#  ('wore', 'out', '.', 'this'): ['fast'],
#  ('out', 'fast', 'this', 'one'): ['.'],
#  ('fast', '.', 'one', 'has'): ['this'],
#  ('.', 'this', 'has', 'a'): ['one', 'tv'],
#  ('this', 'one', 'a', 'hard'): ['has'],
#  ('one', 'has', 'hard', 'outside'): ['a'],
#  ('has', 'a', 'outside', 'shell'): ['hard'],
#  ('a', 'hard', 'shell', 'and'): ['outside'],
#  ('hard', 'outside', 'and', 'the'): ['shell'],
#  ('outside', 'shell', 'the', 'inside'): ['and'],
#  ('shell', 'and', 'inside', 'holds'): ['the'],
#  ('and', 'the', 'holds', 'my'): ['inside'],
#  ('the', 'inside', 'my', 'dvd'): ['holds'],
#  ('inside', 'holds', 'dvd', "'s"): ['my'],
#  ('holds', 'my', "'s", 'nicely'): ['dvd'],
#  ('my', 'dvd', 'nicely', '.'): ["'s"],
#  ('dvd', "'s", '.', 'so'): ['nicely'],
#  ("'s", 'nicely', 'so', 'i'): ['.'],
#  ('nicely', '.', 'i', 'have'): ['so'],
#  ('.', 'so', 'have', 'no'): ['i'],
#  ('so', 'i', 'no', 'complaints'): ['have'],
#  ('i', 'have', 'complaints', '.'): ['no'],
#  ('have', 'no', '.', 'and'): ['complaints'],
#  ('no', 'complaints', 'and', 'at'): ['.'],
#  ('complaints', '.', 'at', 'the'): ['and'],
#  ('.', 'and', 'the', 'price'): ['at', '...'],
#  ('and', 'at', 'price', 'i'): ['the'],
#  ('at', 'the', 'i', 'paid'): ['price', 'price'],
#  ('the', 'price', 'paid', 'i'): ['i'],
#  ('price', 'i', 'i', "'d"): ['paid'],
#  ('i', 'paid', "'d", 'say'): ['i'],
#  ('paid', 'i', 'say', 'this'): ["'d"],
#  ('i', "'d", 'this', 'was'): ['say'],
#  ("'d", 'say', 'was', 'a'): ['this'],
#  ('say', 'this', 'a', 'great'): ['was'],
#  ('this', 'was', 'great', 'deal'): ['a'],
#  ('great', 'value', 'your', 'money'): ['for', 'for'],
#  ('value', 'for', 'money', '.'): ['your', 'your', 'the'],
#  ('for', 'your', '.', 'kingston'): ['money', 'money'],
#  ('your', 'money', 'kingston', 'has'): ['.', '.'],
#  ('money', '.', 'has', 'always'): ['kingston', 'kingston'],
#  ('.', 'kingston', 'always', 'been'): ['has', 'has'],
#  ('kingston', 'has', 'been', 'a'): ['always', 'always'],
#  ('has', 'always', 'a', 'reliable'): ['been', 'been'],
#  ('always', 'been', 'reliable', 'memory'): ['a', 'a'],
#  ('been', 'a', 'memory', 'chip'): ['reliable', 'reliable'],
#  ('a', 'reliable', 'chip', 'company'): ['memory', 'memory'],
#  ('reliable', 'memory', 'company', 'and'): ['chip', 'chip'],
#  ('memory', 'chip', 'and', 'the'): ['company', 'company'],
#  ('chip', 'company', 'the', 'same'): ['and', 'and'],
#  ('company', 'and', 'same', 'goes'): ['the', 'the'],
#  ('and', 'the', 'goes', 'for'): ['same', 'same'],
#  ('the', 'same', 'for', 'this'): ['goes', 'goes'],
#  ('same', 'goes', 'this', 'product'): ['for', 'for'],
#  ('goes', 'for', 'product', '.'): ['this', 'this'],
#  ('i', 'like', 'very', 'much'): ['it', 'it', 'them'],
#  ('like', 'it', 'much', ','): ['very', 'very', 'so'],
#  ('it', 'very', ',', 'i'): ['much', 'much'],
#  ('very', 'much', 'i', 'use'): [',', ','],
#  ('much', ',', 'use', 'it'): ['i', 'i'],
#  (',', 'i', 'it', 'in'): ['use', 'use', 'put'],
#  ('i', 'use', 'in', 'an'): ['it', 'it'],
#  ('use', 'it', 'an', 'outdoor'): ['in', 'in'],
#  ('it', 'in', 'outdoor', 'trail'): ['an', 'an'],
#  ('in', 'an', 'trail', 'camera'): ['outdoor', 'outdoor'],
#  ('an', 'outdoor', 'camera', 'for'): ['trail', 'trail'],
#  ('outdoor', 'trail', 'for', 'wild'): ['camera', 'camera'],
#  ('trail', 'camera', 'wild', 'game'): ['for', 'for'],
#  ('camera', 'for', 'game', 'and'): ['wild', 'wild'],
#  ('for', 'wild', 'and', 'it'): ['game', 'game'],
#  ('wild', 'game', 'it', 'hold'): ['and', 'and'],
#  ('game', 'and', 'hold', 'several'): ['it', 'it'],
#  ('and', 'it', 'several', 'pictures'): ['hold', 'hold'],
#  ('it', 'hold', 'pictures', 'and'): ['several', 'several'],
#  ('hold', 'several', 'and', 'has'): ['pictures', 'pictures'],
#  ('several', 'pictures', 'has', 'been'): ['and', 'and'],
#  ('pictures', 'and', 'been', 'in'): ['has', 'has'],
#  ('and', 'has', 'in', 'the'): ['been', 'been'],
#  ('has', 'been', 'the', 'camera'): ['in', 'in'],
#  ('been', 'in', 'camera', 'in'): ['the', 'the'],
#  ('in', 'the', 'in', 'all'): ['camera', 'camera'],
#  ('the', 'camera', 'all', 'kinds'): ['in', 'in'],
#  ('camera', 'in', 'kinds', 'of'): ['all', 'all'],
#  ('in', 'all', 'of', 'weather'): ['kinds', 'kinds'],
#  ('all', 'kinds', 'weather', '.'): ['of', 'of'],
#  ('kinds', 'of', '.', 'i'): ['weather', 'weather'],
#  ('of', 'weather', 'i', 'would'): ['.', '.'],
#  ('weather', '.', 'would', 'buy'): ['i', 'i'],
#  ('.', 'i', 'buy', 'kingston'): ['would', 'would'],
#  ('i', 'would', 'kingston', 'again'): ['buy', 'buy'],
#  ('i', 'had', 'problems', 'with'): ['no'],
#  ('had', 'no', 'with', 'this'): ['problems', 'problems'],
#  ('no', 'problems', 'this', 'card'): ['with'],
#  ('problems', 'with', 'card', 'and'): ['this'],
#  ('with', 'this', 'and', 'the'): ['card', 'brand'],
#  ('this', 'card', 'the', 'delivery'): ['and'],
#  ('card', 'and', 'delivery', 'was'): ['the'],
#  ('and', 'the', 'was', 'prompt'): ['delivery'],
#  ('the', 'delivery', 'prompt', '...'): ['was'],
#  ('delivery', 'was', '...', 'thank'): ['prompt'],
#  ('was', 'prompt', 'thank', 'you'): ['...'],
#  ('prompt', '...', 'you', 'muc'): ['thank'],
#  ('after', 'going', 'the', 'reviews'): ['through'],
#  ('going', 'through', 'reviews', ','): ['the'],
#  ('through', 'the', ',', 'i'): ['reviews', 'stereo', 'computer'],
#  ('the', 'reviews', 'i', 'bought'): [',', ','],
#  ('reviews', ',', 'bought', 'this'): ['i'],
#  (',', 'i', 'this', 'cf'): ['bought'],
#  ('i', 'bought', 'cf', 'card'): ['this'],
#  ('bought', 'this', 'card', 'for'): ['cf'],
#  ('this', 'cf', 'for', 'my'): ['card'],
#  ('cf', 'card', 'my', 'canon'): ['for'],
#  ('card', 'for', 'canon', 'digital'): ['my'],
#  ('for', 'my', 'digital', 'rebel'): ['canon'],
#  ('my', 'canon', 'rebel', '.'): ['digital'],
#  ('canon', 'digital', '.', 'so'): ['rebel'],
#  ('digital', 'rebel', 'so', 'far'): ['.'],
#  ('rebel', '.', 'far', 'it'): ['so'],
#  ('.', 'so', 'it', 'has'): ['far', 'far'],
#  ('so', 'far', 'has', 'worked'): ['it'],
#  ('far', 'it', 'worked', 'fine'): ['has'],
#  ('it', 'has', 'fine', ','): ['worked'],
#  ('has', 'worked', ',', 'though'): ['fine'],
#  ('worked', 'fine', 'though', 'i'): [','],
#  ('fine', ',', 'i', 'do'): ['though'],
#  (',', 'though', 'do', "n't"): ['i'],
#  ('though', 'i', "n't", 'pretend'): ['do'],
#  ('i', 'do', 'pretend', 'to'): ["n't"],
#  ('do', "n't", 'to', 'be'): ['pretend', 'want', 'want'],
#  ("n't", 'pretend', 'be', 'an'): ['to'],
#  ('pretend', 'to', 'an', 'expert'): ['be'],
#  ('to', 'be', 'expert', 'digital'): ['an'],
#  ('be', 'an', 'digital', 'photographer'): ['expert'],
#  ('an', 'expert', 'photographer', '.'): ['digital'],
#  ('expert', 'digital', '.', 'when'): ['photographer'],
#  ('digital', 'photographer', 'when', 'the'): ['.'],
#  ('photographer', '.', 'the', 'card'): ['when'],
#  ('.', 'when', 'card', 'is'): ['the'],
#  ('when', 'the', 'is', 'empty'): ['card'],
#  ('the', 'card', 'empty', ','): ['is'],
#  ('card', 'is', ',', 'it'): ['empty'],
#  ('is', 'empty', 'it', 'shows'): [','],
#  ('empty', ',', 'shows', '127'): ['it'],
#  (',', 'it', '127', 'shots'): ['shows'],
#  ('it', 'shows', 'shots', 'available'): ['127'],
#  ('shows', '127', 'available', '.'): ['shots'],
#  ('127', 'shots', '.', 'it'): ['available'],
#  ('shots', 'available', 'it', 'seems'): ['.'],
#  ('available', '.', 'seems', 'to'): ['it'],
#  ('.', 'it', 'to', 'read'): ['seems'],
#  ('it', 'seems', 'read', 'reasonably'): ['to'],
#  ('seems', 'to', 'reasonably', 'fast'): ['read'],
#  ('to', 'read', 'fast', ','): ['reasonably'],
#  ('read', 'reasonably', ',', 'though'): ['fast'],
#  ('reasonably', 'fast', 'though', 'it'): [','],
#  ('fast', ',', 'it', 'takes'): ['though'],
#  (',', 'though', 'takes', 'a'): ['it'],
#  ('though', 'it', 'a', 'bit'): ['takes', 'is'],
#  ('it', 'takes', 'bit', 'longer'): ['a'],
#  ('takes', 'a', 'longer', 'than'): ['bit'],
#  ('a', 'bit', 'than', 'i'): ['longer'],
#  ('bit', 'longer', 'i', 'was'): ['than'],
#  ('longer', 'than', 'was', 'used'): ['i'],
#  ('than', 'i', 'used', 'to'): ['was', 'am'],
#  ('i', 'was', 'to', 'with'): ['used'],
#  ('was', 'used', 'with', 'my'): ['to'],
#  ('used', 'to', 'my', 'point-and-shoot'): ['with'],
#  ('to', 'with', 'point-and-shoot', 'olympus'): ['my'],
#  ('with', 'my', 'olympus', 'and'): ['point-and-shoot'],
#  ('my', 'point-and-shoot', 'and', 'its'): ['olympus'],
#  ('point-and-shoot', 'olympus', 'its', 'smartmedia'): ['and'],
#  ('olympus', 'and', 'smartmedia', 'card'): ['its'],
#  ('and', 'its', 'card', '.'): ['smartmedia'],
#  ('i', 'am', 'happy', 'with'): ['very',
#   'verry',
#   'very',
#   'extremely',
#   'very',
#   'very',
#   'very',
#   'very',
#   'very',
#   'very',
#   'completely',
#   'very',
#   'very'],
#  ('am', 'very', 'with', 'this'): ['happy', 'happy'],
#  ('very', 'happy', 'this', 'product'): ['with', 'with'],
#  ('happy', 'with', 'product', '.'): ['this', 'this'],
#  ('with', 'this', '.', 'it'): ['product', 'product', 'unit', 'printer'],
#  ('this', 'product', 'it', 'folds'): ['.'],
#  ('product', '.', 'folds', 'super'): ['it'],
#  ('.', 'it', 'super', 'slim'): ['folds'],
#  ('it', 'folds', 'slim', ','): ['super'],
#  ('folds', 'super', ',', 'so'): ['slim'],
#  ('super', 'slim', 'so', 'traveling'): [','],
#  ('slim', ',', 'traveling', 'with'): ['so'],
#  (',', 'so', 'with', 'it'): ['traveling'],
#  ('so', 'traveling', 'it', 'is'): ['with'],
#  ('traveling', 'with', 'is', 'a'): ['it'],
#  ('with', 'it', 'a', 'breeze'): ['is'],
#  ('it', 'is', 'breeze', '!'): ['a'],
#  ('is', 'a', '!', 'pretty'): ['breeze'],
#  ('a', 'breeze', 'pretty', 'good'): ['!'],
#  ('breeze', '!', 'good', 'sound'): ['pretty'],
#  ('!', 'pretty', 'sound', '-'): ['good'],
#  ('pretty', 'good', '-', 'not'): ['sound'],
#  ('good', 'sound', 'not', 'bose'): ['-'],
#  ('sound', '-', 'bose', 'quality'): ['not'],
#  ('-', 'not', 'quality', ','): ['bose'],
#  ('not', 'bose', ',', 'but'): ['quality'],
#  ('bose', 'quality', 'but', 'for'): [','],
#  ('quality', ',', 'for', 'the'): ['but'],
#  (',', 'but', 'the', 'price'): ['for'],
#  ('but', 'for', 'price', ','): ['the'],
#  ('for', 'the', ',', 'very'): ['price'],
#  ('the', 'price', 'very', 'respectable'): [','],
#  ('price', ',', 'respectable', '!'): ['very'],
#  (',', 'very', '!', 'i'): ['respectable'],
#  ('very', 'respectable', 'i', "'ve"): ['!'],
#  ('respectable', '!', "'ve", 'had'): ['i'],
#  ('!', 'i', 'had', 'it'): ["'ve", "'ve"],
#  ('i', "'ve", 'it', 'almost'): ['had'],
#  ("'ve", 'had', 'almost', 'a'): ['it'],
#  ('had', 'it', 'a', 'year'): ['almost'],
#  ('it', 'almost', 'year', ','): ['a'],
#  ('almost', 'a', ',', 'and'): ['year'],
#  ('a', 'year', 'and', 'it'): [','],
#  ('year', ',', 'it', 'has'): ['and'],
#  (',', 'and', 'has', 'been'): ['it'],
#  ('and', 'it', 'been', 'along'): ['has'],
#  ('it', 'has', 'along', 'on'): ['been'],
#  ('has', 'been', 'on', 'many'): ['along'],
#  ('been', 'along', 'many', 'weekend'): ['on'],
#  ('along', 'on', 'weekend', 'get-aways'): ['many'],
#  ('on', 'many', 'get-aways', ','): ['weekend'],
#  ('many', 'weekend', ',', 'and'): ['get-aways'],
#  ('weekend', 'get-aways', 'and', 'works'): [','],
#  ('get-aways', ',', 'works', 'great'): ['and'],
#  (',', 'and', 'great', '.'): ['works'],
#  ('and', 'works', '.', 'i'): ['great'],
#  ('works', 'great', 'i', 'use'): ['.'],
#  ('great', '.', 'use', 'it'): ['i'],
#  ('.', 'i', 'it', 'alot'): ['use'],
#  ('i', 'use', 'alot', ','): ['it'],
#  ('use', 'it', ',', 'so'): ['alot'],
#  ('it', 'alot', 'so', 'it'): [','],
#  ('alot', ',', 'it', 'was'): ['so'],
#  (',', 'so', 'was', 'a'): ['it', 'i', 'that'],
#  ('so', 'it', 'a', 'good'): ['was'],
#  ('it', 'was', 'good', 'purchase'): ['a', 'a'],
#  ('was', 'a', 'purchase', 'for'): ['good'],
#  ('a', 'good', 'for', 'me'): ['purchase', 'while'],
#  ('i', 'bought', 'reader', 'because'): ['this'],
#  ('bought', 'this', 'because', 'i'): ['reader'],
#  ('this', 'reader', 'i', 'wanted'): ['because'],
#  ('reader', 'because', 'wanted', 'to'): ['i'],
#  ('because', 'i', 'to', 'avoid'): ['wanted'],
#  ('i', 'wanted', 'avoid', 'having'): ['to'],
#  ('wanted', 'to', 'having', 'my'): ['avoid'],
#  ('to', 'avoid', 'my', 'camera'): ['having'],
#  ('avoid', 'having', 'camera', 'and'): ['my'],
#  ('having', 'my', 'and', 'all'): ['camera'],
#  ('my', 'camera', 'all', 'its'): ['and'],
#  ('camera', 'and', 'its', 'cable'): ['all'],
#  ('and', 'all', 'cable', 'attached'): ['its'],
#  ('all', 'its', 'attached', 'to'): ['cable'],
#  ('its', 'cable', 'to', 'my'): ['attached'],
#  ('cable', 'attached', 'my', 'pc'): ['to'],
#  ('attached', 'to', 'pc', 'to'): ['my'],
#  ('to', 'my', 'to', 'download'): ['pc'],
#  ('my', 'pc', 'download', 'the'): ['to'],
#  ('pc', 'to', 'the', 'pictures'): ['download'],
#  ('to', 'download', 'pictures', ';'): ['the'],
#  ('download', 'the', ';', 'and'): ['pictures'],
#  ('the', 'pictures', 'and', 'with'): [';'],
#  ('pictures', ';', 'with', 'this'): ['and'],
#  (';', 'and', 'this', 'reader'): ['with'],
#  ('and', 'with', 'reader', 'i'): ['this'],
#  ('with', 'this', 'i', 'could'): ['reader'],
#  ('this', 'reader', 'could', 'leave'): ['i'],
#  ('reader', 'i', 'leave', 'my'): ['could'],
#  ('i', 'could', 'my', 'camera'): ['leave'],
#  ('could', 'leave', 'camera', '('): ['my'],
#  ('leave', 'my', '(', 'and'): ['camera'],
#  ('my', 'camera', 'and', 'its'): ['('],
#  ('camera', '(', 'its', 'cables'): ['and'],
#  ('(', 'and', 'cables', ')'): ['its'],
#  ('and', 'its', ')', 'in'): ['cables'],
#  ('its', 'cables', 'in', 'its'): [')'],
#  ('cables', ')', 'its', 'case'): ['in'],
#  (')', 'in', 'case', 'and'): ['its'],
#  ('in', 'its', 'and', 'just'): ['case'],
#  ('its', 'case', 'just', 'download'): ['and'],
#  ('case', 'and', 'download', 'the'): ['just'],
#  ('and', 'just', 'the', 'picture'): ['download'],
#  ('just', 'download', 'picture', 'with'): ['the'],
#  ('download', 'the', 'with', 'the'): ['picture'],
#  ('the', 'picture', 'the', 'memory'): ['with'],
#  ('picture', 'with', 'memory', 'card'): ['the'],
#  ('with', 'the', 'card', ','): ['memory'],
#  ('the', 'memory', ',', 'i'): ['card'],
#  ('memory', 'card', 'i', 'recomend'): [','],
#  ('card', ',', 'recomend', 'this'): ['i'],
#  (',', 'i', 'this', 'product'): ['recomend', 'recommend', 'bet'],
#  ('i', 'recomend', 'product', '...'): ['this'],
#  ('recomend', 'this', '...', '.'): ['product'],
#  ('it', "'s", 'simple', 'device'): ['a', 'a'],
#  ("'s", 'a', 'device', ','): ['simple', 'simple'],
#  ('a', 'simple', ',', 'so'): ['device', 'device'],
#  ('simple', 'device', 'so', 'there'): [',', ','],
#  ('device', ',', 'there', "'s"): ['so', 'so'],
#  (',', 'so', "'s", 'not'): ['there', 'there', 'it'],
#  ('so', 'there', 'not', 'to'): ["'s", "'s"],
#  ('there', "'s", 'to', 'say'): ['not', 'not'],
#  ("'s", 'not', 'say', 'about'): ['to', 'to'],
#  ('not', 'to', 'about', 'it'): ['say', 'say'],
#  ('to', 'say', 'it', 'other'): ['about', 'about'],
#  ('say', 'about', 'other', 'than'): ['it', 'it'],
#  ('about', 'it', 'than', 'it'): ['other', 'other'],
#  ('it', 'other', 'it', 'does'): ['than', 'than'],
#  ('other', 'than', 'does', 'the'): ['it', 'it'],
#  ('than', 'it', 'the', 'job'): ['does', 'does'],
#  ('it', 'does', 'job', '.'): ['the', 'the', 'the', 'the'],
#  ('does', 'the', '.', 'you'): ['job', 'job'],
#  ('the', 'job', 'you', 'should'): ['.', '.'],
#  ('job', '.', 'should', 'note'): ['you', 'you'],
#  ('.', 'you', 'note', 'that'): ['should', 'should'],
#  ('you', 'should', 'that', 'the'): ['note', 'note'],
#  ('should', 'note', 'the', 'leds'): ['that', 'that'],
#  ('note', 'that', 'leds', 'on'): ['the', 'the'],
#  ('that', 'the', 'on', 'the'): ['leds', 'leds', 'buckles'],
#  ('the', 'leds', 'the', 'device'): ['on', 'on'],
#  ('leds', 'on', 'device', 'remain'): ['the', 'the'],
#  ('on', 'the', 'remain', 'lit'): ['device', 'device'],
#  ('the', 'device', 'lit', 'as'): ['remain', 'remain'],
#  ('device', 'remain', 'as', 'long'): ['lit', 'lit'],
#  ('remain', 'lit', 'long', 'as'): ['as', 'as'],
#  ('lit', 'as', 'as', 'the'): ['long', 'long'],
#  ('as', 'long', 'the', 'device'): ['as', 'as'],
#  ('long', 'as', 'device', 'is'): ['the', 'the'],
#  ('as', 'the', 'is', 'plugged'): ['device', 'device'],
#  ('the', 'device', 'plugged', 'into'): ['is', 'is'],
#  ('device', 'is', 'into', 'your'): ['plugged', 'plugged'],
#  ('is', 'plugged', 'your', 'pc'): ['into', 'into'],
#  ('plugged', 'into', 'pc', 'and'): ['your', 'your'],
#  ('into', 'your', 'and', 'the'): ['pc', 'pc'],
#  ('your', 'pc', 'the', 'pc'): ['and', 'and'],
#  ('pc', 'and', 'pc', 'is'): ['the', 'the'],
#  ('and', 'the', 'is', 'powered'): ['pc', 'pc'],
#  ('the', 'pc', 'powered', '('): ['is', 'is'],
#  ('pc', 'is', '(', 'they'): ['powered', 'powered'],
#  ('is', 'powered', 'they', 'glow'): ['(', '('],
#  ('powered', '(', 'glow', 'a'): ['they', 'they'],
#  ('(', 'they', 'a', 'bright'): ['glow', 'glow'],
#  ('they', 'glow', 'bright', 'blue'): ['a', 'a'],
#  ('glow', 'a', 'blue', ')'): ['bright', 'bright'],
#  ('a', 'bright', ')', '.'): ['blue', 'blue'],
#  ('i', 'was', 'about', 'buying'): ['thinking', 'apprehensive'],
#  ('was', 'thinking', 'buying', 'a'): ['about'],
#  ('thinking', 'about', 'a', '1g'): ['buying'],
#  ('about', 'buying', '1g', 'card'): ['a'],
#  ('buying', 'a', 'card', ','): ['1g'],
#  ('a', '1g', ',', 'but'): ['card'],
#  ('1g', 'card', 'but', 'after'): [','],
#  ('card', ',', 'after', 'reading'): ['but'],
#  (',', 'but', 'reading', 'one'): ['after'],
#  ('but', 'after', 'one', 'of'): ['reading'],
#  ('after', 'reading', 'of', 'the'): ['one', 'some'],
#  ('reading', 'one', 'the', 'reviews'): ['of'],
#  ('one', 'of', 'reviews', ','): ['the'],
#  ('of', 'the', ',', 'i'): ['reviews', 'flaws', '155s'],
#  ('reviews', ',', 'bought', 'two'): ['i'],
#  (',', 'i', 'two', '512'): ['bought'],
#  ('i', 'bought', '512', 'card'): ['two'],
#  ('bought', 'two', 'card', ','): ['512'],
#  ('two', '512', ',', 'just'): ['card'],
#  ('512', 'card', 'just', 'in'): [','],
#  ('card', ',', 'in', 'case'): ['just'],
#  (',', 'just', 'case', 'that'): ['in'],
#  ('just', 'in', 'that', 'something'): ['case'],
#  ('in', 'case', 'something', 'went'): ['that'],
#  ('case', 'that', 'went', 'wrong'): ['something'],
#  ('that', 'something', 'wrong', '.'): ['went'],
#  ('something', 'went', '.', 'which'): ['wrong'],
#  ('went', 'wrong', 'which', 'to'): ['.'],
#  ('wrong', '.', 'to', 'me'): ['which'],
#  ('.', 'which', 'me', 'made'): ['to'],
#  ('which', 'to', 'made', 'a'): ['me'],
#  ('to', 'me', 'a', 'lot'): ['made'],
#  ('me', 'made', 'lot', 'of'): ['a'],
#  ('made', 'a', 'of', 'sense'): ['lot'],
#  ('a', 'lot', 'sense', '.'): ['of'],
#  ('lot', 'of', '.', 'i'): ['sense', 'money', 'dirt'],
#  ('of', 'sense', 'i', "'m"): ['.'],
#  ('sense', '.', "'m", 'please'): ['i'],
#  ('i', 'have', 'been', 'very'): ['always'],
#  ('have', 'always', 'very', 'pleased'): ['been'],
#  ('always', 'been', 'pleased', 'with'): ['very'],
#  ('been', 'very', 'with', 'the'): ['pleased', 'impressed', 'impressed'],
#  ('very', 'pleased', 'the', 'sandisk'): ['with'],
#  ('pleased', 'with', 'sandisk', 'products'): ['the'],
#  ('with', 'the', 'products', '.'): ['sandisk'],
#  ('the', 'sandisk', '.', 'i'): ['products'],
#  ('sandisk', 'products', 'i', 'would'): ['.'],
#  ('products', '.', 'would', 'highly'): ['i'],
#  ('.', 'i', 'highly', 'recommend'): ['would',
#   'would',
#   'would',
#   "'d",
#   'would',
#   'can',
#   'would'],
#  ('i', 'would', 'recommend', 'them'): ['highly'],
#  ('these', 'earphones', 'great', 'quality'): ['are'],
#  ('earphones', 'are', 'quality', '.'): ['great', 'excellent'],
#  ('are', 'great', '.', 'the'): ['quality'],
#  ('great', 'quality', 'the', 'sound'): ['.'],
#  ('quality', '.', 'sound', 'is'): ['the'],
#  ('.', 'the', 'is', 'good'): ['sound', 'light'],
#  ('the', 'sound', 'good', 'and'): ['is', 'is'],
#  ('sound', 'is', 'and', 'they'): ['good'],
#  ('is', 'good', 'they', 'fit'): ['and'],
#  ('good', 'and', 'fit', 'comfortably'): ['they'],
#  ('and', 'they', 'comfortably', 'in'): ['fit'],
#  ('they', 'fit', 'in', 'the'): ['comfortably'],
#  ('fit', 'comfortably', 'the', 'ear'): ['in'],
#  ('comfortably', 'in', 'ear', 'once'): ['the'],
#  ('in', 'the', 'once', 'you'): ['ear'],
#  ('the', 'ear', 'you', 'get'): ['once'],
#  ('ear', 'once', 'get', 'used'): ['you'],
#  ('once', 'you', 'used', 'to'): ['get'],
#  ('you', 'get', 'to', 'them'): ['used'],
#  ('get', 'used', 'them', '.'): ['to'],
#  ('used', 'to', '.', 'two'): ['them'],
#  ('to', 'them', 'two', 'minuses'): ['.'],
#  ('them', '.', 'minuses', 'make'): ['two'],
#  ('.', 'two', 'make', 'them'): ['minuses'],
#  ('two', 'minuses', 'them', 'only'): ['make'],
#  ('minuses', 'make', 'only', '4'): ['them'],
#  ('make', 'them', '4', 'out'): ['only'],
#  ('them', 'only', 'out', 'of'): ['4'],
#  ('only', '4', 'of', '5'): ['out'],
#  ('4', 'out', '5', 'stars'): ['of'],
#  ('out', 'of', 'stars', ':'): ['5'],
#  ('of', '5', ':', 'first'): ['stars'],
#  ('5', 'stars', 'first', ','): [':'],
#  ('stars', ':', ',', 'the'): ['first'],
#  (':', 'first', 'the', 'customer'): [','],
#  ('first', ',', 'customer', 'support'): ['the'],
#  (',', 'the', 'support', 'is'): ['customer'],
#  ('the', 'customer', 'is', 'weak'): ['support'],
#  ('customer', 'support', 'weak', '.'): ['is'],
#  ('support', 'is', '.', 'there'): ['weak'],
#  ('is', 'weak', 'there', 'is'): ['.'],
#  ('weak', '.', 'is', 'supposed'): ['there'],
#  ('.', 'there', 'supposed', 'to'): ['is'],
#  ('there', 'is', 'to', 'be'): ['supposed'],
#  ('is', 'supposed', 'be', 'a'): ['to'],
#  ('supposed', 'to', 'a', 'website'): ['be'],
#  ('to', 'be', 'website', 'for'): ['a'],
#  ('be', 'a', 'for', 'the'): ['website'],
#  ('a', 'website', 'the', 'product'): ['for'],
#  ('website', 'for', 'product', 'for'): ['the'],
#  ('for', 'the', 'for', 'customer'): ['product'],
#  ('the', 'product', 'customer', 'support'): ['for'],
#  ('product', 'for', 'support', 'and'): ['customer'],
#  ('for', 'customer', 'and', 'replacement'): ['support'],
#  ('customer', 'support', 'replacement', 'parts'): ['and'],
#  ('support', 'and', 'parts', ','): ['replacement'],
#  ('and', 'replacement', ',', 'but'): ['parts'],
#  ('replacement', 'parts', 'but', 'altec'): [','],
#  ('parts', ',', 'altec', 'lansing'): ['but'],
#  (',', 'but', 'lansing', 'his'): ['altec'],
#  ('but', 'altec', 'his', 'it'): ['lansing'],
#  ('altec', 'lansing', 'it', 'linked'): ['his'],
#  ('lansing', 'his', 'linked', 'to'): ['it'],
#  ('his', 'it', 'to', 'a'): ['linked'],
#  ('it', 'linked', 'a', 'seemingly'): ['to'],
#  ('linked', 'to', 'seemingly', 'unrelated'): ['a'],
#  ('to', 'a', 'unrelated', 'product'): ['seemingly'],
#  ('a', 'seemingly', 'product', ';'): ['unrelated'],
#  ('seemingly', 'unrelated', ';', 'second'): ['product'],
#  ('unrelated', 'product', 'second', ','): [';'],
#  ('product', ';', ',', 'the'): ['second'],
#  (';', 'second', 'the', 'volume'): [','],
#  ('second', ',', 'volume', 'control'): ['the'],
#  (',', 'the', 'control', 'is'): ['volume'],
#  ('the', 'volume', 'is', 'a'): ['control'],
#  ('volume', 'control', 'a', 'little'): ['is'],
#  ('control', 'is', 'little', 'heavy'): ['a'],
#  ('is', 'a', 'heavy', 'unless'): ['little'],
#  ('a', 'little', 'unless', 'you'): ['heavy'],
#  ('little', 'heavy', 'you', 'have'): ['unless'],
#  ('heavy', 'unless', 'have', 'somewhere'): ['you'],
#  ('unless', 'you', 'somewhere', 'to'): ['have'],
#  ('you', 'have', 'to', 'clip'): ['somewhere'],
#  ('have', 'somewhere', 'clip', 'it'): ['to'],
#  ('somewhere', 'to', 'it', 'to'): ['clip'],
#  ('to', 'clip', 'to', '('): ['it'],
#  ('clip', 'it', '(', 'this'): ['to'],
#  ('it', 'to', 'this', 'might'): ['('],
#  ('to', '(', 'might', 'be'): ['this'],
#  ('(', 'this', 'be', 'a'): ['might'],
#  ('this', 'might', 'a', 'problem'): ['be'],
#  ('might', 'be', 'problem', 'for'): ['a'],
#  ('be', 'a', 'for', 'runners'): ['problem'],
#  ('a', 'problem', 'runners', ')'): ['for'],
#  ('this', 'cf', 'is', 'so'): ['card'],
#  ('cf', 'card', 'so', 'fast'): ['is'],
#  ('card', 'is', 'fast', 'that'): ['so'],
#  ('is', 'so', 'that', 'i'): ['fast', 'low'],
#  ('so', 'fast', 'i', 'can'): ['that'],
#  ('fast', 'that', 'can', 'run'): ['i'],
#  ('that', 'i', 'run', 'my'): ['can'],
#  ('i', 'can', 'my', 'shutter'): ['run'],
#  ('can', 'run', 'shutter', 'on'): ['my'],
#  ('run', 'my', 'on', 'my'): ['shutter'],
#  ('my', 'shutter', 'my', 'camera'): ['on'],
#  ('shutter', 'on', 'camera', 'non'): ['my'],
#  ('on', 'my', 'non', 'stop'): ['camera'],
#  ('my', 'camera', 'stop', 'until'): ['non'],
#  ('camera', 'non', 'until', 'the'): ['stop'],
#  ('non', 'stop', 'the', 'card'): ['until'],
#  ('stop', 'until', 'card', 'is'): ['the'],
#  ('until', 'the', 'is', 'full'): ['card'],
#  ('the', 'card', 'full', 'at'): ['is'],
#  ('card', 'is', 'at', 'a'): ['full'],
#  ('is', 'full', 'a', 'frame'): ['at'],
#  ('full', 'at', 'frame', 'rate'): ['a'],
#  ('at', 'a', 'rate', 'of'): ['frame'],
#  ('a', 'frame', 'of', '3.5'): ['rate'],
#  ('frame', 'rate', '3.5', 'fps'): ['of'],
#  ('rate', 'of', 'fps', '.'): ['3.5'],
#  ('of', '3.5', '.', 'no'): ['fps'],
#  ('3.5', 'fps', 'no', 'lag'): ['.'],
#  ('fps', '.', 'lag', 'or'): ['no'],
#  ('.', 'no', 'or', 'slow'): ['lag'],
#  ('no', 'lag', 'slow', 'down'): ['or'],
#  ('lag', 'or', 'down', '.'): ['slow'],
#  ('or', 'slow', '.', 'that'): ['down'],
#  ('slow', 'down', 'that', 'is'): ['.'],
#  ('down', '.', 'is', 'amazing'): ['that'],
#  ('.', 'that', 'amazing', '.'): ['is'],
#  ('that', 'is', '.', 'it'): ['amazing'],
#  ('is', 'amazing', 'it', 'makes'): ['.'],
#  ('amazing', '.', 'makes', 'my'): ['it'],
#  ('.', 'it', 'my', 'camera'): ['makes'],
#  ('it', 'makes', 'camera', 'perform'): ['my'],
#  ('makes', 'my', 'perform', 'better'): ['camera'],
#  ('my', 'camera', 'better', '.'): ['perform'],
#  ('camera', 'perform', '.', '('): ['better'],
#  ('perform', 'better', '(', 'canon'): ['.'],
#  ('better', '.', 'canon', 'rebel'): ['('],
#  ('.', '(', 'rebel', 'xt'): ['canon'],
#  ('fast', 'and', 'worth', 'the'): ['reliable..well'],
#  ('and', 'reliable..well', 'the', 'mone'): ['worth'],
#  ('perhaps', 'the', 'addition', 'to'): ['ultimate'],
#  ('the', 'ultimate', 'to', 'a'): ['addition'],
#  ('ultimate', 'addition', 'a', 'good'): ['to'],
#  ('addition', 'to', 'good', 'camera'): ['a'],
#  ('to', 'a', 'camera', '.'): ['good'],
#  ('a', 'good', '.', 'i'): ['camera', 'interface', 'price'],
#  ('good', 'camera', 'i', 'used'): ['.'],
#  ('camera', '.', 'used', 'my'): ['i'],
#  ('.', 'i', 'my', 'camera'): ['used'],
#  ('i', 'used', 'camera', 'with'): ['my'],
#  ('used', 'my', 'with', 'a'): ['camera'],
#  ('my', 'camera', 'a', 'sandisk'): ['with'],
#  ('camera', 'with', 'sandisk', 'pro'): ['a'],
#  ('with', 'a', 'pro', 'duo'): ['sandisk'],
#  ('a', 'sandisk', 'duo', '('): ['pro'],
#  ('sandisk', 'pro', '(', 'the'): ['duo'],
#  ('pro', 'duo', 'the', 'blue'): ['('],
#  ('duo', '(', 'blue', 'one'): ['the'],
#  ('(', 'the', 'one', '...'): ['blue'],
#  ('the', 'blue', '...', ')'): ['one'],
#  ('blue', 'one', ')', 'and'): ['...'],
#  ('one', '...', 'and', 'while'): [')'],
#  ('...', ')', 'while', 'most'): ['and'],
#  (')', 'and', 'most', 'times'): ['while'],
#  ('and', 'while', 'times', 'it'): ['most'],
#  ('while', 'most', 'it', 'was'): ['times'],
#  ('most', 'times', 'was', 'fine'): ['it'],
#  ('times', 'it', 'fine', ','): ['was'],
#  ('it', 'was', ',', 'when'): ['fine'],
#  ('was', 'fine', 'when', 'i'): [','],
#  ('fine', ',', 'i', 'needed'): ['when'],
#  (',', 'when', 'needed', 'to'): ['i'],
#  ('when', 'i', 'to', 'take'): ['needed'],
#  ('i', 'needed', 'take', 'pictures'): ['to'],
#  ('needed', 'to', 'pictures', 'in'): ['take'],
#  ('to', 'take', 'in', 'quick'): ['pictures'],
#  ('take', 'pictures', 'quick', 'succession'): ['in'],
#  ('pictures', 'in', 'succession', '-'): ['quick'],
#  ('in', 'quick', '-', 'it'): ['succession'],
#  ('quick', 'succession', 'it', 'let'): ['-'],
#  ('succession', '-', 'let', 'me'): ['it'],
#  ('-', 'it', 'me', 'down'): ['let'],
#  ('it', 'let', 'down', '.'): ['me'],
#  ('let', 'me', '.', 'the'): ['down'],
#  ('me', 'down', 'the', 'ultra'): ['.'],
#  ('down', '.', 'ultra', 'ii'): ['the'],
#  ('.', 'the', 'ii', 'is'): ['ultra'],
#  ('the', 'ultra', 'is', 'noticably'): ['ii'],
#  ('ultra', 'ii', 'noticably', 'faster'): ['is'],
#  ('ii', 'is', 'faster', '.'): ['noticably'],
#  ('is', 'noticably', '.', 'you'): ['faster'],
#  ('noticably', 'faster', 'you', 'will'): ['.'],
#  ('faster', '.', 'will', 'not'): ['you'],
#  ('.', 'you', 'not', 'regret'): ['will'],
#  ('you', 'will', 'regret', 'buying'): ['not'],
#  ('will', 'not', 'buying', 'this'): ['regret'],
#  ('the', 'sandisk', 'mb', 'secure'): ['512'],
#  ('sandisk', '512', 'secure', 'digitial'): ['mb'],
#  ('512', 'mb', 'digitial', 'ultra'): ['secure'],
#  ('mb', 'secure', 'ultra', 'ii'): ['digitial'],
#  ('secure', 'digitial', 'ii', '('): ['ultra'],
#  ('digitial', 'ultra', '(', 'sdsdh-512-901'): ['ii'],
#  ('ultra', 'ii', 'sdsdh-512-901', ')'): ['('],
#  ('ii', '(', ')', 'sent'): ['sdsdh-512-901'],
#  ('(', 'sdsdh-512-901', 'sent', 'to'): [')'],
#  ('sdsdh-512-901', ')', 'to', 'me'): ['sent'],
#  (')', 'sent', 'me', 'was'): ['to'],
#  ('sent', 'to', 'was', 'not'): ['me'],
#  ('to', 'me', 'not', 'the'): ['was'],
#  ('me', 'was', 'the', 'item'): ['not'],
#  ('was', 'not', 'item', 'i'): ['the'],
#  ('not', 'the', 'i', 'ordered'): ['item'],
#  ('the', 'item', 'ordered', '.'): ['i'],
#  ...}

# %%
# 將中間字矩陣變成或然率向量
pentagram_probabilities = {}
for k, words in iteritems(pentagrams):
  # generate word -> count dict
  if len(set(words)) > 1:
    # if the middle word not has only one probability
    d = {}
    n = 0
    for w in words:
      if w not in d:
        d[w] = 0
      d[w] += 1
      n += 1
    for w, c in iteritems(d):
      d[w] = float(c) / n
    pentagram_probabilities[k] = d

# %%
pentagram_probabilities
# Out:
# {('i', "'ve", 'them', 'for'): {'had': 0.5, 'used': 0.5},
#  ("'ve", 'had', 'for', 'about'): {'it': 0.6666666666666666,
#   'them': 0.3333333333333333},
#  ('is', "n't", 'easy', 'to'): {'always': 0.5, 'that': 0.5},
#  ("'s", 'a', 'case', 'that'): {'great': 0.3333333333333333,
#   'rubber': 0.3333333333333333,
#   'sturdy': 0.3333333333333333},
#  ('.', 'this', 'has', 'a'): {'one': 0.5, 'tv': 0.5},
#  ('.', 'and', 'the', 'price'): {'...': 0.5, 'at': 0.5},
#  ('value', 'for', 'money', '.'): {'the': 0.3333333333333333,
#   'your': 0.6666666666666666},
#  ('i', 'like', 'very', 'much'): {'it': 0.6666666666666666,
#   'them': 0.3333333333333333},
#  ('like', 'it', 'much', ','): {'so': 0.3333333333333333,
#   'very': 0.6666666666666666},
#  (',', 'i', 'it', 'in'): {'put': 0.3333333333333333,
#   'use': 0.6666666666666666},
#  ('with', 'this', 'and', 'the'): {'brand': 0.5, 'card': 0.5},
#  ('through', 'the', ',', 'i'): {'computer': 0.3333333333333333,
#   'reviews': 0.3333333333333333,
#   'stereo': 0.3333333333333333},
#  ('do', "n't", 'to', 'be'): {'pretend': 0.3333333333333333,
#   'want': 0.6666666666666666},
#  ('though', 'it', 'a', 'bit'): {'is': 0.5, 'takes': 0.5},
#  ('than', 'i', 'used', 'to'): {'am': 0.5, 'was': 0.5},
#  ('i', 'am', 'happy', 'with'): {'completely': 0.07692307692307693,
#   'extremely': 0.07692307692307693,
#   'verry': 0.07692307692307693,
#   'very': 0.7692307692307693},
#  ('with', 'this', '.', 'it'): {'printer': 0.25, 'product': 0.5, 'unit': 0.25},
#  (',', 'so', 'was', 'a'): {'i': 0.3333333333333333,
#   'it': 0.3333333333333333,
#   'that': 0.3333333333333333},
#  ('a', 'good', 'for', 'me'): {'purchase': 0.5, 'while': 0.5},
#  (',', 'i', 'this', 'product'): {'bet': 0.3333333333333333,
#   'recomend': 0.3333333333333333,
#   'recommend': 0.3333333333333333},
#  (',', 'so', "'s", 'not'): {'it': 0.3333333333333333,
#   'there': 0.6666666666666666},
#  ('that', 'the', 'on', 'the'): {'buckles': 0.3333333333333333,
#   'leds': 0.6666666666666666},
#  ('i', 'was', 'about', 'buying'): {'apprehensive': 0.5, 'thinking': 0.5},
#  ('after', 'reading', 'of', 'the'): {'one': 0.5, 'some': 0.5},
#  ('of', 'the', ',', 'i'): {'155s': 0.3333333333333333,
#   'flaws': 0.3333333333333333,
#   'reviews': 0.3333333333333333},
#  ('lot', 'of', '.', 'i'): {'dirt': 0.3333333333333333,
#   'money': 0.3333333333333333,
#   'sense': 0.3333333333333333},
#  ('been', 'very', 'with', 'the'): {'impressed': 0.6666666666666666,
#   'pleased': 0.3333333333333333},
#  ('.', 'i', 'highly', 'recommend'): {"'d": 0.14285714285714285,
#   'can': 0.14285714285714285,
#   'would': 0.7142857142857143},
#  ('earphones', 'are', 'quality', '.'): {'excellent': 0.5, 'great': 0.5},
#  ('.', 'the', 'is', 'good'): {'light': 0.5, 'sound': 0.5},
#  ('is', 'so', 'that', 'i'): {'fast': 0.5, 'low': 0.5},
#  ('a', 'good', '.', 'i'): {'camera': 0.3333333333333333,
#   'interface': 0.3333333333333333,
#   'price': 0.3333333333333333},
#  (',', 'and', 'of', 'them'): {'all': 0.5, 'both': 0.5},
#  ('if', 'you', 'to', 'take'): {'love': 0.5, 'want': 0.5},
#  ('it', 'is', 'to', 'use'): {'easier': 0.14285714285714285,
#   'easy': 0.5714285714285714,
#   'great': 0.2857142857142857},
#  ('.', 'the', 'is', 'really'): {'lid': 0.25,
#   'paper': 0.25,
#   'price': 0.25,
#   'screen': 0.25},
#  ('to', 'use', '.', 'i'): {')': 0.3333333333333333, 'it': 0.6666666666666666},
#  ('.', 'i', 'wish', 'i'): {'only': 0.5, 'really': 0.5},
#  ('!', '!', 'is', 'a'): {'it': 0.5, 'this': 0.5},
#  ('is', 'a', 'smaller', 'than'): {'bit': 0.5, 'lot': 0.5},
#  ('is', 'very', 'and', 'works'): {'comfortable': 0.5, 'responsive': 0.5},
#  ('.', 'the', 'is', 'pretty'): {'bass': 0.5, 'mouse': 0.5},
#  ('product', 'a', 'weeks', 'ago'): {'couple': 0.5, 'few': 0.5},
#  ('for', 'me', 'as', 'i'): {',': 0.5, '.': 0.5},
#  ("'m", 'a', 'junkie', '.'): {'gps': 0.5, 'keyboard': 0.5},
#  ('thing', 'is', '.', 'i'): {'cool': 0.5, 'great': 0.5},
#  ('i', 'do', 'use', 'it'): {"n't": 0.75, 'not': 0.25},
#  ('do', "n't", 'it', 'as'): {'see': 0.5, 'use': 0.5},
#  (',', 'but', 'do', "n't"): {'i': 0.42857142857142855,
#   'they': 0.2857142857142857,
#   'we': 0.14285714285714285,
#   'you': 0.14285714285714285},
#  ('over', 'a', 'now', 'and'): {'month': 0.5, 'year': 0.5},
#  ('with', 'no', '.', 'the'): {'hassles': 0.5,
#   'problem': 0.25,
#   'problems': 0.25},
#  ('i', 'have', 'a', 'few'): {'burnt': 0.5, 'had': 0.5},
#  ('it', "'s", 'a', 'great'): {'always': 0.5, 'such': 0.5},
#  ('one', 'at', ',', 'and'): {'home': 0.5, 'sears': 0.5},
#  ('the', 'only', 'with', 'the'): {'issue': 0.5, 'problem': 0.5},
#  ('with', 'the', 'is', 'the'): {'iskin': 0.5, 'keyboard': 0.5},
#  ('i', "'m", 'happy', 'with'): {'quite': 0.1, 'really': 0.1, 'very': 0.8},
#  ("'m", 'very', 'with', 'the'): {'happy': 0.5, 'satisfied': 0.5},
#  (',', 'it', 'have', 'a'): {'must': 0.5, 'should': 0.5},
#  ('.', 'i', 'wish', 'the'): {'do': 0.3333333333333333,
#   'just': 0.3333333333333333,
#   'really': 0.3333333333333333},
#  (',', 'i', 'very', 'happy'): {"'m": 0.5, 'am': 0.5},
#  ('and', 'i', 'very', 'pleased'): {"'m": 0.4, 'am': 0.6},
#  ('i', 'am', 'pleased', 'with'): {'extremely': 0.1111111111111111,
#   'quite': 0.1111111111111111,
#   'very': 0.7777777777777778},
#  ('am', 'very', 'with', 'it'): {'happy': 0.6, 'pleased': 0.4},
#  ('.', 'i', 'this', 'one'): {'bought': 0.25,
#   'choose': 0.25,
#   'found': 0.25,
#   'picked': 0.25},
#  (')', '.', ',', 'i'): {'also': 0.25, 'however': 0.5, 'overall': 0.25},
#  ('bought', 'this', 'set', 'for'): {'drum': 0.5, 'exact': 0.5},
#  ('the', 'same', '.', 'the'): {'case': 0.2,
#   'item': 0.2,
#   'thing': 0.2,
#   'time': 0.4},
#  ('.', 'the', 'of', 'the'): {'back': 0.1,
#   'bottom': 0.1,
#   'crispness': 0.1,
#   'durability': 0.1,
#   'face': 0.1,
#   'quality': 0.2,
#   'range': 0.1,
#   'size': 0.1,
#   'video': 0.1},
#  ('and', 'the', 'of', 'the'): {'heat': 0.5, 'video': 0.5},
#  ('.', 'i', 'that', 'i'): {'expect': 0.2,
#   'know': 0.2,
#   'like': 0.2,
#   'love': 0.2,
#   'noticed': 0.2},
#  ('was', 'simple', 'i', 'have'): {'.': 0.5, 'and': 0.5},
#  ('and', 'i', 'not', 'even'): {'am': 0.5, 'have': 0.5},
#  ('.', 'i', 'a', 'little'): {'suspect': 0.3333333333333333,
#   'was': 0.6666666666666666},
#  ('i', 'was', 'that', 'it'): {'told': 0.5, 'worried': 0.5},
#  ('.', 'i', 'this', 'because'): {'did': 0.5, 'say': 0.5},
#  ('usa', 'told', 'that', 'they'): {'amazon': 0.5, 'me': 0.5},
#  ('at', 'a', 'price', ','): {'bargain': 0.25, 'great': 0.75},
#  ('.', 'i', "n't", 'find'): {'could': 0.6666666666666666,
#   'did': 0.3333333333333333},
#  (',', 'but', "'s", 'a'): {'it': 0.5, 'there': 0.5},
#  (',', 'the', 'of', 'the'): {'bottom': 0.5,
#   'installation': 0.25,
#   'majority': 0.25},
#  ('as', 'i', 'a', 'lot'): {'do': 0.5, 'spend': 0.5},
#  ('you', 'do', 'want', 'to'): {"n't": 0.8, 'not': 0.2},
#  ('want', 'to', 'the', 'money'): {'put': 0.3333333333333333,
#   'save': 0.3333333333333333,
#   'spend': 0.3333333333333333},
#  ('for', 'about', 'years', 'and'): {'2': 0.5, 'three': 0.5},
#  ('.', 'the', 'is', 'extremely'): {'product': 0.3333333333333333,
#   'software': 0.3333333333333333,
#   'sound': 0.3333333333333333},
#  ('i', 'would', 'recommend', 'this'): {'highly': 0.8, 'not': 0.2},
#  ('for', 'the', ',', 'i'): {'background': 0.25, 'price': 0.75},
#  ('but', 'it', 'to', 'work'): {'proved': 0.3333333333333333,
#   'seems': 0.6666666666666666},
#  ('.', 'i', 'a', 'very'): {'am': 0.3333333333333333,
#   'have': 0.3333333333333333,
#   'spent': 0.3333333333333333},
#  ('take', 'up', 'much', 'room'): {'so': 0.5, 'too': 0.5},
#  ('in', 'my', '.', 'the'): {'belongings': 0.3333333333333333,
#   'dorm': 0.3333333333333333,
#   'experience': 0.3333333333333333},
#  ('.', 'the', 'quality', 'is'): {'audio': 0.09090909090909091,
#   'bose': 0.045454545454545456,
#   'image': 0.045454545454545456,
#   'photo': 0.045454545454545456,
#   'picture': 0.13636363636363635,
#   'record': 0.045454545454545456,
#   'sound': 0.45454545454545453,
#   'video': 0.09090909090909091,
#   'voice': 0.045454545454545456},
#  ('is', 'very', '.', 'i'): {'clear': 0.125,
#   'cool': 0.125,
#   'freeing': 0.125,
#   'good': 0.375,
#   'interesting': 0.125,
#   'slow': 0.125},
#  ('with', 'this', ',', 'and'): {'item': 0.5, 'tv': 0.5},
#  ('the', 'only', 'is', 'that'): {'downside': 0.5,
#   'drawback': 0.25,
#   'thing': 0.25},
#  (',', 'you', 'to', 'press'): {'have': 0.5, 'need': 0.5},
#  ('on', 'the', 'there', 'are'): {'pad': 0.5, 'pen': 0.5},
#  ('.', 'the', 'complaint', 'i'): {'only': 0.6666666666666666,
#   'second': 0.3333333333333333},
#  ('the', 'only', 'i', 'have'): {'complaint': 0.2857142857142857,
#   'cure': 0.14285714285714285,
#   'gripe': 0.14285714285714285,
#   'one': 0.14285714285714285,
#   'problem': 0.2857142857142857},
#  ('.', 'i', 'that', 'it'): {'feel': 0.16666666666666666,
#   'find': 0.16666666666666666,
#   'found': 0.16666666666666666,
#   'like': 0.5},
#  ('on', 'the', 'side', ','): {'bright': 0.16666666666666666,
#   'dark': 0.16666666666666666,
#   'down': 0.3333333333333333,
#   'minus': 0.16666666666666666,
#   'plus': 0.16666666666666666},
#  (',', 'and', "'s", 'a'): {'it': 0.75, 'that': 0.25},
#  ('to', 'be', '.', 'i'): {')': 0.25,
#   'insecure': 0.25,
#   'lasting': 0.25,
#   'lost': 0.25},
#  ('the', 'top', 'which', 'is'): {',': 0.5, 'strap': 0.5},
#  ('.', 'i', 'do', "n't"): {'also': 0.5, 'really': 0.5},
#  (',', 'i', "n't", 'like'): {'did': 0.5, 'do': 0.5},
#  ('a', 'better', 'for', 'the'): {'product': 0.5, 'solution': 0.5},
#  ('and', 'it', 'a', 'bit'): {"'s": 0.5, 'is': 0.5},
#  ('so', 'far', 'have', 'not'): {'.': 0.3333333333333333,
#   'i': 0.6666666666666666},
#  ('i', 'have', 'had', 'any'): {"n't": 0.45454545454545453,
#   'never': 0.09090909090909091,
#   'not': 0.45454545454545453},
#  ('the', 'past', 'months', ','): {'6': 0.5, 'couple': 0.5},
#  ('an', 'excellent', '.', 'i'): {'machine': 0.3333333333333333,
#   'phone': 0.3333333333333333,
#   'product': 0.3333333333333333},
#  ('.', 'i', 'two', 'of'): {'bought': 0.5, 'have': 0.5},
#  ('them', '.', 'are', 'a'): {'there': 0.5, 'these': 0.5},
#  ('success', 'with', 'dvd+r', 'up'): {'fujifilm': 0.5, 'tdk': 0.5},
#  ('about', 'this', 'is', 'that'): {'backpack': 0.16666666666666666,
#   'machine': 0.3333333333333333,
#   'monitor': 0.16666666666666666,
#   'phone': 0.3333333333333333},
#  ('on', 'the', '.', 'you'): {'fly': 0.3333333333333333,
#   'right': 0.3333333333333333,
#   'sides': 0.3333333333333333},
#  ('.', 'you', 'need', 'to'): {'definitely': 0.5, 'will': 0.5},
#  ('of', 'the', 'things', 'about'): {'greatest': 0.5, 'other': 0.5},
#  ('on', 'the', '.', 'i'): {'creature': 0.14285714285714285,
#   'desktop': 0.14285714285714285,
#   'dvd-ram': 0.14285714285714285,
#   'fly': 0.14285714285714285,
#   'market': 0.14285714285714285,
#   'tunedok': 0.14285714285714285,
#   'wire': 0.14285714285714285},
#  ('i', 'bought', 'for', 'my'): {'it': 0.125, 'these': 0.125, 'this': 0.75},
#  ('on', 'the', ',', 'to'): {'dvr': 0.5, 'ground': 0.5},
#  ('under', '$', ',', 'you'): {'20': 0.5, '200': 0.5},
#  ('the', 'only', 'i', 'could'): {'flaw': 0.5, 'thing': 0.5},
#  ('i', 'could', 'is', 'that'): {'find': 0.5, 'say': 0.5},
#  ('did', "n't", 'quite', 'right'): {'seem': 0.5, 'work': 0.5},
#  (',', 'but', "'s", 'not'): {'it': 0.5, 'that': 0.5},
#  (',', 'but', 'ca', "n't"): {'just': 0.5, 'you': 0.5},
#  ('you', 'can', 'go', 'wrong'): {'never': 0.3333333333333333,
#   'not': 0.6666666666666666},
#  ('quality', 'is', '.', 'i'): {'astonishing': 0.3333333333333333,
#   'excellent': 0.3333333333333333,
#   'good': 0.3333333333333333},
#  ('are', 'much', 'than', 'the'): {'better': 0.5, 'smaller': 0.5},
#  ('they', 'were', '!', '!'): {'!': 0.5, 'cheaper': 0.5},
#  ('for', 'the', 'that', 'i'): {'amount': 0.5, 'time': 0.5},
#  ('that', 'i', 'for', 'it'): {'got': 0.5, 'paid': 0.5},
#  (',', 'but', 'all', 'it'): {'considering': 0.5, 'in': 0.5},
#  ('i', "'ve", 'it', 'for'): {'had': 0.5555555555555556,
#   'used': 0.4444444444444444},
#  ('it', 'for', 'a', 'month'): {'about': 0.5, 'almost': 0.25, 'over': 0.25},
#  ('it', 'to', '.', 'i'): {'be': 0.5, 'work': 0.5},
#  ('in', 'the', ',', 'and'): {'case': 0.25,
#   'closet': 0.25,
#   'drive': 0.25,
#   'past': 0.25},
#  (',', 'and', 'are', 'the'): {'these': 0.5, 'this': 0.5},
#  ('with', 'good', 'and', 'the'): {'bass': 0.5, 'lighting': 0.5},
#  ('and', 'the', 'is', 'not'): {'design': 0.3333333333333333,
#   'treble': 0.3333333333333333,
#   'unit': 0.3333333333333333},
#  ('.', 'nice', 'for', 'the'): {'bank': 0.5, 'product': 0.5},
#  ('it', 'so', ',', 'i'): {'far': 0.5, 'much': 0.5},
#  ('i', 'do', 'have', 'a'): {"n't": 0.5, 'not': 0.5},
#  ('.', 'i', 'use', 'them'): {'also': 0.5, 'frequently': 0.5},
#  ('many', 'sony', 'in', 'the'): {'cameras': 0.5, 'electronics': 0.5},
#  ('.', 'i', 'have', 'a'): {'already': 0.14285714285714285,
#   'also': 0.2857142857142857,
#   'do': 0.2857142857142857,
#   'myself': 0.14285714285714285,
#   'still': 0.14285714285714285},
#  (',', 'i', 'to', 'purchase'): {'decided': 0.6666666666666666,
#   'had': 0.3333333333333333},
#  ('i', 'was', 'by', 'the'): {'disappointed': 0.25,
#   'floored': 0.25,
#   'intrigued': 0.25,
#   'supprised': 0.25},
#  ('for', '$', ',', 'i'): {'150': 0.5, '79': 0.5},
#  (',', 'i', "n't", 'expect'): {'ca': 0.5, 'do': 0.5},
#  ('same', 'quality', 'i', 'received'): {'.': 0.5, 'as': 0.5},
#  ('for', 'the', ',', 'it'): {'money': 0.75, 'price': 0.25},
#  ('for', 'the', '.', 'the'): {'bedroom': 0.2,
#   'novice': 0.2,
#   'piano': 0.2,
#   'price': 0.2,
#   'purpose': 0.2},
#  ('.', 'i', 'the', 'feature'): {'like': 0.5, 'liked': 0.5},
#  ('like', 'the', 'of', 'the'): {'feature': 0.5,
#   'ruggedness': 0.25,
#   'weight': 0.25},
#  ('to', 'the', 'of', 'the'): {'back': 0.3333333333333333,
#   'bottom': 0.16666666666666666,
#   'outside': 0.16666666666666666,
#   'side': 0.16666666666666666,
#   'top': 0.16666666666666666},
#  ('of', 'the', '.', 'i'): {'best': 0.07142857142857142,
#   'box': 0.07142857142857142,
#   'case': 0.14285714285714285,
#   'day': 0.07142857142857142,
#   'ipod': 0.07142857142857142,
#   'laptop': 0.07142857142857142,
#   'phones': 0.07142857142857142,
#   'pouch': 0.07142857142857142,
#   'product': 0.07142857142857142,
#   'satellites': 0.07142857142857142,
#   'screen': 0.07142857142857142,
#   'ss-mf650h': 0.07142857142857142,
#   'three': 0.07142857142857142},
#  ('.', 'i', 'recommend', 'it'): {"'d": 0.25, 'highly': 0.375, 'would': 0.375},
#  ('as', 'a', '.', 'i'): {'backup': 0.25, 'bridge': 0.25, 'gift': 0.5},
#  ('.', 'i', 'it', '4'): {'gave': 0.5, 'rate': 0.5},
#  ('is', '``', "''", '.'): {'admin': 0.5, 'ok': 0.5},
#  (',', 'it', 'not', '.'): {"'s": 0.5, 'does': 0.5},
#  ('it', "'s", '.', 'the'): {'excellent': 0.3333333333333333,
#   'great': 0.3333333333333333,
#   'not': 0.3333333333333333},
#  ('of', 'the', 'and', 'the'): {'box': 0.5, 'price': 0.5},
#  ('have', "n't", 'any', 'problems'): {'experienced': 0.2, 'had': 0.8},
#  ('it', 'does', 'come', 'with'): {"n't": 0.5, 'not': 0.5},
#  ('with', 'a', 'so', 'i'): {'headset': 0.5, 'hh': 0.5},
#  ('did', "n't", 'to', 'buy'): {'have': 0.5, 'want': 0.5},
#  ('before', 'you', 'it', '.'): {'buy': 0.5, 'change': 0.25, 'use': 0.25},
#  ('me', ',', 'i', 'have'): {'although': 0.5, 'because': 0.5},
#  ('.', 'i', 'to', 'buy'): {'decided': 0.25, 'had': 0.5, 'plan': 0.25},
#  ('pulled', 'the', 'out', 'of'): {'ipod': 0.5, 'receiver': 0.5},
#  ('when', 'the', 'is', 'in'): {'ipod': 0.5, 'unit': 0.5},
#  ('.', 'the', 'problem', 'is'): {'last': 0.5, 'only': 0.5},
#  ('an', '``', "''", 'to'): {'upgrade': 0.5, 'uplink': 0.5},
#  ('to', 'get', 'to', 'work'): {'it': 0.75, 'them': 0.25},
#  ('than', 'that', 'it', 'is'): {',': 0.5, '...': 0.5},
#  ('i', 'was', 'to', 'get'): {'able': 0.42857142857142855,
#   'going': 0.42857142857142855,
#   'hesitant': 0.14285714285714285},
#  ('in', 'the', 'that', 'i'): {'neighborhood': 0.3333333333333333,
#   'songs': 0.3333333333333333,
#   'time': 0.3333333333333333},
#  ('sort', 'of', ',', 'but'): {'expected': 0.5, 'receiver': 0.5},
#  ('fine', ',', 'when', 'i'): {'although': 0.5, 'but': 0.5},
#  ('when', 'i', 'to', 'the'): {'connect': 0.3333333333333333,
#   'listen': 0.3333333333333333,
#   'went': 0.3333333333333333},
#  ('on', 'the', ')', ','): {'screen': 0.5, 'subject': 0.5},
#  ('.', 'i', 'had', 'no'): {"'ve": 0.5, 'have': 0.5},
#  ('i', "'ve", 'no', 'problems'): {'experienced': 0.16666666666666666,
#   'had': 0.8333333333333334},
#  ('.', 'i', 'recommend', 'this'): {'definitely': 0.06666666666666667,
#   'highly': 0.4,
#   'really': 0.13333333333333333,
#   'strongly': 0.13333333333333333,
#   'would': 0.26666666666666666},
#  (',', 'which', 'on', 'the'): {'are': 0.5, 'sits': 0.5},
#  ('of', 'the', '.', 'it'): {'av500': 0.16666666666666666,
#   'controller': 0.16666666666666666,
#   'desk': 0.16666666666666666,
#   'line': 0.16666666666666666,
#   'pages': 0.16666666666666666,
#   'way': 0.16666666666666666},
#  ('the', 'best', 'i', "'ve"): {'5.8': 0.2,
#   'gadget-products': 0.2,
#   'headphones': 0.2,
#   'mouse': 0.4},
#  ('mouse', 'i', 'ever', 'owned'): {"'ve": 0.6666666666666666,
#   'have': 0.3333333333333333},
#  ('.', 'it', 'fast', ','): {'is': 0.5, 'prints': 0.5},
#  ('.', 'i', 'definitely', 'recommend'): {"'d": 0.3333333333333333,
#   'would': 0.6666666666666666},
#  ('i', 'would', 'recommend', 'it'): {'definitely': 0.3333333333333333,
#   'highly': 0.6666666666666666},
#  ('this', 'mouse', 'just', 'right'): {'feels': 0.5, 'is': 0.5},
#  ('one', '.', 'of', 'the'): {'most': 0.5, 'one': 0.5},
#  ('to', 'my', '.', 'for'): {'iriver': 0.5, 'reciever': 0.5},
#  (',', 'it', 'a', 'little'): {"'s": 0.5, 'feels': 0.5},
#  ('are', 'the', 'to', 'go'): {'requirement': 0.5, 'way': 0.5},
#  ('.', 'i', "n't", 'know'): {'did': 0.1, 'do': 0.9},
#  ('i', 'do', 'know', 'how'): {"n't": 0.6666666666666666,
#   'not': 0.3333333333333333},
#  ('from', 'one', 'to', 'another'): {'computer': 0.5, 'place': 0.5},
#  ('the', 'way', 'i', "'ve"): {',': 0.5, '.': 0.5},
#  ('i', "'ve", 'mine', 'for'): {'had': 0.5, 'owned': 0.5},
#  ('.', 'i', 'have', 'to'): {'just': 0.6666666666666666,
#   'never': 0.3333333333333333},
#  ('have', 'the', 'model', '('): {'1g': 0.5, 'dvd-224m': 0.5},
#  ('which', 'is', '.', 'i'): {'great': 0.5, 'nice': 0.5},
#  ('is', 'great', 'i', 'was'): {'!': 0.5, '.': 0.5},
#  ('to', 'the', ',', 'but'): {'bottom': 0.5, 'next': 0.5},
#  ('.', 'i', 'the', 'same'): {'experienced': 0.5, 'had': 0.5},
#  ('.', 'i', 'it', 'in'): {'installed': 0.2,
#   'plugged': 0.2,
#   'sent': 0.2,
#   'use': 0.4},
#  ('a', 'good', '.', 'it'): {'buy': 0.6666666666666666,
#   'value': 0.3333333333333333},
#  ('easy', 'to', '.', 'i'): {'setup': 0.25, 'use': 0.75},
#  ('.', 'i', 'wish', 'it'): {'just': 0.5, 'only': 0.5},
#  (',', 'i', 'very', 'satisfied'): {"'m": 0.5, 'am': 0.5},
#  ('and', 'thought', 'was', 'the'): {'it': 0.5, 'that': 0.5},
#  (',', 'i', 'able', 'to'): {"'m": 0.25, 'am': 0.25, 'was': 0.5},
#  ('.', 'the', 'was', 'fast'): {'service': 0.5, 'shipping': 0.5},
#  ('service', 'was', 'and', 'the'): {'excellent': 0.5, 'fast': 0.5},
#  (',', 'my', ',', 'and'): {'ebooks': 0.5, 'jeans': 0.5},
#  ('.', 'i', 'had', 'to'): {'have': 0.25, 'just': 0.25, 'never': 0.5},
#  ('.', 'i', 'it', 'myself'): {'did': 0.5, 'experienced': 0.5},
#  ('it', "'s", 'not', 'the'): {'actually': 0.5, 'probably': 0.5},
#  ('i', 'am', 'impressed', 'with'): {'greatly': 0.3333333333333333,
#   'very': 0.6666666666666666},
#  ('am', 'very', 'with', 'the'): {'familiar': 0.1111111111111111,
#   'happy': 0.3333333333333333,
#   'impressed': 0.3333333333333333,
#   'pleased': 0.1111111111111111,
#   'satisfied': 0.1111111111111111},
#  ('and', 'it', 'just', 'fine'): {'is': 0.3333333333333333,
#   'records': 0.3333333333333333,
#   'works': 0.3333333333333333},
#  ('.', 'i', 'used', 'it'): {"'ve": 0.5, 'also': 0.1, 'even': 0.1, 'have': 0.3},
#  ('.', 'this', 'is', 'much'): {'hookup': 0.5, 'one': 0.5},
#  ('of', 'the', '.', 'there'): {'bag': 0.3333333333333333,
#   'lawnmower': 0.3333333333333333,
#   'pack': 0.3333333333333333},
#  ('.', 'it', 'great', ','): {'looks': 0.2, 'works': 0.8},
#  ('i', 'have', 'this', 'system'): {'used': 0.3333333333333333,
#   'with': 0.6666666666666666},
#  ('you', 'are', 'going', 'to'): {'just': 0.3333333333333333,
#   "n't": 0.3333333333333333,
#   'not': 0.3333333333333333},
#  ('do', "n't", 'to', 'take'): {'need': 0.5, 'seem': 0.5},
#  ('to', 'take', 'of', 'your'): {'all': 0.5, 'care': 0.5},
#  ('with', 'my', 'and', 'i'): {'husband': 0.5, 'mac': 0.5},
#  ('a', 'bad', '.', 'i'): {'disc': 0.5, 'review': 0.5},
#  ('i', 'would', 'this', 'product'): {'reccommend': 0.3333333333333333,
#   'recommend': 0.6666666666666666},
#  ('.', 'it', 'be', 'a'): {'may': 0.5, 'would': 0.5},
#  ('i', 'do', 'consider', 'it'): {"n't": 0.5, 'still': 0.5},
#  ('and', 'finally', 'on', 'this'): {'decided': 0.5, 'settled': 0.5},
#  ("'m", 'very', 'with', 'my'): {'pleased': 0.5, 'satisfied': 0.5},
#  ('.', 'i', 'that', 'the'): {'agree': 0.25,
#   'find': 0.25,
#   'think': 0.25,
#   'wish': 0.25},
#  ('.', 'i', 'the', 'instructions'): {'followed': 0.5, 'saved': 0.5},
#  ('it', 'is', '.', 'i'): {'better': 0.3333333333333333,
#   'fine': 0.3333333333333333,
#   'possible': 0.3333333333333333},
#  ('and', 'it', 'fine', '.'): {"'s": 0.3333333333333333,
#   'played': 0.3333333333333333,
#   'works': 0.3333333333333333},
#  ('other', 'reviews', 'this', 'product'): {'for': 0.5, 'of': 0.5},
#  ('is', 'not', 'if', 'you'): {'easy': 0.5, 'true': 0.5},
#  ('to', 'be', 'with', 'this'): {'expected': 0.5, 'happy': 0.5},
#  ('recommend', 'this', 'to', 'anyone'): {'mic': 0.2,
#   'phone': 0.2,
#   'product': 0.2,
#   'setup': 0.2,
#   'system': 0.2},
#  ('for', 'about', 'months', '.'): {'six': 0.5, 'three': 0.5},
#  ("'m", 'very', 'with', 'this'): {'happy': 0.6,
#   'pleased': 0.2,
#   'satisfied': 0.2},
#  ('this', 'product', 'it', "'s"): {'.': 0.5, 'since': 0.5},
#  ('in', 'a', '.', 'i'): {'card': 0.5, 'snap': 0.5},
#  ('i', 'have', 'with', 'a'): {'had': 0.5, 'worked': 0.5},
#  ('and', 'i', 'never', 'had'): {"'ve": 0.3333333333333333,
#   'have': 0.6666666666666666},
#  ('i', 'have', 'had', 'to'): {"n't": 0.25, 'never': 0.25, 'not': 0.5},
#  ('thank', 'you', '!', '!'): {'!': 0.5, 'motorola': 0.5},
#  ('is', 'a', 'buy', '.'): {'definte': 0.5, 'good': 0.5},
#  ('overall', ',', 'is', 'a'): {'it': 0.3333333333333333,
#   'this': 0.6666666666666666},
#  (',', 'it', 'a', 'good'): {"'s": 0.2, 'is': 0.4, 'turned': 0.2, 'was': 0.2},
#  ('.', 'i', 'the', 'fact'): {'enjoy': 0.3333333333333333,
#   'like': 0.3333333333333333,
#   'love': 0.3333333333333333},
#  ('love', 'the', 'that', 'it'): {'convenience': 0.5, 'fact': 0.5},
#  ('over', 'the', 'of', 'the'): {'edge': 0.5, 'roar': 0.5},
#  ('a', 'little', 'on', 'the'): {'more': 0.5, 'time': 0.5},
#  ('do', "n't", 'you', 'have'): {'-': 0.5, 'think': 0.5},
#  ('i', 'bought', '.', 'i'): {'it': 0.3333333333333333,
#   'one': 0.3333333333333333,
#   'used': 0.3333333333333333},
#  ('if', 'you', 'a', 'good'): {'choose': 0.3333333333333333,
#   'get': 0.3333333333333333,
#   'want': 0.3333333333333333},
#  ('the', 'most', 'part', 'of'): {'annoying': 0.3333333333333333,
#   'subjective': 0.3333333333333333,
#   'unique': 0.3333333333333333},
#  ('have', 'to', 'up', 'for'): {'make': 0.5, 'save': 0.5},
#  (',', 'as', 'as', 'the'): {'soon': 0.5, 'well': 0.5},
#  ('you', 'are', 'with', 'the'): {'met': 0.5, 'ok': 0.5},
#  ('is', 'the', 'product', 'for'): {'best': 0.5, 'perfect': 0.5},
#  ('and', 'i', 'going', 'to'): {"'m": 0.5, 'was': 0.5},
#  ('as', 'well', 'it', 'is'): {'.': 0.5, 'but': 0.5},
#  ('.', 'it', 'very', 'easy'): {"'s": 0.3333333333333333,
#   'is': 0.6666666666666666},
#  ('easy', 'to', 'on', 'and'): {'get': 0.5, 'type': 0.5},
#  ('.', 'it', 'easy', 'to'): {'is': 0.8, 'was': 0.2},
#  ('it', 'was', 'to', 'install'): {'easy': 0.6666666666666666,
#   'simple': 0.3333333333333333},
#  ('i', 'am', 'with', 'the'): {'happier': 0.2,
#   'impressed': 0.4,
#   'pleased': 0.2,
#   'satisfied': 0.2},
#  ('through', 'the', 'of', 'the'): {'front': 0.5, 'lot': 0.5},
#  ('of', 'the', '.', 'the'): {'guitar': 0.125,
#   'keys': 0.125,
#   'nano': 0.125,
#   'printer': 0.125,
#   'product': 0.125,
#   'receiver': 0.125,
#   'way': 0.125,
#   'wireless': 0.125},
#  ('in', 'the', 'of', 'the'): {'bottom': 0.25, 'center': 0.25, 'middle': 0.5},
#  ('it', "'s", 'to', 'do'): {'advertised': 0.5, 'suppose': 0.5},
#  ('so', 'the', 'does', 'not'): {'nano': 0.5, 'sound': 0.5},
#  ('.', 'the', 'is', 'very'): {'bass': 0.25,
#   'design': 0.125,
#   'labeling': 0.125,
#   'mouse': 0.125,
#   'sound': 0.25,
#   'wire': 0.125},
#  ('a', 'small', 'rather', 'than'): {'box': 0.5, 'inconvenience': 0.5},
#  ('from', 'the', '.', 'it'): {'nano': 0.3333333333333333,
#   'speakers': 0.3333333333333333,
#   'wall': 0.3333333333333333},
#  ('is', 'very', ',', 'and'): {'convient': 0.14285714285714285,
#   'good': 0.42857142857142855,
#   'inexpensive': 0.14285714285714285,
#   'obvious': 0.14285714285714285,
#   'punchy': 0.14285714285714285},
#  ('for', 'the', ',', 'and'): {'hd': 0.2,
#   'money': 0.2,
#   'price': 0.2,
#   'problem': 0.2,
#   'road': 0.2},
#  (',', 'you', 'need', 'a'): {'only': 0.3333333333333333,
#   'will': 0.6666666666666666},
#  ('you', 'will', 'a', 'lot'): {'need': 0.5, 'save': 0.5},
#  (',', 'the', 'are', 'good'): {'prices': 0.5, 'ssmf650h': 0.5},
#  ('on', 'the', '.', 'they'): {'bass': 0.5, 'road': 0.5},
#  ('a', 'bit', ',', 'but'): {'better': 0.5, 'shady': 0.5},
#  ('if', 'you', 'looking', 'for'): {"'re": 0.36363636363636365,
#   'are': 0.6363636363636364},
#  ('happy', 'with', 'purchase', '.'): {'my': 0.6, 'this': 0.4},
#  ('with', 'this', '.', 'i'): {'camera': 0.2,
#   'model': 0.2,
#   'paper': 0.2,
#   'purchase': 0.4},
#  ('.', 'i', 'been', 'very'): {"'ve": 0.5, 'have': 0.5},
#  ('highs', 'are', 'and', 'the'): {'crisp': 0.5, 'present': 0.5},
#  (',', 'not', '.', 'the'): {'boomy': 0.5, 'exceptional': 0.5},
#  ('after', 'i', 'it', 'and'): {'connected': 0.5, 'installed': 0.5},
#  ('the', 'first', '.', 'i'): {'failed': 0.25,
#   'floor': 0.25,
#   'one': 0.25,
#   'time': 0.25},
#  ('or', '``', "''", 'for'): {'0': 0.5, 'large': 0.5},
#  ('that', 'the', 'of', 'the'): {'quality': 0.3333333333333333,
#   'thinness': 0.3333333333333333,
#   'use': 0.3333333333333333},
#  ('if', 'the', 'is', 'not'): {'connection': 0.5, 'fit': 0.5},
#  ('.', 'there', 'be', 'a'): {'could': 0.3333333333333333,
#   'may': 0.3333333333333333,
#   'should': 0.3333333333333333},
#  ("'ve", 'ever', '.', 'the'): {'bought': 0.5, 'had': 0.5},
#  ('to', 'my', ')', '.'): {'router': 0.5, 'wife': 0.5},
#  ('with', 'my', 'ipod', '.'): {'regular-sized': 0.5, 'white': 0.5},
#  ('volume', ',', ',', 'and'): {'bass': 0.5, 'depth': 0.5},
#  ('i', "'ve", 'it', '.'): {'compared': 0.3333333333333333,
#   'had': 0.3333333333333333,
#   'owned': 0.3333333333333333},
#  ('that', 'the', 'is', 'no'): {'8125': 0.5, 'item': 0.5},
#  ('with', 'my', 'player', 'and'): {'cd': 0.5, 'mp3': 0.5},
#  ('my', 'only', 'is', 'that'): {'complaint': 0.25,
#   'problem': 0.25,
#   'regret': 0.25,
#   'wish': 0.25},
#  ('can', 'really', 'the', 'bass'): {'feel': 0.5, 'follow': 0.5},
#  ('not', 'too', ',', 'but'): {'bad': 0.3333333333333333,
#   'bright': 0.3333333333333333,
#   'sure': 0.3333333333333333},
#  (',', 'and', '.', 'the'): {'easily': 0.25, 'musical': 0.25, 'vivid': 0.5},
#  ('.', 'in', ',', 'i'): {'all': 0.3333333333333333,
#   'fact': 0.6666666666666666},
#  (',', 'i', 'these', 'headphones'): {'blame': 0.5, 'love': 0.5},
#  ('.', 'i', "n't", 'think'): {'ca': 0.125, 'do': 0.875},
#  ('if', 'this', 'would', 'work'): {'hub': 0.5, 'product': 0.5},
#  ('.', 'i', 'been', 'using'): {"'ve": 0.5714285714285714,
#   'have': 0.42857142857142855},
#  ('so', 'you', "n't", 'have'): {'do': 0.75, 'wo': 0.25},
#  ('have', ',', 'it', 'is'): {'and': 0.5, 'but': 0.5},
#  ('.', 'i', 'on', 'the'): {"'m": 0.25,
#   'focused': 0.25,
#   'settled': 0.25,
#   'stay': 0.25},
#  ('on', 'my', '.', 'i'): {'ear': 0.25,
#   'hand': 0.25,
#   'mac': 0.25,
#   'receiver': 0.25},
#  ('.', 'i', 'had', 'it'): {"'ve": 0.8571428571428571,
#   'have': 0.14285714285714285},
#  ('.', 'i', 'glad', 'i'): {"'m": 0.75, 'am': 0.25},
#  (',', 'i', 'not', 'a'): {"'m": 0.5, 'am': 0.5},
#  ('.', 'but', 'you', "'re"): {'if': 0.6666666666666666,
#   'unless': 0.3333333333333333},
#  ('for', 'about', 'months', 'now'): {'2': 0.2, '3': 0.2, '4': 0.2, '8': 0.4},
#  ('to', 'work', '.', 'it'): {'well': 0.5, 'with': 0.5},
#  ('in', 'the', 'of', 'a'): {'form': 0.4, 'middle': 0.6},
#  ('i', 'am', 'with', 'this'): {'happy': 0.3333333333333333,
#   'pleased': 0.3333333333333333,
#   'thrilled': 0.3333333333333333},
#  ('a', 'good', '.', 'the'): {'fit': 0.3333333333333333,
#   'purchase': 0.3333333333333333,
#   'value': 0.3333333333333333},
#  ('kind', 'of', ',', 'but'): {'expensive': 0.5, 'media': 0.5},
#  ('been', 'using', 'for', 'a'): {'them': 0.6666666666666666,
#   'these': 0.3333333333333333},
#  ('.', '(', ':', 'i'): {'disclaimer': 0.5, 'note': 0.5},
#  ('.', 'this', 'is', 'better'): {'machine': 0.5, 'range': 0.5},
#  ('if', 'you', 'in', 'a'): {'are': 0.5, 'invest': 0.5},
#  ('i', 'do', 'think', 'it'): {"n't": 0.75, 'not': 0.25},
#  ('on', 'a', 'set', 'of'): {'great': 0.5, 'quality': 0.5},
#  ('.', 'the', 'of', 'this'): {'openness': 0.3333333333333333,
#   'size': 0.3333333333333333,
#   'sound': 0.3333333333333333},
#  ('you', "'ll", 'have', 'to'): {'either': 0.5, 'never': 0.5},
#  ('any', 'other', '.', 'it'): {'drive': 0.5, 'problems': 0.5},
#  ("'m", 'very', 'so', 'far'): {'impressed': 0.5, 'satisfied': 0.5},
#  ('between', 'the', 'and', 'the'): {'437': 0.5, 'windsheild': 0.5},
#  ('i', 'got', ',', 'i'): {'home': 0.5, 'it': 0.5},
#  ('and', 'the', 'was', 'a'): {'intall': 0.3333333333333333,
#   'mount': 0.3333333333333333,
#   'sound': 0.3333333333333333},
#  ('.', 'i', 'the', 'sound'): {'set': 0.5, 'think': 0.5},
#  ('i', 'was', 'impressed', 'with'): {'not': 0.5, 'really': 0.5},
#  ('the', 'earbuds', 'came', 'with'): {'that': 0.6666666666666666,
#   'which': 0.3333333333333333},
#  ('it', '.', ',', 'i'): {'however': 0.3333333333333333,
#   'overall': 0.3333333333333333,
#   'well': 0.3333333333333333},
#  (',', 'i', 'say', 'that'): {'can': 0.3333333333333333,
#   'should': 0.3333333333333333,
#   'would': 0.3333333333333333},
#  ('for', 'the', 'price', '.'): {'inexpensive': 0.5, 'right': 0.5},
#  ('the', 'best', 'phones', 'i'): {'budget': 0.5, 'wireless': 0.5},
#  ('from', 'the', '.', 'the'): {'front': 0.3333333333333333,
#   'handset': 0.3333333333333333,
#   'pictures': 0.3333333333333333},
#  ('.', 'the', 'is', 'a'): {'alternative': 0.07142857142857142,
#   'artifact': 0.07142857142857142,
#   'cable': 0.07142857142857142,
#   'clickwheel': 0.07142857142857142,
#   'construction': 0.07142857142857142,
#   'drum': 0.07142857142857142,
#   'handset': 0.07142857142857142,
#   'itrip': 0.14285714285714285,
#   'paper': 0.07142857142857142,
#   'pc155': 0.07142857142857142,
#   'phone': 0.07142857142857142,
#   'screen': 0.07142857142857142,
#   'tunecast': 0.07142857142857142},
#  ('.', 'the', 'is', 'clear'): {'picture': 0.5, 'sound': 0.5},
#  (',', 'and', ',', 'the'): {'again': 0.5, 'intimate': 0.5},
#  ('.', 'the', 'are', 'easy'): {'controls': 0.5, 'jacks': 0.5},
#  ('controls', 'are', 'to', 'use'): {'easy': 0.6666666666666666,
#   'simple': 0.3333333333333333},
#  ('easy', 'to', '.', 'the'): {'navigate': 0.3333333333333333,
#   'progam': 0.3333333333333333,
#   'use': 0.3333333333333333},
#  ('quality', 'and', 'of', 'the'): {'fidelity': 0.25,
#   'finish': 0.25,
#   'longevity': 0.25,
#   'performance': 0.25},
#  ('.', 'the', 'buttons', 'are'): {'extra': 0.5, 'function': 0.5},
#  ('that', 'it', 'with', 'a'): {'came': 0.5, 'comes': 0.5},
#  ('.', 'it', 'so', 'small'): {"'s": 0.5, 'is': 0.5},
#  ('the', 'phone', '.', 'i'): {')': 0.5, 'lot': 0.5},
#  ('you', 'are', 'to', 'use'): {'going': 0.6666666666666666,
#   'planning': 0.3333333333333333},
#  ('a', 'great', 'to', 'have'): {'idea': 0.5, 'product': 0.5},
#  ('.', 'the', 'does', 'not'): {'printer': 0.3333333333333333,
#   'q9b': 0.3333333333333333,
#   'unit': 0.3333333333333333},
#  ('works', 'great', 'if', 'you'): {'!': 0.5, '.': 0.5},
#  ('.', 'i', 'a', 'few'): {'paid': 0.5, 'write': 0.5},
#  ('.', 'i', 'did', "n't"): {'just': 0.3333333333333333,
#   'really': 0.6666666666666666},
#  ('.', 'i', 'like', 'this'): {'actually': 0.5, 'really': 0.5},
#  ('on', 'my', 'and', 'it'): {'imac': 0.5, 'pc': 0.5},
#  ('i', 'did', 'want', 'to'): {"n't": 0.75, 'not': 0.25},
#  ('the', 'best', 'for', 'the'): {'bang': 0.25, 'one': 0.25, 'place': 0.5},
#  ('do', "n't", 'to', 'worry'): {'have': 0.6666666666666666,
#   'want': 0.3333333333333333},
#  ('to', 'the', '.', 'i'): {'internet': 0.16666666666666666,
#   'kitchen': 0.16666666666666666,
#   'radio': 0.16666666666666666,
#   'store': 0.16666666666666666,
#   'trackman': 0.16666666666666666,
#   'wall': 0.16666666666666666},
#  (',', 'this', 'a', 'great'): {'is': 0.7142857142857143,
#   'was': 0.2857142857142857},
#  ('is', 'a', 'product', '.'): {'great': 0.6666666666666666,
#   'wonderful': 0.3333333333333333},
#  ('in', 'the', '.', 'the'): {'60s': 0.2,
#   'house': 0.2,
#   'marketplace': 0.2,
#   'office': 0.2,
#   'past': 0.2},
#  ('ca', "n't", 'it', ','): {'find': 0.5, 'watch': 0.5},
#  (',', 'you', 'want', 'to'): {'may': 0.25, 'might': 0.5, 'will': 0.25},
#  (',', 'i', 'not', 'sure'): {"'m": 0.5, 'was': 0.5},
#  ('i', 'was', 'surprised', 'when'): {'so': 0.5, 'very': 0.5},
#  ('i', 'found', 'that', 'the'): {'is': 0.5, 'out': 0.5},
#  ('would', 'be', 'if', 'the'): {'better': 0.3333333333333333,
#   'nice': 0.3333333333333333,
#   'worse': 0.3333333333333333},
#  (',', 'but', 'have', "n't"): {'i': 0.6666666666666666,
#   'still': 0.3333333333333333},
#  ('very', 'high', '.', 'i'): {'expectations': 0.3333333333333333,
#   'levels': 0.3333333333333333,
#   'quality': 0.3333333333333333},
#  ('.', 'for', 'price', ','): {'the': 0.75, 'this': 0.25},
#  ('.', 'at', ',', 'i'): {'first': 0.5, 'home': 0.5},
#  ('of', 'the', ',', 'and'): {'screen': 0.5, 'water': 0.5},
#  ('than', 'the', '.', 'i'): {'bose': 0.5, 'sharp': 0.5},
#  ('i', 'am', 'able', 'to'): {'even': 0.5, 'not': 0.5},
#  ('for', 'the', 'to', 'go'): {'price': 0.5, 'static': 0.5},
#  (',', 'it', 'still', 'not'): {'was': 0.5, 'will': 0.5},
#  ('.', 'the', 'is', "n't"): {'interface': 0.3333333333333333,
#   'sound': 0.3333333333333333,
#   'urc9910': 0.3333333333333333},
#  ('and', 'the', 'is', 'a'): {'other': 0.25,
#   'remote': 0.25,
#   'result': 0.25,
#   'subwoofer': 0.25},
#  ('.', 'it', 'a', 'little'): {"'s": 0.25, 'holds': 0.25, 'is': 0.5},
#  ('is', 'a', 'hard', 'to'): {'bit': 0.5, 'little': 0.5},
#  ('you', 'do', 'need', 'to'): {"n't": 0.6666666666666666,
#   'not': 0.3333333333333333},
#  ('.', 'it', 'the', 'job'): {'does': 0.5, 'gets': 0.5},
#  ('though', 'the', 'is', 'a'): {'snare': 0.5, 'ui': 0.5},
#  ('.', 'it', 'record', 'in'): {'can': 0.5, 'you': 0.5},
#  ('need', 'to', 'it', 'as'): {'burn': 0.5, 'use': 0.5},
#  ('i', "'m", 'to', 'see'): {'glad': 0.5, 'happy': 0.5},
#  ('if', 'you', 'it', 'on'): {'drop': 0.3333333333333333,
#   'heard': 0.3333333333333333,
#   'put': 0.3333333333333333},
#  ('it', "'s", '.', 'and'): {'indescribable': 0.5, 'smooth': 0.5},
#  ('by', 'the', ',', 'i'): {'8': 0.25, 'way': 0.75},
#  ('the', 'quickcam', 'for', 'my'): {'fusion': 0.5, 'stx': 0.5},
#  ('.', 'it', 'a', 'great'): {"'s": 0.75, 'is': 0.25},
#  ('a', 'good', 'for', 'the'): {'price': 0.5, 'value': 0.5},
#  ('about', 'a', '.', 'i'): {'month': 0.25, 'week': 0.25, 'year': 0.5},
#  ('find', 'the', 'of', 'the'): {'balance': 0.5, 'shape': 0.5},
#  ('.', 'the', 'is', 'great'): {'fit': 0.3333333333333333,
#   'price': 0.3333333333333333,
#   'sound': 0.3333333333333333},
#  ('.', 'i', "n't", 'be'): {'could': 0.5, 'wo': 0.5},
#  ('for', 'this', 'is', 'the'): {'mouse': 0.5, 'pda': 0.5},
#  ('.', 'i', 'to', 'get'): {'have': 0.5, 'tried': 0.5},
#  ('.', 'the', 'is', 'crystal'): {'screen': 0.5, 'sound': 0.5},
#  ('feature', 'is', '.', 'the'): {'handy': 0.5, 'useful': 0.5},
#  ('a', 'little', ',', 'and'): {'high': 0.3333333333333333,
#   'slower': 0.3333333333333333,
#   'small': 0.3333333333333333},
#  ('.', 'i', 'it', 'with'): {'updated': 0.5, 'use': 0.5},
#  ('and', 'the', 'is', 'fast'): {'camera': 0.5, 'printing': 0.5},
#  ('.', 'if', 'want', 'to'): {'i': 0.2857142857142857,
#   'you': 0.7142857142857143},
#  ('is', 'really', '.', 'the'): {'cool': 0.5, 'great': 0.5},
#  ('i', 'do', 'use', 'the'): {"n't": 0.6666666666666666,
#   'not': 0.3333333333333333},
#  ('.', 'the', 'deserves', 'a'): {'base': 0.5, 'unit': 0.5},
#  ('it', "'s", 'that', 'the'): {'cool': 0.3333333333333333,
#   'nice': 0.3333333333333333,
#   'unlikely': 0.3333333333333333},
#  ('the', 'best', 'on', 'the'): {'deals': 0.3333333333333333,
#   'one': 0.3333333333333333,
#   'price': 0.3333333333333333},
#  ('a', 'very', 'product', '.'): {'durable': 0.5, 'solid': 0.5},
#  ('.', 'it', 'not', 'bad'): {"'s": 0.5, 'is': 0.5},
#  ('by', 'the', 'of', 'the'): {'quality': 0.5,
#   'speakers': 0.25,
#   'tension': 0.25},
#  ('.', 'in', ',', 'the'): {'addition': 0.5, 'fact': 0.5},
#  ('.', 'my', 'is', 'to'): {'recomendation': 0.5, 'recommendation': 0.5},
#  (',', 'no', ',', 'no'): {'issues': 0.5, 'receipt': 0.5},
#  ('.', 'it', 'great', '.'): {"'s": 0.5, 'worked': 0.5},
#  ('.', 'for', 'speakers', ','): {'small': 0.5, 'travel': 0.5},
#  ('with', 'the', 'and', 'the'): {'macs': 0.5, 'sound': 0.5},
#  ('easy', 'to', 'and', 'use'): {'install': 0.5,
#   'reach': 0.16666666666666666,
#   'set-up': 0.16666666666666666,
#   'setup': 0.16666666666666666},
#  ('on', 'the', 'of', 'the'): {'back': 0.3333333333333333,
#   'bottom': 0.06666666666666667,
#   'front': 0.2,
#   'outside': 0.06666666666666667,
#   'quality': 0.13333333333333333,
#   'side': 0.06666666666666667,
#   'sides': 0.06666666666666667,
#   'top': 0.06666666666666667},
#  ('is', 'very', 'and', 'the'): {'comfortable': 0.5, 'stylish': 0.5},
#  ('have', 'to', 'the', 'bass'): {'say': 0.5, 'turn': 0.5},
#  ('for', 'the', ',', 'this'): {'money': 0.5, 'price': 0.5},
#  ('and', 'it', 'great', '!'): {'worked': 0.5, 'works': 0.5},
#  ('of', 'the', 'into', 'the'): {'cable': 0.5, 'earpiece': 0.5},
#  ('and', 'the', 'end', 'into'): {'other': 0.6666666666666666,
#   'white': 0.3333333333333333},
#  ('reviewer', 'who', 'the', 'speakers'): {'returned': 0.5, 'said': 0.5},
#  ('time', 'to', 'how', 'to'): {'know': 0.5, 'learn': 0.5},
#  ('because', 'i', 'wanted', 'to'): {'just': 0.5, 'only': 0.5},
#  ('i', 'just', 'to', 'get'): {'have': 0.5, 'wanted': 0.5},
#  ('for', 'the', ',', 'you'): {'cost': 0.25, 'price': 0.75},
#  ('home', 'theater', '.', 'the'): {'equipment': 0.6666666666666666,
#   'values': 0.3333333333333333},
#  ('with', 'the', ',', 'but'): {'catridge': 0.5, 'gps': 0.5},
#  (')', '.', 'far', ','): {'by': 0.5, 'so': 0.5},
#  ('were', 'as', 'as', 'the'): {'cheap': 0.5, 'good': 0.5},
#  ('and', 'the', 'are', 'just'): {'earbuds': 0.3333333333333333,
#   'prints': 0.3333333333333333,
#   'roads': 0.3333333333333333},
#  ('to', 'turn', 'the', 'volume'): {'down': 0.6666666666666666,
#   'up': 0.3333333333333333},
#  ('.', 'i', 'back', 'to'): {'switched': 0.5, 'went': 0.5},
#  ('of', 'the', ',', 'so'): {'tv': 0.5, 'westinghouse': 0.5},
#  ('it', "'s", 'quite', 'good'): {'actually': 0.5, 'also': 0.5},
#  ('not', 'a', ',', 'but'): {'techie': 0.5, 'ton': 0.5},
#  ('bought', 'this', ',', 'i'): {'device': 0.5, 'product': 0.5},
#  ('.', 'i', 'it', 'for'): {'bought': 0.25, 'use': 0.75},
#  ('very', 'pleased', 'it', "'s"): {'.': 0.5, 'with': 0.5},
#  ('no', 'problems', 'though', ','): {',': 0.5, '.': 0.5},
#  ('.', 'i', 'mine', 'at'): {'bought': 0.5, 'found': 0.5},
#  ('i', "'ve", 'with', 'it'): {'had': 0.6666666666666666,
#   'worked': 0.3333333333333333},
#  ('in', 'the', 'and', 'i'): {'dark': 0.3333333333333333,
#   'kitchen': 0.3333333333333333,
#   'tivoli': 0.3333333333333333},
#  ('listen', 'to', 'music', 'and'): {'classical': 0.5, 'rock': 0.5},
#  ('.', 'my', 'is', 'that'): {'complaint': 0.5, 'opinion': 0.5},
#  ('you', 'are', 'to', 'the'): {'listening': 0.5, 'used': 0.5},
#  ('.', 'this', 'is', 'great'): {'radio': 0.5, 'thing': 0.5},
#  ('you', 'do', 'have', 'to'): {"n't": 0.8888888888888888,
#   'not': 0.1111111111111111},
#  ('from', 'my', 'to', 'my'): {'cellphne': 0.5, 'pc': 0.5},
#  ("n't", 'even', 'close', 'to'): {'come': 0.5, 'get': 0.5},
#  ('.', 'i', 'both', 'the'): {'enjoy': 0.5, 'have': 0.5},
#  ('.', 'it', 'perfect', 'for'): {"'s": 0.3333333333333333,
#   'is': 0.6666666666666666},
#  ('.', 'it', 'with', 'a'): {'came': 0.75, 'comes': 0.25},
#  ('.', 'my', 'problem', 'with'): {'biggest': 0.25, 'only': 0.75},
#  ('with', 'the', 'is', 'that'): {'6600gt': 0.3333333333333333,
#   'e30s': 0.3333333333333333,
#   'player': 0.3333333333333333},
#  ('is', 'that', 'ca', "n't"): {'i': 0.5, 'you': 0.5},
#  ('to', 'the', 'from', 'the'): {'picture': 0.5, 'touches': 0.5},
#  ('.', 'this', 'has', 'been'): {'baby': 0.25,
#   'model': 0.25,
#   'printer': 0.25,
#   'product': 0.25},
#  ('you', 'are', 'for', 'a'): {'looking': 0.75, 'shopping': 0.25},
#  ('appointments', ',', ',', 'and'): {'dates': 0.5, 'tasks': 0.5},
#  ('i', 'am', 'with', 'my'): {'happy': 0.5, 'working': 0.5},
#  ('is', 'so', '.', 'i'): {'great': 0.3333333333333333,
#   'portable': 0.3333333333333333,
#   'reliable': 0.3333333333333333},
#  ('like', 'the', 'that', 'you'): {'fact': 0.5, 'option': 0.5},
#  ('not', 'as', 'as', 'the'): {'bloated': 0.3333333333333333,
#   'good': 0.6666666666666666},
#  ('need', 'to', 'up', 'the'): {'crank': 0.5, 'turn': 0.5},
#  ('headphones', ',', 'are', 'more'): {'some': 0.5, 'you': 0.5},
#  ('and', 'for', 'price', ','): {'that': 0.5, 'the': 0.5},
#  ('for', 'that', ',', 'i'): {'matter': 0.5, 'price': 0.5},
#  ('i', 'have', 'had', 'a'): {"n't": 0.6666666666666666,
#   'never': 0.3333333333333333},
#  ('i', 'have', '.', 'the'): {'had': 0.5, 'purchased': 0.5},
#  ('.', 'all', 'need', 'is'): {'i': 0.5, 'you': 0.5},
#  ('.', 'you', 'to', 'get'): {'have': 0.5, 'need': 0.5},
#  ('.', 'it', 'small', 'and'): {"'s": 0.5, 'is': 0.5},
#  ('.', 'you', 'feel', 'it'): {'barely': 0.5, 'can': 0.5},
#  ('the', 'old', '.', 'the'): {'one': 0.5, 'ones': 0.5},
#  ('the', 'same', 'as', 'the'): {'experience': 0.5, 'price': 0.5},
#  ('.', 'works', 'with', 'my'): {'beautifully': 0.5, 'great': 0.5},
#  ('i', 'first', 'this', 'little'): {'heard': 0.5, 'purchased': 0.5},
#  ('not', 'only', ',', 'but'): {'comfortable': 0.3333333333333333,
#   'invaluable': 0.3333333333333333,
#   'noise-cancelling': 0.3333333333333333},
#  (',', 'but', 'very', 'good'): {'a': 0.5, 'still': 0.5},
#  ('.', 'i', "n't", 'need'): {'did': 0.4, 'do': 0.6},
#  ('a', 'little', ',', 'but'): {'bright': 0.14285714285714285,
#   'bulky': 0.14285714285714285,
#   'expensicve': 0.14285714285714285,
#   'loud': 0.14285714285714285,
#   'noisy': 0.14285714285714285,
#   'slow': 0.14285714285714285,
#   'work': 0.14285714285714285},
#  ('has', 'a', 'rubber', 'coating'): {'nice': 0.5, 'thick': 0.5},
#  (',', 'and', 'is', 'worth'): {'it': 0.5, 'overall': 0.5},
#  ('you', 'can', 'all', 'the'): {'hear': 0.5, 'print': 0.5},
#  ('the', 'best', 'i', 'ever'): {'headphones': 0.3333333333333333,
#   'purchase': 0.3333333333333333,
#   'webcam': 0.3333333333333333},
#  ('.', 'it', 'take', 'a'): {'does': 0.5, 'may': 0.5},
#  ('it', 'does', 'a', 'bit'): {'come': 0.3333333333333333,
#   'feel': 0.3333333333333333,
#   'take': 0.3333333333333333},
#  (',', 'you', 'have', 'to'): {'also': 0.5, 'definitely': 0.5},
#  ('for', 'that', 'it', 'was'): {',': 0.5, '--': 0.5},
#  ('recommend', 'this', '.', 'i'): {'cable': 0.3333333333333333,
#   'mouse': 0.6666666666666666},
#  ('my', 'other', '.', 'i'): {'electronics': 0.3333333333333333,
#   'laptop': 0.3333333333333333,
#   'remotes': 0.3333333333333333},
#  ('a', 'decent', 'of', 'headphones'): {'pair': 0.5, 'set': 0.5},
#  ('set', 'of', 'for', 'my'): {'headphones': 0.5, 'speakers': 0.5},
#  ('does', "n't", 'like', 'a'): {'sound': 0.6666666666666666,
#   'thump': 0.3333333333333333},
#  ('had', 'a', 'problem', 'with'): {'single': 0.6666666666666666,
#   'small': 0.3333333333333333},
#  ('.', 'we', 'used', 'it'): {"'ve": 0.3333333333333333,
#   'have': 0.6666666666666666},
#  ('in', 'the', 'as', 'well'): {'car': 0.5, 'future': 0.5},
#  ('.', 'i', 'also', 'used'): {"'ve": 0.5, 'have': 0.5},
#  ('i', "'ve", 'used', 'it'): {'also': 0.5, 'only': 0.5},
#  ('with', 'my', '.', 'i'): {'mp3': 0.4, 'purchase': 0.4, 'set-up': 0.2},
#  ('.', 'i', 'used', 'them'): {"'ve": 0.5, 'have': 0.5},
#  ('of', 'the', ')', '.'): {'ends': 0.25,
#   'manual': 0.25,
#   'movie': 0.25,
#   'tv': 0.25},
#  ('.', 'it', 'all', 'the'): {'does': 0.5, 'has': 0.5},
#  ('and', 'i', 'the', 'fact'): {'like': 0.5, 'love': 0.5},
#  ('have', 'to', 'to', 'the'): {'refer': 0.5, 'run': 0.5},
#  ('with', 'this', ',', 'it'): {'package': 0.5, 'phone': 0.5},
#  ('i', 'have', '.', 'i'): {'...': 0.25,
#   'had': 0.25,
#   'used': 0.25,
#   'viewed': 0.25},
#  ('a', 'bit', ',', 'and'): {'flimsy': 0.5, 'loud': 0.5},
#  ('on', 'the', 'hand', ','): {'one': 0.3333333333333333,
#   'other': 0.6666666666666666},
#  ('is', 'a', 'loud', ','): {'bit': 0.5, 'little': 0.5},
#  ('satisfied', 'with', 'product', '.'): {'the': 0.5, 'this': 0.5},
#  ('the', 'past', 'years', '.'): {'3': 0.5, 'couple': 0.5},
#  ('.', 'the', 'on', 'the'): {'cushioning': 0.3333333333333333,
#   'price': 0.3333333333333333,
#   'resolution': 0.3333333333333333},
#  ('a', 'big', '.', 'the'): {'deal': 0.3333333333333333,
#   'difference': 0.6666666666666666},
#  ('it', "'s", 'to', 'be'): {'going': 0.25, 'something': 0.25, 'supposed': 0.5},
#  ('.', 'the', 'is', 'also'): {'bluetooth': 0.25,
#   'cable': 0.25,
#   'phone': 0.25,
#   'picturemate': 0.25},
#  (',', 'the', "'s", 'are'): {'eb': 0.5, 'pro-4aa': 0.25, 'ur-20': 0.25},
#  ('the', 'most', 'of', 'the'): {'capable': 0.5, 'comfortable': 0.5},
#  ('the', 'most', ',', 'and'): {'durable': 0.5, 'important': 0.5},
#  ('i', 'recently', 'these', 'speakers'): {'bought': 0.5, 'purchased': 0.5},
#  ('i', 'also', 'a', 'logitech'): {'have': 0.5, 'tried': 0.5},
#  ('it', 'is', 'worth', 'it'): {'definitely': 0.5, 'not': 0.5},
#  ('the', 'accuracy', 'the', 'receipt'): {'of': 0.5, 'on': 0.5},
#  (',', 'i', 'wanted', 'to'): {'just': 0.5, 'still': 0.5},
#  ('out', 'for', '.', 'i'): {'it': 0.5, 'myself': 0.5},
#  ('.', 'it', 'the', 'best'): {'does': 0.5, 'is': 0.5},
#  ('to', 'the', 'version', '.'): {'lastest': 0.5, 'monster': 0.5},
#  (',', 'as', 'of', 'the'): {'any': 0.5, 'some': 0.5},
#  ('on', 'the', '.', 'the'): {'desk': 0.14285714285714285,
#   'ear': 0.14285714285714285,
#   'mouse': 0.14285714285714285,
#   'network': 0.14285714285714285,
#   'screen': 0.14285714285714285,
#   'wall': 0.14285714285714285,
#   'weekends': 0.14285714285714285},
#  ('reason', 'i', 'not', 'give'): {'did': 0.6666666666666666,
#   'would': 0.3333333333333333},
#  ('i', 'did', 'give', 'it'): {"n't": 0.5, 'not': 0.5},
#  ('not', 'give', '5', 'stars'): {'it': 0.3333333333333333,
#   'them': 0.3333333333333333,
#   'this': 0.3333333333333333},
#  ('of', 'the', 'of', 'the'): {'back': 0.5, 'size': 0.5},
#  ('there', 'was', 'option', 'for'): {'an': 0.5, 'the': 0.5},
#  ('is', 'a', 'to', 'use'): {'must': 0.5, 'pleasure': 0.5},
#  ('with', 'the', 'of', 'the'): {'ability': 0.14285714285714285,
#   'comfort': 0.14285714285714285,
#   'design': 0.14285714285714285,
#   'exception': 0.14285714285714285,
#   'mechanics': 0.14285714285714285,
#   'quality': 0.14285714285714285,
#   'top': 0.14285714285714285},
#  ('it', 'three', 'ago', '.'): {'months': 0.3333333333333333,
#   'weeks': 0.6666666666666666},
#  ("'s", 'a', 'of', 'the'): {'list': 0.5, 'picture': 0.5},
#  ('when', 'the', 'is', 'off'): {'car': 0.3333333333333333,
#   'electricity': 0.3333333333333333,
#   'unit': 0.3333333333333333},
#  ('that', 'i', "n't", 'like'): {'did': 0.5, 'do': 0.5},
#  ('is', 'a', 'as', 'well'): {'must': 0.5, 'plus': 0.5},
#  ('and', 'you', 'need', 'to'): {'really': 0.5, 'will': 0.5},
#  ('.', 'the', 'is', 'the'): {'bass': 0.3333333333333333,
#   'burner': 0.3333333333333333,
#   'cobra': 0.3333333333333333},
#  ('in', 'the', 'department', '.'): {'comfort': 0.5, 'quality': 0.5},
#  ('i', 'am', 'to', 'find'): {'able': 0.5, 'yet': 0.5},
#  ('the', 'sound', 'is', 'so'): {'isolation': 0.5, 'quality': 0.5},
#  (',', 'so', 'do', "n't"): {'i': 0.6666666666666666,
#   'you': 0.3333333333333333},
#  ('like', 'this', '.', 'it'): {'mouse': 0.3333333333333333,
#   'phone': 0.3333333333333333,
#   'unit': 0.3333333333333333},
#  ('very', 'good', 'i', "'m"): {',': 0.5, ';': 0.5},
#  (',', 'i', 'recommend', 'this'): {"'d": 0.3333333333333333,
#   'can': 0.3333333333333333,
#   'highly': 0.3333333333333333},
#  ('.', 'i', "n't", 'wait'): {'ca': 0.5, 'could': 0.5},
#  ('but', 'the', 'is', 'so'): {'samsung': 0.5, 'silicone': 0.5},
#  ('and', 'the', 'is', 'easy'): {'folding': 0.3333333333333333,
#   'remote': 0.3333333333333333,
#   'software': 0.3333333333333333},
#  ('my', 'only', 'is', 'the'): {'hesitation': 0.5, 'problem': 0.5},
#  ('for', 'my', ',', 'i'): {'purposes': 0.5, 'wife': 0.5},
#  (',', 'i', 'like', 'to'): {"'d": 0.5, 'would': 0.5},
#  ('and', 'i', 'love', 'it'): {'absolutely': 0.5, 'just': 0.5},
#  ('and', 'the', 'is', 'so'): {'color': 0.5, 'treble': 0.5},
#  (',', 'and', 'it', "'s"): {'does': 0.5, 'now': 0.5},
#  ('so', 'many', 'features', ','): {'great': 0.5, 'more': 0.5},
#  ('when', 'i', 'it', 'and'): {'got': 0.5, 'hear': 0.5},
#  ('you', 'can', '.', 'i'): {'get': 0.5, 'use': 0.5},
#  ('you', 'can', 'it', 'with'): {'do': 0.5, 'use': 0.5},
#  (',', 'but', 'it', "'s"): {'frankly': 0.5, 'now': 0.5},
#  ('(', 'or', ')', 'a'): {'use': 0.5, 'want': 0.5},
#  ('speakers', 'are', 'for', 'the'): {'awesome': 0.5, 'great': 0.5},
#  ('.', 'i', 'these', 'for'): {'bought': 0.5, 'purchased': 0.5},
# ...
#   'prefer': 0.3333333333333333,
#   'want': 0.3333333333333333},
#  ('when', 'i', 'in', 'the'): {"'m": 0.25,
#   'wanted': 0.25,
#   'was': 0.25,
#   'work': 0.25},
#  ('in', 'the', '.', 'it'): {'back': 0.16666666666666666,
#   'case': 0.16666666666666666,
#   'dark': 0.16666666666666666,
#   'house': 0.16666666666666666,
#   'song': 0.3333333333333333},
#  ('.', 'it', 'well', ','): {'protects': 0.5, 'works': 0.5},
#  ('it', 'works', ',', 'and'): {'great': 0.5, 'well': 0.5},
#  ('of', 'the', '.', 'this'): {'box': 0.3333333333333333,
#   'unit': 0.3333333333333333,
#   'way': 0.3333333333333333},
#  ('not', 'as', 'as', 'i'): {'good': 0.5, 'picky': 0.5},
#  ('i', 'have', 'used', 'it'): {'also': 0.5, "n't": 0.25, 'never': 0.25},
#  ('a', 'good', ',', 'and'): {'copy': 0.5, 'price': 0.5},
#  (',', 'but', 'have', 'to'): {'i': 0.25, 'you': 0.75},
#  ('to', 'watch', 'on', 'a'): {'movies': 0.5, 'video': 0.5},
#  ('of', 'the', 'are', 'in'): {'holes': 0.5, 'ports': 0.5},
#  ('.', 'the', 'thing', 'is'): {'only': 0.5, 'other': 0.5},
#  ('that', 'the', 'does', 'not'): {'unit': 0.5, 'xr55': 0.5},
#  ('.', 'i', 'not', 'like'): {'did': 0.6666666666666666,
#   'do': 0.3333333333333333},
#  ('i', 'did', 'like', 'the'): {"n't": 0.3333333333333333,
#   'not': 0.6666666666666666},
#  ('!', 'i', 'the', 'fact'): {'like': 0.5, 'love': 0.5},
#  ('the', 'dock', '.', 'i'): {')': 0.5, 'connector': 0.5},
#  ('want', 'to', 'through', 'the'): {'flip': 0.3333333333333333,
#   'listen': 0.6666666666666666},
#  ('.', 'the', 'had', 'a'): {'belkin': 0.5, 'screen': 0.5},
#  ('but', 'i', 'that', 'i'): {'feel': 0.5, 'find': 0.5},
#  ('i', 'am', 'glad', 'i'): {'quite': 0.3333333333333333,
#   'really': 0.3333333333333333,
#   'thoroughly': 0.3333333333333333},
#  ('.', 'i', 'this', 'product'): {'buy': 0.3333333333333333,
#   'reccomend': 0.3333333333333333,
#   'recommend': 0.3333333333333333},
#  ('in', 'my', ',', 'and'): {'bag': 0.5, 'printer': 0.5},
#  ('i', 'can', 'that', 'the'): {'imagine': 0.5, 'say': 0.5},
#  ('this', 'thing', 'great', '.'): {'is': 0.5, 'works': 0.5},
#  ('you', 'can', 'your', 'ipod'): {'control': 0.5, 'use': 0.5},
#  ('i', 'had', 'bought', 'a'): {"n't": 0.5, 'originally': 0.5},
#  ('was', 'a', '.', 'i'): {'consideration': 0.5, 'joke': 0.5},
#  ('and', 'it', 'great', '.'): {'is': 0.5, 'worked': 0.5},
#  ('all', 'the', 'of', 'the'): {'features': 0.5, 'inconsistencies': 0.5},
#  (')', ',', 'it', "'s"): {'and': 0.6666666666666666,
#   'but': 0.3333333333333333},
#  ('.', 'i', 'it', 'might'): {'think': 0.3333333333333333,
#   'thought': 0.6666666666666666},
#  ('great', ',', 'it', 'does'): {'and': 0.6666666666666666,
#   'but': 0.3333333333333333},
#  ('and', 'this', 'the', 'best'): {'are': 0.5, 'is': 0.5},
#  ('light', ',', ',', 'and'): {'confortable': 0.5, 'siren': 0.5},
#  ('that', 'the', 'is', 'a'): {'bass': 0.5, 'sound': 0.5},
#  ('the', 'best', 'i', 'have'): {'.': 0.16666666666666666,
#   'device': 0.16666666666666666,
#   'mic': 0.16666666666666666,
#   'mouse': 0.16666666666666666,
#   'phones': 0.16666666666666666,
#   'speakers': 0.16666666666666666},
#  ('not', 'the', '.', 'i'): {'best': 0.5, 'worst': 0.5},
#  ('with', 'the', 'is', 'a'): {'samson': 0.5, 'speakers': 0.5},
#  ('.', 'i', 'needed', 'a'): {'also': 0.5, 'really': 0.5},
#  (',', 'i', 'have', 'to'): {'do': 0.25, 'probably': 0.25, 'would': 0.5},
#  ('and', 'the', 'is', 'great'): {'reception': 0.3333333333333333,
#   'sound': 0.6666666666666666},
#  ('they', 'are', 'comfortable', 'and'): {'super': 0.5, 'very': 0.5},
#  ('.', 'i', 'a', 'couple'): {'had': 0.3333333333333333,
#   'have': 0.3333333333333333,
#   'transferred': 0.3333333333333333},
#  ('you', 'turn', 'the', 'player'): {'off': 0.5, 'on': 0.5},
#  ('.', 'the', 'feature', 'is'): {'best': 0.6666666666666666,
#   'folding': 0.3333333333333333},
#  ('the', 'best', 'is', 'the'): {'feature': 0.3333333333333333,
#   'features': 0.3333333333333333,
#   'part': 0.3333333333333333},
#  ('is', 'the', '.', 'i'): {'price': 0.5, 'remote': 0.5},
#  ('what', 'i', 'it', 'to'): {'need': 0.5, 'want': 0.5},
#  ('so', 'i', 'this', 'one'): {'chose': 0.5, 'got': 0.5},
#  ('with', 'a', 'megapixel', 'camera'): {'2': 0.2,
#   '3': 0.2,
#   '4': 0.2,
#   '5': 0.2,
#   '6': 0.2},
#  ('camera', ',', 'images', 'when'): {'106': 0.5, '51': 0.5},
#  (',', 'this', 'will', 'be'): {'card': 0.3333333333333333,
#   'contract': 0.6666666666666666},
#  ('.', 'i', "n't", 'get'): {'ca': 0.3333333333333333,
#   'did': 0.6666666666666666},
#  ('have', 'had', 'for', 'a'): {'mine': 0.5, 'the': 0.5},
#  ('in', 'the', '.', 'i'): {'boonies': 0.3333333333333333,
#   'list': 0.3333333333333333,
#   'phone': 0.3333333333333333},
#  ('i', 'am', 'by', 'the'): {'amazed': 0.3333333333333333,
#   'impressed': 0.3333333333333333,
#   'satisfied': 0.3333333333333333},
#  ('where', 'i', '.', 'i'): {'am': 0.5, 'live': 0.5},
#  ('of', 'the', 'is', 'not'): {'database': 0.5, 'tv': 0.5},
#  ('it', 'is', 'and', 'the'): {'comfortable': 0.5, 'new': 0.5},
#  (',', 'and', 'to', 'the'): {'connects': 0.5, 'contrary': 0.5},
#  ('and', 'a', 'fit', '.'): {'comfortable': 0.5, 'perfect': 0.5},
#  ('from', 'the', 'of', 'the'): {'convenience': 0.5, 'king': 0.5},
#  ('when', 'it', 'to', 'the'): {'comes': 0.5, 'switches': 0.5},
#  ('into', 'the', 'of', 'the'): {'side': 0.5, 'top': 0.5},
#  ('.', 'the', 'does', "n't"): {'ink': 0.3333333333333333,
#   'mouse': 0.3333333333333333,
#   'trackball': 0.3333333333333333},
#  ('and', 'you', 'have', 'to'): {"'ll": 0.3333333333333333,
#   'never': 0.3333333333333333,
#   'will': 0.3333333333333333},
#  ('you', 'will', 'to', 'get'): {'have': 0.5, 'need': 0.5},
#  ('break', 'the', 'one', '.'): {'current': 0.5, 'old': 0.5},
#  (',', 'i', 'it', 'as'): {'see': 0.5, 'use': 0.5},
#  ('weight', 'and', '.', 'i'): {'durable': 0.5, 'size': 0.5},
#  ('so', 'i', "n't", 'comment'): {'ca': 0.75, 'wo': 0.25},
#  ('.', 'the', 'would', 'be'): {'armband': 0.5, 'bracket': 0.5},
#  ('a', 'replacement', ',', 'but'): {'cap': 0.5, 'knob': 0.5},
#  ('listening', 'to', 'music', 'through'): {'loud': 0.5, 'your': 0.5},
#  ('on', 'the', ',', 'and'): {'price': 0.5, 'run': 0.5},
#  ('of', 'the', 'does', "n't"): {'album': 0.5, 'colors': 0.5},
#  ('.', 'when', 'listen', 'to'): {'i': 0.5, 'you': 0.5},
#  ('a', 'little', '.', 'but'): {')': 0.3333333333333333,
#   'thin': 0.3333333333333333,
#   'wierd': 0.3333333333333333},
#  ('if', 'you', 'to', 'save'): {'have': 0.3333333333333333,
#   'want': 0.6666666666666666},
#  ('into', 'the', '.', 'i'): {'c340': 0.5, 'unit': 0.5},
#  ('price', ',', 'ca', "n't"): {'i': 0.5, 'you': 0.5},
#  ('for', '$', 'to', '$'): {'800': 0.5, '90': 0.5},
#  ('on', 'the', 'from', 'the'): {'ipod': 0.5, 'pc': 0.5},
#  ('order', 'to', 'them', '.'): {'hear': 0.5, 'view': 0.5},
#  ('in', 'the', '.', 'if'): {'tunedok': 0.5, 'usb': 0.5},
#  ('to', 'tell', 'difference', 'between'): {'any': 0.5, 'the': 0.5},
#  ('when', 'i', 'listening', 'to'): {"'m": 0.6666666666666666,
#   'am': 0.3333333333333333},
#  ('to', 'be', 'to', 'use'): {'able': 0.6666666666666666,
#   'easy': 0.3333333333333333},
#  ('have', 'used', 'for', 'over'): {'it': 0.5, 'mine': 0.5},
#  ('.', 'the', 'part', 'about'): {'best': 0.5, 'nice': 0.5},
#  ('about', 'this', 'is', 'the'): {'keyboard': 0.5, 'mouse': 0.5},
#  ('.', 'the', 'comes', 'with'): {'modem': 0.5, 'mouse': 0.5},
#  ('.', 'do', 'and', 'you'): {'that': 0.5, 'this': 0.5},
#  ('a', 'great', '.', 'i'): {'alternative': 0.25,
#   'option': 0.25,
#   'phone': 0.25,
#   'printer': 0.25},
#  ('when', 'i', 'to', 'replace'): {'decided': 0.5, 'need': 0.5},
#  ('.', 'i', 'one', 'of'): {'bought': 0.5, 'got': 0.5},
#  (',', 'and', ',', 'but'): {'intec': 0.5, 'zune': 0.5},
#  ('-', 'better', 'than', 'the'): {'detail': 0.5, 'screen': 0.5},
#  ('a', 'good', '.', 'you'): {'picture': 0.5, 'seal': 0.5},
#  ('picture', '.', 'ca', "n't"): {'i': 0.5, 'you': 0.5},
#  ('you', 'do', 'have', 'a'): {"n't": 0.6666666666666666,
#   'not': 0.3333333333333333},
#  ('is', 'a', 'on', 'the'): {'little': 0.6666666666666666,
#   'stamp': 0.3333333333333333},
#  ('do', "n't", 'you', 'will'): {'then': 0.5, 'thonk': 0.5},
#  ('.', 'the', 'part', 'is'): {'best': 0.6666666666666666,
#   'speakerphone': 0.3333333333333333},
#  (',', 'the', 'from', 'the'): {'copy': 0.5, 'kick': 0.5},
#  ('decided', 'to', 'one', 'of'): {'buy': 0.5, 'try': 0.5},
#  ('i', 'was', 'for', 'something'): {'looking': 0.5, 'searching': 0.5},
#  ('if', 'you', 'to', 'connect'): {'plan': 0.5, 'wished': 0.5},
#  ('to', 'connect', 'to', 'the'): {'it': 0.5, 'them': 0.5},
#  ('on', 'the', ',', 'which'): {'belt': 0.5, 'left': 0.5},
#  ('.', 'i', 'the', '``'): {'chose': 0.5, 'prefer': 0.5},
#  ('in', 'the', 'and', 'it'): {'car': 0.3333333333333333,
#   'rain': 0.3333333333333333,
#   'yard': 0.3333333333333333},
#  ('as', 'you', '.', 'i'): {'need': 0.5, 'wish': 0.5},
#  ('on', 'my', 'table', '.'): {'computer': 0.5, 'tray': 0.5},
#  ('is', 'a', 'phone', '.'): {'great': 0.6666666666666666,
#   'terrific': 0.3333333333333333},
#  ('the', 'only', 'that', 'i'): {'complaint': 0.3333333333333333,
#   'phone': 0.3333333333333333,
#   'problem': 0.3333333333333333},
#  ('i', 'use', '.', 'i'): {'it': 0.5, 'now': 0.5},
#  ('if', 'you', 'looking', 'to'): {"'re": 0.6666666666666666,
#   'are': 0.3333333333333333},
#  ('satisfied', 'with', 'purchase', '.'): {'our': 0.5, 'this': 0.5},
#  ('and', 'very', 'to', 'use'): {'easy': 0.5, 'simple': 0.5},
#  ('in', 'the', ',', 'i'): {'meanwhile': 0.5, 'store': 0.5},
#  ('should', 'know', 'it', "'s"): {'about': 0.5, 'that': 0.5},
#  ('this', 'product', 'because', 'it'): {',': 0.5, '5stars': 0.5},
#  ('what', 'it', 'supposed', 'to'): {'is': 0.5, 'was': 0.5},
#  ('across', 'the', ',', 'but'): {'board': 0.5, 'room': 0.5},
#  ('.', 'in', 'case', ','): {'any': 0.6666666666666666,
#   'this': 0.3333333333333333},
#  ('.', 'the', 'themselves', 'are'): {'cables': 0.6666666666666666,
#   'wires': 0.3333333333333333},
#  ('when', 'i', 'them', '.'): {'bought': 0.5, 'use': 0.5},
#  ('i', 'was', 'happy', 'with'): {'rather': 0.5, 'so': 0.5},
#  ('with', 'my', '.', 'the'): {'camera': 0.5, 'choice': 0.5},
#  ('pleased', 'with', '.', 'the'): {'it': 0.5, 'them': 0.5},
#  ('.', 'i', 'bought', 'it'): {'initially': 0.5, 'only': 0.5},
#  ('i', 'do', 'like', 'the'): {"n't": 0.5, 'not': 0.5},
#  ('without', 'a', '.', 'i'): {'flicker': 0.5, 'problem': 0.5},
#  (',', 'it', 'a', 'great'): {"'s": 0.8, 'is': 0.2},
#  ('.', 'the', 'is', 'quite'): {'headset': 0.5, 'remote': 0.5},
#  ('and', 'you', 'good', 'to'): {"'re": 0.5, 'are': 0.5},
#  ('since', 'i', 'it', '3'): {'bought': 0.6666666666666666,
#   'got': 0.3333333333333333},
#  ('.', 'the', 'range', 'is'): {'detection': 0.3333333333333333,
#   'middle': 0.3333333333333333,
#   'rf': 0.3333333333333333},
#  ('range', 'is', 'good', ','): {'really': 0.5, 'very': 0.5},
#  ('i', 'have', 'on', 'my'): {'experienced': 0.5, 'had': 0.5},
#  ('.', 'i', 'them', 'with'): {'use': 0.5, 'used': 0.5},
#  ('at', 'a', 'volume', '.'): {'higher': 0.5, 'lower': 0.5},
#  ('in', 'a', ',', 'it'): {'plane': 0.5, 'store': 0.5},
#  ('.', 'the', 'can', 'be'): {'7800gt': 0.5, 'kids': 0.5},
#  ('nvidia', 'geforce', 'ddl', 'agp'): {'6800gt': 0.5, '6800ultra': 0.5},
#  ('nvidia', 'geforce', 'pci', 'express'): {'6600': 0.5, '7800gt': 0.5},
#  ('nvidia', 'quadrofx', 'nvidia', 'quadrofx'): {'2000': 0.16666666666666666,
#   '3000': 0.16666666666666666,
#   '3400': 0.16666666666666666,
#   '3450': 0.16666666666666666,
#   '4000': 0.16666666666666666,
#   '4400': 0.16666666666666666},
#  ('nvidia', 'geforce', 'nvidia', 'geforce'): {'7800gt': 0.5, '7800gtx': 0.5},
#  (',', 'the', 'is', 'in'): {'picture': 0.5, 'sensor': 0.5},
#  ('my', 'old', '.', 'i'): {'sandisk': 0.5, 'system': 0.5},
#  ('at', 'the', 'of', 'the'): {'beginning': 0.3333333333333333,
#   'end': 0.3333333333333333,
#   'top': 0.3333333333333333},
#  ('this', 'is', 'first', 'mp3'): {'my': 0.5, 'the': 0.5},
#  ('i', "'m", 'glad', 'i'): {'so': 0.5, 'very': 0.5},
#  ('glad', 'i', 'it', '.'): {'bought': 0.5, 'have': 0.5},
#  ('.', 'my', 'problem', 'is'): {'biggest': 0.5, 'only': 0.5},
#  ('anyone', 'who', 'looking', 'for'): {"'s": 0.5, 'is': 0.5},
#  ('on', 'this', '.', 'i'): {'mouse': 0.5, 'one': 0.5},
#  ('and', 'i', "n't", 'want'): {'did': 0.5, 'do': 0.5},
#  ('is', 'the', 'for', 'you'): {'camera': 0.3333333333333333,
#   'number': 0.3333333333333333,
#   'product': 0.3333333333333333},
#  ('the', 'gps', '.', 'this'): {'activated': 0.5, 'satellites': 0.5},
#  ('i', 'have', 'this', 'for'): {'done': 0.5, 'had': 0.5},
#  ('you', 'can', 'the', 'same'): {'do': 0.5, 'get': 0.5},
#  ('.', 'i', 'this', 'unit'): {'found': 0.5, 'give': 0.5},
#  ('do', "n't", 'it', '.'): {'cut': 0.5, 'fix': 0.5},
#  ('and', 'i', 'say', 'that'): {"'d": 0.5, 'can': 0.5},
#  ('for', 'your', '.', 'i'): {'body': 0.3333333333333333,
#   'buck': 0.3333333333333333,
#   'ipod': 0.3333333333333333},
#  ('of', 'the', 'price', '.'): {'purchase': 0.5, 'street': 0.5},
#  ('i', 'have', 'used', 'the'): {"n't": 0.6666666666666666,
#   'never': 0.3333333333333333},
#  ('spend', '$', 'on', 'a'): {'500': 0.5, '80': 0.5},
#  ('give', 'the', '5', 'stars'): {'product': 0.5, 'roady': 0.5},
#  ('5', 'stars', 'that', 'the'): {'is': 0.5, 'was': 0.5},
#  ('see', 'page', 'of', 'the'): {'76': 0.5, '77': 0.5},
#  ('of', 'the', "'s", 'manual'): {'owner': 0.5, 'user': 0.5},
#  ('dolby', '5.1', 'dts', 'tracks'): {'and/or': 0.5, 'or': 0.5},
#  ('.', 'my', 'complaint', 'with'): {'main': 0.5, 'only': 0.5},
#  ('this', 'printer', 'and', 'the'): {',': 0.5, '--': 0.5},
#  (',', 'the', 'is', 'a'): {'1280': 0.5, 'isqueez': 0.5},
#  ('.', 'the', 'is', 'not'): {'design': 0.25,
#   'menu': 0.25,
#   'sound': 0.25,
#   'unit': 0.25},
#  ('the', 'sound', ',', 'and'): {'directly': 0.5, 'is': 0.5},
#  ('takes', 'a', 'time', 'to'): {'little': 0.3333333333333333,
#   'long': 0.6666666666666666},
#  (',', 'and', '.', 'you'): {'bass': 0.3333333333333333,
#   'bingo': 0.3333333333333333,
#   'strong': 0.3333333333333333},
#  ('highly', 'recommend', 'to', 'anyone'): {'them': 0.5, 'these': 0.5},
#  (',', 'and', 'the', 'price'): {'considering': 0.5, 'for': 0.5},
#  (')', '.', ',', 'this'): {'also': 0.3333333333333333,
#   'anyways': 0.3333333333333333,
#   'first': 0.3333333333333333},
#  ('are', 'a', 'difficult', 'to'): {'bit': 0.5, 'little': 0.5},
#  ('with', 'a', 'cable', ','): {'dvi': 0.5, 'usb': 0.5},
#  ('for', 'color', '.', 'however'): {')': 0.5, 'ipods': 0.5},
#  ('is', 'the', 'way', 'to'): {'best': 0.5, 'only': 0.5},
#  ('my', 'only', 'complaint', 'is'): {'minor': 0.5, 'possible': 0.5},
#  ('you', 'know', 'you', 'are'): {'what': 0.5, 'who': 0.5},
#  ('i', 'have', 'it', 'to'): {'shown': 0.5, 'taken': 0.5},
#  ('and', 'they', 'to', 'work'): {'appear': 0.5, 'seem': 0.5},
#  ('and', 'the', 'on', 'the'): {'icing': 0.5, 'people': 0.5},
#  ('gone', 'through', 'lot', 'of'): {'a': 0.5, 'the': 0.5},
#  ('for', 'about', 'years', '.'): {'3': 0.5, 'six': 0.5},
#  ('.', 'i', 'hooked', 'them'): {'first': 0.5, 'then': 0.5},
#  ('it', 'is', 'and', 'it'): {'fast': 0.5, 'open': 0.5},
#  ('that', 'are', 'mentioned', 'in'): {"n't": 0.5, 'not': 0.5},
#  ("n't", 'quite', 'enough', ','): {'granular': 0.5, 'large': 0.5},
#  ('all', 'the', 'on', 'the'): {'force': 0.5, 'way': 0.5},
#  ('on', 'the', 'at', 'the'): {'disk': 0.5, 'usb': 0.5},
#  ('you', "'ve", 'had', 'a'): {'ever': 0.5, 'never': 0.5},
#  ('easier', 'to', 'than', 'the'): {'distinguish': 0.5, 'use': 0.5},
#  ('i', 'am', 'satisfied', 'with'): {'extreamly': 0.5, 'very': 0.5},
#  ('.', 'it', 'small', ','): {"'s": 0.5, 'is': 0.5},
#  ('the', 'best', 'you', 'can'): {'lock': 0.5, 'printer': 0.5},
#  ('is', 'very', '.', 'we'): {'entertained': 0.5, 'good': 0.5},
#  (',', 'not', 'at', 'all'): {'bad': 0.5, 'true': 0.5},
#  ('music', 'quality', 'if', 'you'): {',': 0.5, '.': 0.5},
#  ('on', 'the', '.', 'my'): {'ipod': 0.5, 'top': 0.5},
#  (',', 'and', '.', 'they'): {'notebooks': 0.5, 'reliable': 0.5},
#  ('also', 'put', 'of', 'those'): {'one': 0.5, 'some': 0.5},
#  ('that', 'the', 'itself', 'is'): {'cup': 0.5, 'transmitter': 0.5},
#  ('you', 'might', 'to', 'consider'): {'wan': 0.5, 'want': 0.5},
#  ('that', 'the', 'does', "n't"): {'picture': 0.3333333333333333,
#   'tunedok': 0.3333333333333333,
#   'volume': 0.3333333333333333},
#  ('if', 'you', 'like', 'me'): {"'re": 0.5, 'are': 0.5},
#  ('i', 'purchased', 'for', 'my'): {'these': 0.5, 'this': 0.5},
#  ('in', 'the', 'and', 'am'): {'past': 0.5, 'states': 0.5},
#  ('need', 'a', 'of', 'storage'): {'lot': 0.5, 'ton': 0.5},
#  (',', 'and', 'that', 'the'): {'found': 0.5, 'notice': 0.5},
#  ...}

# %%
def random_sample(d):
  # 從字典隨機選出一個帶機率值的樣本，回傳累積機率值最大的字
  r = random.random()
  cumulative = 0
  for w, p in iteritems(d):
    cumulative += p 
    if r < cumulative:
      return w

# %%
def test_spinner():
  review= random.choice(positive_reviews)
  s = review.text.lower()
  print("Original:", s)
  tokens = nltk.tokenize.word_tokenize(s)
  for i in range(len(tokens) - 4):
    if random.random() < 0.2: # 20% chance of replacement
      k = (tokens[i], tokens[i + 1], tokens[i+3], tokens[i+4])
      if k in pentagram_probabilities:
        w = random_sample(pentagram_probabilities[k])
        tokens[i + 2] = w
  print("Spun:")
  print(" ".join(tokens).replace(" .", ".").replace(" '", "'").replace(" ,", ",").replace("$ ", "$").replace(" !", "!"))

if __name__ == '__main__':
  test_spinner()
# Out:
# Original:
# i have owned many sony cameras in the past and am currently using two right now. the only problem i have encountered with any digital camera is that when you think you have enough memory, you run out when you need it most. that is why i upgraded all of my cameras from 256 and 512 meg memory sticks to the sony 1 gig. actually i carry a spare 1 gig too where ever i go.
#
# look, when you take video with your digital camera or you use a high file size (3-6 megapixels) per picture, which you should always do to get the best possible prints made, your camera will need a ton of storage space.  especially if you are on vacation or encounter a great photo moment or maybe even something you hadn't expected like a wildfire, a plane crash, a bank robbery or maybe even a cat in the park having kittens. you can always "resize" you photos to a smaller size later when you save then to your computer if you want to save space. trust me, take large megapixel pics now and you will be amazed at how many shots came out better that you expected.
#
# you never know. i have tons of pictures that people ask how did i ever get such good pictures of such amazing things. i have a helicopter crash, police car up a power poll, deer in downtown oakland, house fire before the fire dept got there, tons of wild animals, any many more things i saw while i was driving somewhere or walking in a park. if you want great photos you have to be prepared when the moment arrives!
#
# matching a camera with its name brand memory is also a great idea. no problems ever!! the sony memory sticks i have from 5 to 6 years ago still work great with no problems. they make it fast and easy to transfer data from your camera to your computer. they are tiny wafer thin and extremely light weight and durable. i have first hand knowledge that products with the sony name on it are first rate and high quality. if you want quality buy sony
#
# Spun:
# i have owned many sony cameras in the past and am currently using two right now. the only problem i have encountered with any digital camera is that when you think you have enough memory, you run out when you need it most. that is why i upgraded all of my cameras from 256 and 512 meg memory sticks to the sony 1 gig. actually i carry a spare 1 gig too where ever i go. look, when you take video with your digital camera or you use a high file size ( 3-6 megapixels ) per picture, which you should always do to get the best possible prints made, your camera will need a lot of storage space. especially if you are on vacation or encounter a great photo moment or maybe even something you had n't expected like a wildfire, a plane crash, a bank robbery or maybe even a cat in the park having kittens. you can always `` resize'' you photos to a smaller size later when you save then to your computer if you want to save space. trust me, take large megapixel pics now and you will be amazed at how many shots came out better that you expected. you never know. i have tons of pictures that people ask how did i ever get such good pictures of such amazing things. i have a helicopter crash, police car up a power poll, deer in downtown oakland, house fire before the fire dept got there, tons of wild animals, any many more things i saw while i was driving somewhere or walking in a park. if you want great photos you have to be prepared when the moment arrives! matching a camera with its name brand memory is also a great idea. no problems ever!! the sony memory sticks i have from 5 to 6 years ago still work great with no problems. they make it fast and easy to transfer data from your camera to your computer. they are tiny wafer thin and extremely light weight and durable. i have first hand knowledge that products with the sony name on it are first rate and high quality. if you want quality buy sony
