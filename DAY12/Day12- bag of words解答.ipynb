# %% [markdown]
# ## 作業目標：搭建一個bag of words模型

# %% [markdown]
# ---

# %%
import pandas as pd
import nltk
#nltk.download()
import numpy as np
dataset=pd.read_csv('Restaurant_Reviews.tsv',delimiter='\t',quoting=3)
corpus=dataset['Review'].values

# %%
whole_words = []
for sentence in corpus:
    tokenized_sentence = nltk.word_tokenize(sentence)
    for word in tokenized_sentence:
        whole_words.append(word)

# %%
whole_words = set(whole_words)
print('共有{}個單字'.format(len(whole_words)))
# Out:
# 共有2356個單字

# %%
word_index = {}
index_word = {}
n = 0
for word in whole_words:
    word_index[word] = n 
    index_word[n] = word
    n+=1

# %%
word_index
# Out:
# {'IN': 0,
#  'guys': 1,
#  'unexperienced': 2,
#  'closed': 3,
#  'chicken': 4,
#  'qualified': 5,
#  'Really': 6,
#  'Long': 7,
#  'fellow': 8,
#  'BARGAIN': 9,
#  'flat-lined': 10,
#  'chocolate': 11,
#  'Tigerlilly': 12,
#  'need': 13,
#  'definately': 14,
#  'Disappointed': 15,
#  'warmer': 16,
#  'FREEZING': 17,
#  'nigiri': 18,
#  'golden-crispy': 19,
#  'gyros': 20,
#  'sad': 21,
#  'surprised': 22,
#  'ever': 23,
#  'choose': 24,
#  'entire': 25,
#  'Crystals': 26,
#  'Greek': 27,
#  'papers': 28,
#  'dripping': 29,
#  'enjoyable': 30,
#  'hungry': 31,
#  'Point': 32,
#  'Francisco': 33,
#  'bars': 34,
#  'empty': 35,
#  'boot': 36,
#  'bank': 37,
#  'quit': 38,
#  'bites': 39,
#  'Left': 40,
#  'By': 41,
#  'Please': 42,
#  'focused': 43,
#  'chefs': 44,
#  'nice': 45,
#  'waiting': 46,
#  'delightful': 47,
#  'management': 48,
#  'BBQ': 49,
#  'Aria': 50,
#  'year': 51,
#  'affordable': 52,
#  'naan': 53,
#  'sauces': 54,
#  'charming': 55,
#  'thru': 56,
#  'stepped': 57,
#  'croutons': 58,
#  'deliciously': 59,
#  'prime': 60,
#  'new': 61,
#  'strawberry': 62,
#  'but': 63,
#  'grandmother': 64,
#  'packed': 65,
#  'lacking': 66,
#  'LEGIT': 67,
#  'passed': 68,
#  'dried': 69,
#  'Mandalay': 70,
#  'salad': 71,
#  'portions': 72,
#  'fiancé': 73,
#  'pizzas': 74,
#  'extra': 75,
#  'now': 76,
#  'belly': 77,
#  'Heimer': 78,
#  'attack': 79,
#  'last': 80,
#  'Oh': 81,
#  'stuff': 82,
#  'setting': 83,
#  'Hopefully': 84,
#  'relleno': 85,
#  'PEOPLE': 86,
#  'REALLY': 87,
#  'grocery': 88,
#  'AVOID': 89,
#  'Crostini': 90,
#  'name': 91,
#  'WAY': 92,
#  'outstanding': 93,
#  'value': 94,
#  'leftover': 95,
#  'pork': 96,
#  'and': 97,
#  'mind': 98,
#  'literally': 99,
#  'count': 100,
#  'Salads': 101,
#  'atmosphere.1': 102,
#  'shocked': 103,
#  'breakfast': 104,
#  'Total': 105,
#  'wine': 106,
#  'Mmmm': 107,
#  'margaritas': 108,
#  'Outstanding': 109,
#  'pricing': 110,
#  'Ramsey': 111,
#  'average': 112,
#  'inspired': 113,
#  'What': 114,
#  'sporting': 115,
#  'brings': 116,
#  'he': 117,
#  'operation': 118,
#  'brunch': 119,
#  'grill': 120,
#  'brisket': 121,
#  'disappointing': 122,
#  'dipping': 123,
#  'salt': 124,
#  'pack': 125,
#  'completely': 126,
#  '15': 127,
#  'bad': 128,
#  'to': 129,
#  'Gold': 130,
#  'lot': 131,
#  'way': 132,
#  'winner': 133,
#  'cream': 134,
#  'Why': 135,
#  'turkey': 136,
#  'theft': 137,
#  'mom': 138,
#  'staff': 139,
#  'rubber': 140,
#  'Based': 141,
#  'BEST': 142,
#  'VERY': 143,
#  'Mirage': 144,
#  'part': 145,
#  'somethat': 146,
#  'with': 147,
#  'Overall': 148,
#  'hours': 149,
#  'got': 150,
#  'Paying': 151,
#  'such': 152,
#  'THAT': 153,
#  'Dessert': 154,
#  'vegan/veggie': 155,
#  'themselves': 156,
#  'latte': 157,
#  'summarize': 158,
#  "'m": 159,
#  'Honestly': 160,
#  'pepper..and': 161,
#  'underwhelming': 162,
#  'recent': 163,
#  'ripped': 164,
#  'cuisine': 165,
#  'An': 166,
#  'reviewing..': 167,
#  'bucks': 168,
#  'human': 169,
#  'military': 170,
#  'waiter': 171,
#  'covered': 172,
#  'this': 173,
#  'sushi': 174,
#  'about': 175,
#  '4': 176,
#  'Kind': 177,
#  'OWNERS': 178,
#  'best': 179,
#  'promptly': 180,
#  'Update': 181,
#  'say': 182,
#  'get': 183,
#  'thick': 184,
#  'first': 185,
#  'Despite': 186,
#  'plantains': 187,
#  'tartar': 188,
#  'trying': 189,
#  'Service': 190,
#  'pho': 191,
#  'said': 192,
#  'one': 193,
#  'violinists': 194,
#  'finish': 195,
#  'actual': 196,
#  'expect': 197,
#  'Big': 198,
#  'moist': 199,
#  'EXPERIENCE': 200,
#  'proclaimed': 201,
#  'servers': 202,
#  'blandest': 203,
#  'neither': 204,
#  '?': 205,
#  'ratio': 206,
#  'These': 207,
#  'cheek': 208,
#  'Ambience': 209,
#  'use': 210,
#  'common': 211,
#  '(': 212,
#  'buffet': 213,
#  'liking': 214,
#  'easily': 215,
#  'overwhelmed': 216,
#  'Maybe': 217,
#  'Mexican': 218,
#  'fail': 219,
#  'Ordered': 220,
#  'remember': 221,
#  'warm': 222,
#  'Edinburgh': 223,
#  'eating': 224,
#  'Hard': 225,
#  'dressed': 226,
#  'much': 227,
#  'whatsoever': 228,
#  'downside': 229,
#  'providing': 230,
#  'appalling': 231,
#  'Eew': 232,
#  'Then': 233,
#  'night': 234,
#  'ingredients': 235,
#  'Las': 236,
#  'tepid': 237,
#  'took': 238,
#  'saying': 239,
#  'business': 240,
#  'on': 241,
#  'impeccable': 242,
#  'live': 243,
#  'smelled': 244,
#  'watched': 245,
#  'orders': 246,
#  'scene': 247,
#  'smoothies': 248,
#  "'d": 249,
#  'Stars': 250,
#  'Buffet': 251,
#  'tummy': 252,
#  'lover': 253,
#  'authentic': 254,
#  'ladies': 255,
#  'unhealthy': 256,
#  'letdown': 257,
#  'falling': 258,
#  'dry': 259,
#  'served': 260,
#  'gooodd': 261,
#  'Bean': 262,
#  'capers': 263,
#  'Rock': 264,
#  'chef': 265,
#  'Fridays': 266,
#  'loudly': 267,
#  'Soggy': 268,
#  'getting': 269,
#  'crab': 270,
#  'tap': 271,
#  'rudely': 272,
#  'vinegrette': 273,
#  'decide': 274,
#  'Friend': 275,
#  'soooo': 276,
#  'provides': 277,
#  'caterpillar': 278,
#  'selections': 279,
#  'pay': 280,
#  'owners': 281,
#  'tell': 282,
#  'giving': 283,
#  'happened': 284,
#  'She': 285,
#  'Great': 286,
#  'pace': 287,
#  'via': 288,
#  'dollars': 289,
#  'Waited': 290,
#  'eel': 291,
#  'avoided': 292,
#  'doubt': 293,
#  'wave': 294,
#  'light': 295,
#  'cheated': 296,
#  'Khao': 297,
#  'busy': 298,
#  'Mushroom': 299,
#  'above': 300,
#  'chains': 301,
#  'unbelievably': 302,
#  'Caesar': 303,
#  'pile': 304,
#  'both': 305,
#  'sitting': 306,
#  'tongue': 307,
#  'court': 308,
#  'rich': 309,
#  'godfathers': 310,
#  'staying': 311,
#  'beef': 312,
#  'chickens': 313,
#  'rge': 314,
#  'saffron': 315,
#  'flavorful': 316,
#  'Also': 317,
#  'Yelpers': 318,
#  'NEVER': 319,
#  'are': 320,
#  'sticks': 321,
#  'Perhaps': 322,
#  'Mango': 323,
#  'hella': 324,
#  'blown': 325,
#  'single': 326,
#  'thats': 327,
#  'coconut': 328,
#  'past': 329,
#  'left': 330,
#  'fails': 331,
#  'sauce': 332,
#  'Delight': 333,
#  'complete': 334,
#  'they': 335,
#  'had': 336,
#  'desired': 337,
#  'slow': 338,
#  'blow': 339,
#  'WILL': 340,
#  'begin': 341,
#  'airline': 342,
#  'disaster': 343,
#  'shoots': 344,
#  'companions': 345,
#  '%': 346,
#  'Jamaican': 347,
#  'boy': 348,
#  'hummus': 349,
#  'INCONSIDERATE': 350,
#  'Wo': 351,
#  'your': 352,
#  'Magazine': 353,
#  'quantity': 354,
#  'generous': 355,
#  'lunch': 356,
#  'girlfriend': 357,
#  'manager': 358,
#  'ESTABLISHMENT': 359,
#  'quite': 360,
#  'rarely': 361,
#  'However': 362,
#  'ranch': 363,
#  'contain': 364,
#  'veal': 365,
#  'AND': 366,
#  'pop': 367,
#  'nicest': 368,
#  'AN': 369,
#  'NASTY': 370,
#  'ate': 371,
#  'flat': 372,
#  'imaginative': 373,
#  'saving': 374,
#  'awkward': 375,
#  "'": 376,
#  'customize': 377,
#  'pictures': 378,
#  'job': 379,
#  'OVERPRICED': 380,
#  'giant': 381,
#  'sat': 382,
#  'placed': 383,
#  'RUDE': 384,
#  'lady': 385,
#  'Waitress': 386,
#  'flirting': 387,
#  'judging': 388,
#  'Thus': 389,
#  'That': 390,
#  'classics': 391,
#  'hi': 392,
#  'suggest': 393,
#  'nothing': 394,
#  'noodles': 395,
#  ':': 396,
#  'bone': 397,
#  'Google': 398,
#  'peanut': 399,
#  'properly': 400,
#  'chow': 401,
#  'cocktails': 402,
#  'is': 403,
#  'person': 404,
#  'awkwardly': 405,
#  'ignore': 406,
#  'especially': 407,
#  'BACK': 408,
#  'pan': 409,
#  'hate': 410,
#  'shrimp': 411,
#  'butter': 412,
#  'efficient': 413,
#  'Yama': 414,
#  'their': 415,
#  'break': 416,
#  'Standard': 417,
#  'Pizza': 418,
#  'Prices': 419,
#  'yummy': 420,
#  'managed': 421,
#  'pancakes': 422,
#  'disgust': 423,
#  'smeared': 424,
#  'Panna': 425,
#  'Def': 426,
#  'pears': 427,
#  'living': 428,
#  'Sat': 429,
#  'tailored': 430,
#  'enjoy': 431,
#  'waste': 432,
#  'hankering': 433,
#  ')': 434,
#  'specials': 435,
#  'foods': 436,
#  'our': 437,
#  'bit': 438,
#  'Frenchman': 439,
#  'head': 440,
#  'flair': 441,
#  'Weird': 442,
#  'version': 443,
#  'Took': 444,
#  'Those': 445,
#  'cow': 446,
#  'indicate': 447,
#  'Rice': 448,
#  'customer': 449,
#  "'ll": 450,
#  'wall': 451,
#  'Firehouse': 452,
#  'tried': 453,
#  'letting': 454,
#  'Camelback': 455,
#  'seafood': 456,
#  'attentive': 457,
#  'tables': 458,
#  'dressing': 459,
#  'Tonight': 460,
#  'glass': 461,
#  'guy': 462,
#  'pita': 463,
#  'Plus': 464,
#  'restaraunt': 465,
#  'joint': 466,
#  'healthy': 467,
#  'bus': 468,
#  'Ha': 469,
#  'having': 470,
#  'Penne': 471,
#  'gas': 472,
#  'Vegas': 473,
#  'gristle': 474,
#  'anyone': 475,
#  'whole': 476,
#  'bill': 477,
#  'rancheros': 478,
#  'worst': 479,
#  'itself': 480,
#  'revisiting': 481,
#  'teeth': 482,
#  'Anyways': 483,
#  'party': 484,
#  'circumstances': 485,
#  'FLAVOR': 486,
#  'expanded': 487,
#  'oil': 488,
#  'southwest': 489,
#  'come': 490,
#  'even': 491,
#  'bye': 492,
#  'wife': 493,
#  'week': 494,
#  'biscuits': 495,
#  'meh': 496,
#  'perfection': 497,
#  'bartender': 498,
#  'added': 499,
#  'college': 500,
#  "'s": 501,
#  'To': 502,
#  'duo': 503,
#  'drink': 504,
#  'melt': 505,
#  'Damn': 506,
#  'non-fancy': 507,
#  'ALL': 508,
#  'Bellagio': 509,
#  'voted': 510,
#  'mouthful': 511,
#  'lost': 512,
#  'heart': 513,
#  'bring': 514,
#  'taste': 515,
#  'up': 516,
#  'equally': 517,
#  'Crema': 518,
#  'blue': 519,
#  'mess': 520,
#  '6': 521,
#  'tenders': 522,
#  'Dog': 523,
#  'course': 524,
#  'lil': 525,
#  'become': 526,
#  'Wow': 527,
#  'min': 528,
#  '-My': 529,
#  'stinks': 530,
#  'end': 531,
#  'mains': 532,
#  'dont': 533,
#  'rather': 534,
#  'Baba': 535,
#  'Delicious': 536,
#  'chewy': 537,
#  'tip': 538,
#  'ground': 539,
#  'A': 540,
#  'wanted': 541,
#  'FANTASTIC': 542,
#  'nutshell': 543,
#  'unique': 544,
#  'overpriced': 545,
#  'section': 546,
#  'into': 547,
#  'excellent': 548,
#  'struggle': 549,
#  'fo': 550,
#  'kids': 551,
#  'rare': 552,
#  'further': 553,
#  'wildly': 554,
#  'location': 555,
#  'dirty': 556,
#  'i': 557,
#  'spring': 558,
#  'nut': 559,
#  'screwed': 560,
#  'impressive': 561,
#  'pats': 562,
#  'bland': 563,
#  'oysters': 564,
#  'Up': 565,
#  'charcoal': 566,
#  'lacked': 567,
#  'pastas': 568,
#  'be': 569,
#  'bathrooms': 570,
#  '.the': 571,
#  'pink': 572,
#  'middle': 573,
#  'connoisseur': 574,
#  'deuchebaggery': 575,
#  'behind': 576,
#  'recommendation': 577,
#  'several': 578,
#  'Perfect': 579,
#  'may': 580,
#  'absolutley': 581,
#  'disgraceful': 582,
#  'outrageously': 583,
#  'incredible': 584,
#  'sucked': 585,
#  'Scottsdale': 586,
#  'attention': 587,
#  '35': 588,
#  'apologize': 589,
#  'Bad': 590,
#  'venturing': 591,
#  'Tasted': 592,
#  'fact': 593,
#  'poor': 594,
#  'man': 595,
#  'accomodate': 596,
#  'beautifully': 597,
#  'weekend': 598,
#  'ensued': 599,
#  'larger': 600,
#  'loving': 601,
#  'each': 602,
#  'curry': 603,
#  '2': 604,
#  'fat': 605,
#  'pumpkin': 606,
#  'next': 607,
#  'register': 608,
#  'HOUR': 609,
#  'Over': 610,
#  'MANAGEMENT': 611,
#  'forty': 612,
#  'strings': 613,
#  'presentation': 614,
#  '11.99': 615,
#  'spots': 616,
#  'mostly': 617,
#  'possible': 618,
#  'Their': 619,
#  'flavorless': 620,
#  'restaurant': 621,
#  'Christmas': 622,
#  'play': 623,
#  'par': 624,
#  'craving': 625,
#  'callings': 626,
#  'summary': 627,
#  'friends': 628,
#  'ice': 629,
#  'foot': 630,
#  'skimp': 631,
#  'treat': 632,
#  'peanuts': 633,
#  '.very': 634,
#  'delight': 635,
#  'Come': 636,
#  'chip': 637,
#  'amount': 638,
#  'TOLD': 639,
#  'watered': 640,
#  'Crust': 641,
#  'refrained': 642,
#  'music': 643,
#  'carbs': 644,
#  'totally': 645,
#  'smaller': 646,
#  'Host': 647,
#  'Elk': 648,
#  '..ohhh': 649,
#  'offered': 650,
#  'Overpriced': 651,
#  'included': 652,
#  'TIME': 653,
#  'probably': 654,
#  'cheese': 655,
#  'wound': 656,
#  'Pita': 657,
#  'cold': 658,
#  'understand': 659,
#  'yellowtail': 660,
#  'Fantastic': 661,
#  'too': 662,
#  'experienced': 663,
#  'Everything': 664,
#  '90': 665,
#  'Awesome': 666,
#  'going': 667,
#  'Restaurant': 668,
#  'bagels': 669,
#  'combos': 670,
#  'Company': 671,
#  'thanks': 672,
#  'Are': 673,
#  'ago': 674,
#  'haunt': 675,
#  'Steak': 676,
#  'Generous': 677,
#  'rowdy': 678,
#  'Bisque': 679,
#  'sure': 680,
#  'undercooked': 681,
#  ',': 682,
#  'polite': 683,
#  'over-whelm': 684,
#  'Cotta': 685,
#  'mall': 686,
#  'onion': 687,
#  'anticipated': 688,
#  'awful': 689,
#  'dinners': 690,
#  'roasted': 691,
#  'driest': 692,
#  '4.00': 693,
#  'nay': 694,
#  'Today': 695,
#  'Maria': 696,
#  'seriously': 697,
#  'appetizer': 698,
#  'exactly': 699,
#  'across': 700,
#  'OF': 701,
#  'events': 702,
#  'Steve': 703,
#  'yucky': 704,
#  'No': 705,
#  'Chinese': 706,
#  'occasions': 707,
#  'dog': 708,
#  'world': 709,
#  'Ample': 710,
#  'shoe': 711,
#  'stayed': 712,
#  'arrives': 713,
#  'jalapeno': 714,
#  'Buldogis': 715,
#  'imagine': 716,
#  'under-services': 717,
#  'sharply': 718,
#  'baby': 719,
#  'truffle': 720,
#  'HAPPENED': 721,
#  'showed': 722,
#  'English': 723,
#  'upgrading': 724,
#  'exquisite': 725,
#  'otherwise': 726,
#  'down': 727,
#  'joy': 728,
#  'Noca': 729,
#  'review': 730,
#  'delivery': 731,
#  'instantly': 732,
#  'disgusted': 733,
#  'MANY': 734,
#  'consistent': 735,
#  'Sooooo': 736,
#  '*': 737,
#  'After': 738,
#  'recommend': 739,
#  'experience': 740,
#  'day': 741,
#  'bug': 742,
#  'months': 743,
#  'Much': 744,
#  'boxes': 745,
#  'known': 746,
#  'oh': 747,
#  'after': 748,
#  'law': 749,
#  'Strip': 750,
#  'falafels': 751,
#  'disappointment': 752,
#  'correction': 753,
#  'since': 754,
#  'This': 755,
#  'sause': 756,
#  'like': 757,
#  'Ironman': 758,
#  'stay': 759,
#  'used': 760,
#  'ordered': 761,
#  'mixed': 762,
#  'walls': 763,
#  'show': 764,
#  'we': 765,
#  'round': 766,
#  'Plater': 767,
#  'disappoint': 768,
#  'mood': 769,
#  'greens': 770,
#  'Coffee': 771,
#  'hooked': 772,
#  'most': 773,
#  'Egg': 774,
#  'accident': 775,
#  'in': 776,
#  'driving': 777,
#  'GO': 778,
#  'dish': 779,
#  'sucks': 780,
#  'car': 781,
#  'perfectly': 782,
#  'grab': 783,
#  'satisfying': 784,
#  'blows': 785,
#  'sides': 786,
#  'why': 787,
#  'sandwich': 788,
#  'only': 789,
#  'actually': 790,
#  'work': 791,
#  'preparing': 792,
#  'Everyone': 793,
#  'climbing': 794,
#  'Hawaiian': 795,
#  'Magic': 796,
#  'fabulous': 797,
#  'stale': 798,
#  'multi-grain': 799,
#  'Reasonably': 800,
#  'liked': 801,
#  'gloves.Everything': 802,
#  'Will': 803,
#  'die': 804,
#  'eaten': 805,
#  'delicioso': 806,
#  'suggestions': 807,
#  'hated': 808,
#  'non-customer': 809,
#  'help': 810,
#  'solidify': 811,
#  'Owner': 812,
#  'My': 813,
#  'Cod': 814,
#  'grilled': 815,
#  'tolerance': 816,
#  'palate': 817,
#  'LOVED': 818,
#  'tasteless': 819,
#  'binge': 820,
#  'Horrible': 821,
#  'box': 822,
#  'for': 823,
#  'couple': 824,
#  'a': 825,
#  'patio': 826,
#  'establishment': 827,
#  'wagyu': 828,
#  '&': 829,
#  'ventilation': 830,
#  'beer': 831,
#  'Waiter': 832,
#  'industry': 833,
#  'whether': 834,
#  'tuna': 835,
#  'tea': 836,
#  'Pineapple': 837,
#  'generic': 838,
#  'wrong': 839,
#  'hospitality': 840,
#  'me..Bunch': 841,
#  'Disappointing': 842,
#  'short': 843,
#  'FS': 844,
#  'feels': 845,
#  'refill': 846,
#  'bunch': 847,
#  'lettuce': 848,
#  'Thai': 849,
#  'reduction': 850,
#  '8': 851,
#  'tartare': 852,
#  'poorly': 853,
#  'quickly': 854,
#  'something': 855,
#  'provided': 856,
#  'hereas': 857,
#  '-': 858,
#  'Shrimp-': 859,
#  'vodka': 860,
#  'CONCLUSION': 861,
#  'venue': 862,
#  '.THE': 863,
#  'choux': 864,
#  's': 865,
#  'assure': 866,
#  'coffee': 867,
#  '10+': 868,
#  'town': 869,
#  'ourselves': 870,
#  'pancake': 871,
#  'Italian': 872,
#  'mediocre': 873,
#  'Coming': 874,
#  'worries': 875,
#  'tiny': 876,
#  'sugary': 877,
#  'Thumbs': 878,
#  'under': 879,
#  'descriptions': 880,
#  'figured': 881,
#  'cocktail': 882,
#  'bellies': 883,
#  'sunglasses': 884,
#  'rings': 885,
#  'breaks': 886,
#  'brother': 887,
#  'NOT': 888,
#  'mayo': 889,
#  'Seafood': 890,
#  'mile': 891,
#  'what': 892,
#  'fuzzy': 893,
#  'am': 894,
#  'limited': 895,
#  'happier': 896,
#  'its': 897,
#  'effort': 898,
#  'seemed': 899,
#  'tater': 900,
#  'front': 901,
#  'ones': 902,
#  'wish': 903,
#  'big': 904,
#  'picture': 905,
#  'Japanese': 906,
#  'free': 907,
#  'fresh': 908,
#  'garlic': 909,
#  'awesome': 910,
#  'him': 911,
#  'puréed': 912,
#  'requested': 913,
#  'Your': 914,
#  'Smashburger': 915,
#  'crepe': 916,
#  '...': 917,
#  'garden': 918,
#  'fare': 919,
#  'drag': 920,
#  'handling': 921,
#  'delish': 922,
#  'cant': 923,
#  'Server': 924,
#  'One': 925,
#  'mein': 926,
#  'Flower': 927,
#  'been-stepped-in-and-tracked-everywhere': 928,
#  'crowds': 929,
#  'Nobu': 930,
#  'grow': 931,
#  'amazing': 932,
#  'years': 933,
#  'atmosphere': 934,
#  'ala': 935,
#  'dark': 936,
#  'the': 937,
#  '..went': 938,
#  'NO': 939,
#  'worth': 940,
#  'not': 941,
#  'continue': 942,
#  'shall': 943,
#  'postinos': 944,
#  'walked': 945,
#  'towards': 946,
#  'beat': 947,
#  'extremely': 948,
#  'taco': 949,
#  'deeply': 950,
#  'ribeye': 951,
#  'piece': 952,
#  'shower': 953,
#  'workers': 954,
#  'moz': 955,
#  'bodes': 956,
#  'drunk': 957,
#  'friendly': 958,
#  'was': 959,
#  'hot': 960,
#  'glance': 961,
#  'reading': 962,
#  'Filet': 963,
#  'water': 964,
#  'unwrapped': 965,
#  'Omelets': 966,
#  'rice': 967,
#  'number': 968,
#  'arriving': 969,
#  'performed': 970,
#  'bacon': 971,
#  'lukewarm': 972,
#  'Sprouts': 973,
#  'silently': 974,
#  'Be': 975,
#  'six': 976,
#  'writing': 977,
#  'mistake': 978,
#  'pale': 979,
#  'soooooo': 980,
#  'airport': 981,
#  'coupons': 982,
#  'bought': 983,
#  'she': 984,
#  'prepare': 985,
#  'case': 986,
#  'finally': 987,
#  'sense': 988,
#  'Breeze': 989,
#  'life': 990,
#  'heads': 991,
#  'huevos': 992,
#  '1': 993,
#  'unbelievable': 994,
#  'mary': 995,
#  'lovers': 996,
#  'Philadelphia': 997,
#  'imagined': 998,
#  'Denny': 999,
#  ...}

# %%
index_word
# Out:
# {0: 'IN',
#  1: 'guys',
#  2: 'unexperienced',
#  3: 'closed',
#  4: 'chicken',
#  5: 'qualified',
#  6: 'Really',
#  7: 'Long',
#  8: 'fellow',
#  9: 'BARGAIN',
#  10: 'flat-lined',
#  11: 'chocolate',
#  12: 'Tigerlilly',
#  13: 'need',
#  14: 'definately',
#  15: 'Disappointed',
#  16: 'warmer',
#  17: 'FREEZING',
#  18: 'nigiri',
#  19: 'golden-crispy',
#  20: 'gyros',
#  21: 'sad',
#  22: 'surprised',
#  23: 'ever',
#  24: 'choose',
#  25: 'entire',
#  26: 'Crystals',
#  27: 'Greek',
#  28: 'papers',
#  29: 'dripping',
#  30: 'enjoyable',
#  31: 'hungry',
#  32: 'Point',
#  33: 'Francisco',
#  34: 'bars',
#  35: 'empty',
#  36: 'boot',
#  37: 'bank',
#  38: 'quit',
#  39: 'bites',
#  40: 'Left',
#  41: 'By',
#  42: 'Please',
#  43: 'focused',
#  44: 'chefs',
#  45: 'nice',
#  46: 'waiting',
#  47: 'delightful',
#  48: 'management',
#  49: 'BBQ',
#  50: 'Aria',
#  51: 'year',
#  52: 'affordable',
#  53: 'naan',
#  54: 'sauces',
#  55: 'charming',
#  56: 'thru',
#  57: 'stepped',
#  58: 'croutons',
#  59: 'deliciously',
#  60: 'prime',
#  61: 'new',
#  62: 'strawberry',
#  63: 'but',
#  64: 'grandmother',
#  65: 'packed',
#  66: 'lacking',
#  67: 'LEGIT',
#  68: 'passed',
#  69: 'dried',
#  70: 'Mandalay',
#  71: 'salad',
#  72: 'portions',
#  73: 'fiancé',
#  74: 'pizzas',
#  75: 'extra',
#  76: 'now',
#  77: 'belly',
#  78: 'Heimer',
#  79: 'attack',
#  80: 'last',
#  81: 'Oh',
#  82: 'stuff',
#  83: 'setting',
#  84: 'Hopefully',
#  85: 'relleno',
#  86: 'PEOPLE',
#  87: 'REALLY',
#  88: 'grocery',
#  89: 'AVOID',
#  90: 'Crostini',
#  91: 'name',
#  92: 'WAY',
#  93: 'outstanding',
#  94: 'value',
#  95: 'leftover',
#  96: 'pork',
#  97: 'and',
#  98: 'mind',
#  99: 'literally',
#  100: 'count',
#  101: 'Salads',
#  102: 'atmosphere.1',
#  103: 'shocked',
#  104: 'breakfast',
#  105: 'Total',
#  106: 'wine',
#  107: 'Mmmm',
#  108: 'margaritas',
#  109: 'Outstanding',
#  110: 'pricing',
#  111: 'Ramsey',
#  112: 'average',
#  113: 'inspired',
#  114: 'What',
#  115: 'sporting',
#  116: 'brings',
#  117: 'he',
#  118: 'operation',
#  119: 'brunch',
#  120: 'grill',
#  121: 'brisket',
#  122: 'disappointing',
#  123: 'dipping',
#  124: 'salt',
#  125: 'pack',
#  126: 'completely',
#  127: '15',
#  128: 'bad',
#  129: 'to',
#  130: 'Gold',
#  131: 'lot',
#  132: 'way',
#  133: 'winner',
#  134: 'cream',
#  135: 'Why',
#  136: 'turkey',
#  137: 'theft',
#  138: 'mom',
#  139: 'staff',
#  140: 'rubber',
#  141: 'Based',
#  142: 'BEST',
#  143: 'VERY',
#  144: 'Mirage',
#  145: 'part',
#  146: 'somethat',
#  147: 'with',
#  148: 'Overall',
#  149: 'hours',
#  150: 'got',
#  151: 'Paying',
#  152: 'such',
#  153: 'THAT',
#  154: 'Dessert',
#  155: 'vegan/veggie',
#  156: 'themselves',
#  157: 'latte',
#  158: 'summarize',
#  159: "'m",
#  160: 'Honestly',
#  161: 'pepper..and',
#  162: 'underwhelming',
#  163: 'recent',
#  164: 'ripped',
#  165: 'cuisine',
#  166: 'An',
#  167: 'reviewing..',
#  168: 'bucks',
#  169: 'human',
#  170: 'military',
#  171: 'waiter',
#  172: 'covered',
#  173: 'this',
#  174: 'sushi',
#  175: 'about',
#  176: '4',
#  177: 'Kind',
#  178: 'OWNERS',
#  179: 'best',
#  180: 'promptly',
#  181: 'Update',
#  182: 'say',
#  183: 'get',
#  184: 'thick',
#  185: 'first',
#  186: 'Despite',
#  187: 'plantains',
#  188: 'tartar',
#  189: 'trying',
#  190: 'Service',
#  191: 'pho',
#  192: 'said',
#  193: 'one',
#  194: 'violinists',
#  195: 'finish',
#  196: 'actual',
#  197: 'expect',
#  198: 'Big',
#  199: 'moist',
#  200: 'EXPERIENCE',
#  201: 'proclaimed',
#  202: 'servers',
#  203: 'blandest',
#  204: 'neither',
#  205: '?',
#  206: 'ratio',
#  207: 'These',
#  208: 'cheek',
#  209: 'Ambience',
#  210: 'use',
#  211: 'common',
#  212: '(',
#  213: 'buffet',
#  214: 'liking',
#  215: 'easily',
#  216: 'overwhelmed',
#  217: 'Maybe',
#  218: 'Mexican',
#  219: 'fail',
#  220: 'Ordered',
#  221: 'remember',
#  222: 'warm',
#  223: 'Edinburgh',
#  224: 'eating',
#  225: 'Hard',
#  226: 'dressed',
#  227: 'much',
#  228: 'whatsoever',
#  229: 'downside',
#  230: 'providing',
#  231: 'appalling',
#  232: 'Eew',
#  233: 'Then',
#  234: 'night',
#  235: 'ingredients',
#  236: 'Las',
#  237: 'tepid',
#  238: 'took',
#  239: 'saying',
#  240: 'business',
#  241: 'on',
#  242: 'impeccable',
#  243: 'live',
#  244: 'smelled',
#  245: 'watched',
#  246: 'orders',
#  247: 'scene',
#  248: 'smoothies',
#  249: "'d",
#  250: 'Stars',
#  251: 'Buffet',
#  252: 'tummy',
#  253: 'lover',
#  254: 'authentic',
#  255: 'ladies',
#  256: 'unhealthy',
#  257: 'letdown',
#  258: 'falling',
#  259: 'dry',
#  260: 'served',
#  261: 'gooodd',
#  262: 'Bean',
#  263: 'capers',
#  264: 'Rock',
#  265: 'chef',
#  266: 'Fridays',
#  267: 'loudly',
#  268: 'Soggy',
#  269: 'getting',
#  270: 'crab',
#  271: 'tap',
#  272: 'rudely',
#  273: 'vinegrette',
#  274: 'decide',
#  275: 'Friend',
#  276: 'soooo',
#  277: 'provides',
#  278: 'caterpillar',
#  279: 'selections',
#  280: 'pay',
#  281: 'owners',
#  282: 'tell',
#  283: 'giving',
#  284: 'happened',
#  285: 'She',
#  286: 'Great',
#  287: 'pace',
#  288: 'via',
#  289: 'dollars',
#  290: 'Waited',
#  291: 'eel',
#  292: 'avoided',
#  293: 'doubt',
#  294: 'wave',
#  295: 'light',
#  296: 'cheated',
#  297: 'Khao',
#  298: 'busy',
#  299: 'Mushroom',
#  300: 'above',
#  301: 'chains',
#  302: 'unbelievably',
#  303: 'Caesar',
#  304: 'pile',
#  305: 'both',
#  306: 'sitting',
#  307: 'tongue',
#  308: 'court',
#  309: 'rich',
#  310: 'godfathers',
#  311: 'staying',
#  312: 'beef',
#  313: 'chickens',
#  314: 'rge',
#  315: 'saffron',
#  316: 'flavorful',
#  317: 'Also',
#  318: 'Yelpers',
#  319: 'NEVER',
#  320: 'are',
#  321: 'sticks',
#  322: 'Perhaps',
#  323: 'Mango',
#  324: 'hella',
#  325: 'blown',
#  326: 'single',
#  327: 'thats',
#  328: 'coconut',
#  329: 'past',
#  330: 'left',
#  331: 'fails',
#  332: 'sauce',
#  333: 'Delight',
#  334: 'complete',
#  335: 'they',
#  336: 'had',
#  337: 'desired',
#  338: 'slow',
#  339: 'blow',
#  340: 'WILL',
#  341: 'begin',
#  342: 'airline',
#  343: 'disaster',
#  344: 'shoots',
#  345: 'companions',
#  346: '%',
#  347: 'Jamaican',
#  348: 'boy',
#  349: 'hummus',
#  350: 'INCONSIDERATE',
#  351: 'Wo',
#  352: 'your',
#  353: 'Magazine',
#  354: 'quantity',
#  355: 'generous',
#  356: 'lunch',
#  357: 'girlfriend',
#  358: 'manager',
#  359: 'ESTABLISHMENT',
#  360: 'quite',
#  361: 'rarely',
#  362: 'However',
#  363: 'ranch',
#  364: 'contain',
#  365: 'veal',
#  366: 'AND',
#  367: 'pop',
#  368: 'nicest',
#  369: 'AN',
#  370: 'NASTY',
#  371: 'ate',
#  372: 'flat',
#  373: 'imaginative',
#  374: 'saving',
#  375: 'awkward',
#  376: "'",
#  377: 'customize',
#  378: 'pictures',
#  379: 'job',
#  380: 'OVERPRICED',
#  381: 'giant',
#  382: 'sat',
#  383: 'placed',
#  384: 'RUDE',
#  385: 'lady',
#  386: 'Waitress',
#  387: 'flirting',
#  388: 'judging',
#  389: 'Thus',
#  390: 'That',
#  391: 'classics',
#  392: 'hi',
#  393: 'suggest',
#  394: 'nothing',
#  395: 'noodles',
#  396: ':',
#  397: 'bone',
#  398: 'Google',
#  399: 'peanut',
#  400: 'properly',
#  401: 'chow',
#  402: 'cocktails',
#  403: 'is',
#  404: 'person',
#  405: 'awkwardly',
#  406: 'ignore',
#  407: 'especially',
#  408: 'BACK',
#  409: 'pan',
#  410: 'hate',
#  411: 'shrimp',
#  412: 'butter',
#  413: 'efficient',
#  414: 'Yama',
#  415: 'their',
#  416: 'break',
#  417: 'Standard',
#  418: 'Pizza',
#  419: 'Prices',
#  420: 'yummy',
#  421: 'managed',
#  422: 'pancakes',
#  423: 'disgust',
#  424: 'smeared',
#  425: 'Panna',
#  426: 'Def',
#  427: 'pears',
#  428: 'living',
#  429: 'Sat',
#  430: 'tailored',
#  431: 'enjoy',
#  432: 'waste',
#  433: 'hankering',
#  434: ')',
#  435: 'specials',
#  436: 'foods',
#  437: 'our',
#  438: 'bit',
#  439: 'Frenchman',
#  440: 'head',
#  441: 'flair',
#  442: 'Weird',
#  443: 'version',
#  444: 'Took',
#  445: 'Those',
#  446: 'cow',
#  447: 'indicate',
#  448: 'Rice',
#  449: 'customer',
#  450: "'ll",
#  451: 'wall',
#  452: 'Firehouse',
#  453: 'tried',
#  454: 'letting',
#  455: 'Camelback',
#  456: 'seafood',
#  457: 'attentive',
#  458: 'tables',
#  459: 'dressing',
#  460: 'Tonight',
#  461: 'glass',
#  462: 'guy',
#  463: 'pita',
#  464: 'Plus',
#  465: 'restaraunt',
#  466: 'joint',
#  467: 'healthy',
#  468: 'bus',
#  469: 'Ha',
#  470: 'having',
#  471: 'Penne',
#  472: 'gas',
#  473: 'Vegas',
#  474: 'gristle',
#  475: 'anyone',
#  476: 'whole',
#  477: 'bill',
#  478: 'rancheros',
#  479: 'worst',
#  480: 'itself',
#  481: 'revisiting',
#  482: 'teeth',
#  483: 'Anyways',
#  484: 'party',
#  485: 'circumstances',
#  486: 'FLAVOR',
#  487: 'expanded',
#  488: 'oil',
#  489: 'southwest',
#  490: 'come',
#  491: 'even',
#  492: 'bye',
#  493: 'wife',
#  494: 'week',
#  495: 'biscuits',
#  496: 'meh',
#  497: 'perfection',
#  498: 'bartender',
#  499: 'added',
#  500: 'college',
#  501: "'s",
#  502: 'To',
#  503: 'duo',
#  504: 'drink',
#  505: 'melt',
#  506: 'Damn',
#  507: 'non-fancy',
#  508: 'ALL',
#  509: 'Bellagio',
#  510: 'voted',
#  511: 'mouthful',
#  512: 'lost',
#  513: 'heart',
#  514: 'bring',
#  515: 'taste',
#  516: 'up',
#  517: 'equally',
#  518: 'Crema',
#  519: 'blue',
#  520: 'mess',
#  521: '6',
#  522: 'tenders',
#  523: 'Dog',
#  524: 'course',
#  525: 'lil',
#  526: 'become',
#  527: 'Wow',
#  528: 'min',
#  529: '-My',
#  530: 'stinks',
#  531: 'end',
#  532: 'mains',
#  533: 'dont',
#  534: 'rather',
#  535: 'Baba',
#  536: 'Delicious',
#  537: 'chewy',
#  538: 'tip',
#  539: 'ground',
#  540: 'A',
#  541: 'wanted',
#  542: 'FANTASTIC',
#  543: 'nutshell',
#  544: 'unique',
#  545: 'overpriced',
#  546: 'section',
#  547: 'into',
#  548: 'excellent',
#  549: 'struggle',
#  550: 'fo',
#  551: 'kids',
#  552: 'rare',
#  553: 'further',
#  554: 'wildly',
#  555: 'location',
#  556: 'dirty',
#  557: 'i',
#  558: 'spring',
#  559: 'nut',
#  560: 'screwed',
#  561: 'impressive',
#  562: 'pats',
#  563: 'bland',
#  564: 'oysters',
#  565: 'Up',
#  566: 'charcoal',
#  567: 'lacked',
#  568: 'pastas',
#  569: 'be',
#  570: 'bathrooms',
#  571: '.the',
#  572: 'pink',
#  573: 'middle',
#  574: 'connoisseur',
#  575: 'deuchebaggery',
#  576: 'behind',
#  577: 'recommendation',
#  578: 'several',
#  579: 'Perfect',
#  580: 'may',
#  581: 'absolutley',
#  582: 'disgraceful',
#  583: 'outrageously',
#  584: 'incredible',
#  585: 'sucked',
#  586: 'Scottsdale',
#  587: 'attention',
#  588: '35',
#  589: 'apologize',
#  590: 'Bad',
#  591: 'venturing',
#  592: 'Tasted',
#  593: 'fact',
#  594: 'poor',
#  595: 'man',
#  596: 'accomodate',
#  597: 'beautifully',
#  598: 'weekend',
#  599: 'ensued',
#  600: 'larger',
#  601: 'loving',
#  602: 'each',
#  603: 'curry',
#  604: '2',
#  605: 'fat',
#  606: 'pumpkin',
#  607: 'next',
#  608: 'register',
#  609: 'HOUR',
#  610: 'Over',
#  611: 'MANAGEMENT',
#  612: 'forty',
#  613: 'strings',
#  614: 'presentation',
#  615: '11.99',
#  616: 'spots',
#  617: 'mostly',
#  618: 'possible',
#  619: 'Their',
#  620: 'flavorless',
#  621: 'restaurant',
#  622: 'Christmas',
#  623: 'play',
#  624: 'par',
#  625: 'craving',
#  626: 'callings',
#  627: 'summary',
#  628: 'friends',
#  629: 'ice',
#  630: 'foot',
#  631: 'skimp',
#  632: 'treat',
#  633: 'peanuts',
#  634: '.very',
#  635: 'delight',
#  636: 'Come',
#  637: 'chip',
#  638: 'amount',
#  639: 'TOLD',
#  640: 'watered',
#  641: 'Crust',
#  642: 'refrained',
#  643: 'music',
#  644: 'carbs',
#  645: 'totally',
#  646: 'smaller',
#  647: 'Host',
#  648: 'Elk',
#  649: '..ohhh',
#  650: 'offered',
#  651: 'Overpriced',
#  652: 'included',
#  653: 'TIME',
#  654: 'probably',
#  655: 'cheese',
#  656: 'wound',
#  657: 'Pita',
#  658: 'cold',
#  659: 'understand',
#  660: 'yellowtail',
#  661: 'Fantastic',
#  662: 'too',
#  663: 'experienced',
#  664: 'Everything',
#  665: '90',
#  666: 'Awesome',
#  667: 'going',
#  668: 'Restaurant',
#  669: 'bagels',
#  670: 'combos',
#  671: 'Company',
#  672: 'thanks',
#  673: 'Are',
#  674: 'ago',
#  675: 'haunt',
#  676: 'Steak',
#  677: 'Generous',
#  678: 'rowdy',
#  679: 'Bisque',
#  680: 'sure',
#  681: 'undercooked',
#  682: ',',
#  683: 'polite',
#  684: 'over-whelm',
#  685: 'Cotta',
#  686: 'mall',
#  687: 'onion',
#  688: 'anticipated',
#  689: 'awful',
#  690: 'dinners',
#  691: 'roasted',
#  692: 'driest',
#  693: '4.00',
#  694: 'nay',
#  695: 'Today',
#  696: 'Maria',
#  697: 'seriously',
#  698: 'appetizer',
#  699: 'exactly',
#  700: 'across',
#  701: 'OF',
#  702: 'events',
#  703: 'Steve',
#  704: 'yucky',
#  705: 'No',
#  706: 'Chinese',
#  707: 'occasions',
#  708: 'dog',
#  709: 'world',
#  710: 'Ample',
#  711: 'shoe',
#  712: 'stayed',
#  713: 'arrives',
#  714: 'jalapeno',
#  715: 'Buldogis',
#  716: 'imagine',
#  717: 'under-services',
#  718: 'sharply',
#  719: 'baby',
#  720: 'truffle',
#  721: 'HAPPENED',
#  722: 'showed',
#  723: 'English',
#  724: 'upgrading',
#  725: 'exquisite',
#  726: 'otherwise',
#  727: 'down',
#  728: 'joy',
#  729: 'Noca',
#  730: 'review',
#  731: 'delivery',
#  732: 'instantly',
#  733: 'disgusted',
#  734: 'MANY',
#  735: 'consistent',
#  736: 'Sooooo',
#  737: '*',
#  738: 'After',
#  739: 'recommend',
#  740: 'experience',
#  741: 'day',
#  742: 'bug',
#  743: 'months',
#  744: 'Much',
#  745: 'boxes',
#  746: 'known',
#  747: 'oh',
#  748: 'after',
#  749: 'law',
#  750: 'Strip',
#  751: 'falafels',
#  752: 'disappointment',
#  753: 'correction',
#  754: 'since',
#  755: 'This',
#  756: 'sause',
#  757: 'like',
#  758: 'Ironman',
#  759: 'stay',
#  760: 'used',
#  761: 'ordered',
#  762: 'mixed',
#  763: 'walls',
#  764: 'show',
#  765: 'we',
#  766: 'round',
#  767: 'Plater',
#  768: 'disappoint',
#  769: 'mood',
#  770: 'greens',
#  771: 'Coffee',
#  772: 'hooked',
#  773: 'most',
#  774: 'Egg',
#  775: 'accident',
#  776: 'in',
#  777: 'driving',
#  778: 'GO',
#  779: 'dish',
#  780: 'sucks',
#  781: 'car',
#  782: 'perfectly',
#  783: 'grab',
#  784: 'satisfying',
#  785: 'blows',
#  786: 'sides',
#  787: 'why',
#  788: 'sandwich',
#  789: 'only',
#  790: 'actually',
#  791: 'work',
#  792: 'preparing',
#  793: 'Everyone',
#  794: 'climbing',
#  795: 'Hawaiian',
#  796: 'Magic',
#  797: 'fabulous',
#  798: 'stale',
#  799: 'multi-grain',
#  800: 'Reasonably',
#  801: 'liked',
#  802: 'gloves.Everything',
#  803: 'Will',
#  804: 'die',
#  805: 'eaten',
#  806: 'delicioso',
#  807: 'suggestions',
#  808: 'hated',
#  809: 'non-customer',
#  810: 'help',
#  811: 'solidify',
#  812: 'Owner',
#  813: 'My',
#  814: 'Cod',
#  815: 'grilled',
#  816: 'tolerance',
#  817: 'palate',
#  818: 'LOVED',
#  819: 'tasteless',
#  820: 'binge',
#  821: 'Horrible',
#  822: 'box',
#  823: 'for',
#  824: 'couple',
#  825: 'a',
#  826: 'patio',
#  827: 'establishment',
#  828: 'wagyu',
#  829: '&',
#  830: 'ventilation',
#  831: 'beer',
#  832: 'Waiter',
#  833: 'industry',
#  834: 'whether',
#  835: 'tuna',
#  836: 'tea',
#  837: 'Pineapple',
#  838: 'generic',
#  839: 'wrong',
#  840: 'hospitality',
#  841: 'me..Bunch',
#  842: 'Disappointing',
#  843: 'short',
#  844: 'FS',
#  845: 'feels',
#  846: 'refill',
#  847: 'bunch',
#  848: 'lettuce',
#  849: 'Thai',
#  850: 'reduction',
#  851: '8',
#  852: 'tartare',
#  853: 'poorly',
#  854: 'quickly',
#  855: 'something',
#  856: 'provided',
#  857: 'hereas',
#  858: '-',
#  859: 'Shrimp-',
#  860: 'vodka',
#  861: 'CONCLUSION',
#  862: 'venue',
#  863: '.THE',
#  864: 'choux',
#  865: 's',
#  866: 'assure',
#  867: 'coffee',
#  868: '10+',
#  869: 'town',
#  870: 'ourselves',
#  871: 'pancake',
#  872: 'Italian',
#  873: 'mediocre',
#  874: 'Coming',
#  875: 'worries',
#  876: 'tiny',
#  877: 'sugary',
#  878: 'Thumbs',
#  879: 'under',
#  880: 'descriptions',
#  881: 'figured',
#  882: 'cocktail',
#  883: 'bellies',
#  884: 'sunglasses',
#  885: 'rings',
#  886: 'breaks',
#  887: 'brother',
#  888: 'NOT',
#  889: 'mayo',
#  890: 'Seafood',
#  891: 'mile',
#  892: 'what',
#  893: 'fuzzy',
#  894: 'am',
#  895: 'limited',
#  896: 'happier',
#  897: 'its',
#  898: 'effort',
#  899: 'seemed',
#  900: 'tater',
#  901: 'front',
#  902: 'ones',
#  903: 'wish',
#  904: 'big',
#  905: 'picture',
#  906: 'Japanese',
#  907: 'free',
#  908: 'fresh',
#  909: 'garlic',
#  910: 'awesome',
#  911: 'him',
#  912: 'puréed',
#  913: 'requested',
#  914: 'Your',
#  915: 'Smashburger',
#  916: 'crepe',
#  917: '...',
#  918: 'garden',
#  919: 'fare',
#  920: 'drag',
#  921: 'handling',
#  922: 'delish',
#  923: 'cant',
#  924: 'Server',
#  925: 'One',
#  926: 'mein',
#  927: 'Flower',
#  928: 'been-stepped-in-and-tracked-everywhere',
#  929: 'crowds',
#  930: 'Nobu',
#  931: 'grow',
#  932: 'amazing',
#  933: 'years',
#  934: 'atmosphere',
#  935: 'ala',
#  936: 'dark',
#  937: 'the',
#  938: '..went',
#  939: 'NO',
#  940: 'worth',
#  941: 'not',
#  942: 'continue',
#  943: 'shall',
#  944: 'postinos',
#  945: 'walked',
#  946: 'towards',
#  947: 'beat',
#  948: 'extremely',
#  949: 'taco',
#  950: 'deeply',
#  951: 'ribeye',
#  952: 'piece',
#  953: 'shower',
#  954: 'workers',
#  955: 'moz',
#  956: 'bodes',
#  957: 'drunk',
#  958: 'friendly',
#  959: 'was',
#  960: 'hot',
#  961: 'glance',
#  962: 'reading',
#  963: 'Filet',
#  964: 'water',
#  965: 'unwrapped',
#  966: 'Omelets',
#  967: 'rice',
#  968: 'number',
#  969: 'arriving',
#  970: 'performed',
#  971: 'bacon',
#  972: 'lukewarm',
#  973: 'Sprouts',
#  974: 'silently',
#  975: 'Be',
#  976: 'six',
#  977: 'writing',
#  978: 'mistake',
#  979: 'pale',
#  980: 'soooooo',
#  981: 'airport',
#  982: 'coupons',
#  983: 'bought',
#  984: 'she',
#  985: 'prepare',
#  986: 'case',
#  987: 'finally',
#  988: 'sense',
#  989: 'Breeze',
#  990: 'life',
#  991: 'heads',
#  992: 'huevos',
#  993: '1',
#  994: 'unbelievable',
#  995: 'mary',
#  996: 'lovers',
#  997: 'Philadelphia',
#  998: 'imagined',
#  999: 'Denny',
#  ...}

# %% [markdown]
# ## 轉換句子為bag of words型式

# %%
def _get_bag_of_words_vector(sentence, word_index_dic, whole_words):
    sentence = sentence
    vector = np.zeros(len(whole_words))
    for word in nltk.word_tokenize(sentence):
        if word in whole_words:
            vector[word_index[word]]+=1
    return vector

# %%
_get_bag_of_words_vector('Wow... Loved this place.', word_index, whole_words)
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])
