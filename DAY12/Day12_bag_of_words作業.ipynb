# %% [markdown]
# ## 作業目標：搭建一個bag of words模型

# %% [markdown]
# ---

# %%
import pandas as pd
import nltk
#nltk.download()
nltk.download('punkt')
import numpy as np
dataset=pd.read_csv('Restaurant_Reviews.tsv',delimiter='\t',quoting=3)
corpus=dataset['Review'].values
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# ### 從文本中取出所有單字

# %%
whole_words = []
for sentence in corpus:
    tokenized_sentence = nltk.word_tokenize(sentence)
    for word in tokenized_sentence:
        whole_words.append(word)

# %% [markdown]
# ### 移除重複單字

# %%
whole_words = set(whole_words)
print('共有{}個單字'.format(len(whole_words)))
# Out:
# 共有2356個單字

# %% [markdown]
# ### 建立字典使每一個單字有對應數值

# %%
word_index = {}
index_word = {}
n = 0
for word in whole_words:
    """自行填入"""
    word_index[word] = n
    index_word[n] = word
    n+= 1

# %%
word_index
# Out:
# {'cash': 0,
#  'covered': 1,
#  'curry': 2,
#  'elegantly': 3,
#  'foot': 4,
#  'onion': 5,
#  'beateous': 6,
#  'heat': 7,
#  'Tucson': 8,
#  'typical': 9,
#  'lacked': 10,
#  'And': 11,
#  '*heart*': 12,
#  'dishes': 13,
#  'apart': 14,
#  'disbelief': 15,
#  'steakhouse': 16,
#  'guest': 17,
#  'between': 18,
#  'wash': 19,
#  'common': 20,
#  '.very': 21,
#  'soundtrack': 22,
#  'course': 23,
#  'shower': 24,
#  'par': 25,
#  'guess': 26,
#  'oh': 27,
#  'tried': 28,
#  'use': 29,
#  'price': 30,
#  'Coming': 31,
#  'quantity': 32,
#  'towards': 33,
#  'warm': 34,
#  'shrimp': 35,
#  'overcooked': 36,
#  'Oh': 37,
#  'ate': 38,
#  'guys': 39,
#  'Be': 40,
#  'Ample': 41,
#  'since': 42,
#  'craving': 43,
#  'walls': 44,
#  'stuff': 45,
#  'luck': 46,
#  'six': 47,
#  'raspberry': 48,
#  'kids': 49,
#  'roasted': 50,
#  'meet': 51,
#  'Bacon': 52,
#  'fact': 53,
#  'highlights': 54,
#  'offered': 55,
#  'Wonderful': 56,
#  'sangria': 57,
#  'cake': 58,
#  'finger': 59,
#  'peanut': 60,
#  'Tasty': 61,
#  'How': 62,
#  'these': 63,
#  'Big': 64,
#  'missing': 65,
#  'inspired': 66,
#  'us': 67,
#  'Hut': 68,
#  'homemade': 69,
#  'crêpe': 70,
#  'crazy': 71,
#  'swung': 72,
#  'ended': 73,
#  'gluten': 74,
#  'Ambience': 75,
#  'Subway': 76,
#  'walked': 77,
#  '2': 78,
#  'lacking': 79,
#  'generous': 80,
#  'single': 81,
#  'can': 82,
#  'Mushroom': 83,
#  'lost': 84,
#  'immediately': 85,
#  'totally': 86,
#  'EVER': 87,
#  'bye': 88,
#  'under': 89,
#  'Things': 90,
#  'tots': 91,
#  'Blah': 92,
#  'disappointment': 93,
#  'Caesar': 94,
#  'Edinburgh': 95,
#  'longer': 96,
#  'Join': 97,
#  'try': 98,
#  'companions': 99,
#  'Ians': 100,
#  'pay': 101,
#  'dressing': 102,
#  'letdown': 103,
#  'baklava': 104,
#  'portion': 105,
#  'Phoenix': 106,
#  'caught': 107,
#  'pastry': 108,
#  'circumstances': 109,
#  'added': 110,
#  'self': 111,
#  'side': 112,
#  'Burger': 113,
#  'driest': 114,
#  'lots': 115,
#  'uninspired': 116,
#  'sashimi': 117,
#  'then': 118,
#  'dipping': 119,
#  'couple': 120,
#  'complaints': 121,
#  'ALL': 122,
#  'love': 123,
#  'things': 124,
#  'Third': 125,
#  'deliver': 126,
#  'Awesome': 127,
#  'under-services': 128,
#  'friend': 129,
#  'worth': 130,
#  'hopes': 131,
#  'accordingly': 132,
#  'five': 133,
#  'running': 134,
#  'Best': 135,
#  'trimmed': 136,
#  'easily': 137,
#  'fast': 138,
#  'STALE': 139,
#  'happened': 140,
#  'turn': 141,
#  'flirting': 142,
#  'enthusiastic': 143,
#  'NO': 144,
#  'Elk': 145,
#  'holiday': 146,
#  'stood': 147,
#  'screwed': 148,
#  'guacamole': 149,
#  'considering': 150,
#  'eyes': 151,
#  'Francisco': 152,
#  'send': 153,
#  'Ironman': 154,
#  'joint': 155,
#  'seasonal': 156,
#  'stars': 157,
#  'away': 158,
#  'grab': 159,
#  'preparing': 160,
#  'flavor': 161,
#  'heads': 162,
#  'raving': 163,
#  'THAT': 164,
#  'tops': 165,
#  'tummy': 166,
#  'public': 167,
#  'Sun': 168,
#  'register': 169,
#  'asking': 170,
#  'boys': 171,
#  'Wife': 172,
#  'prices': 173,
#  'garlic': 174,
#  'spring': 175,
#  'positive': 176,
#  'cranberry': 177,
#  'Experience': 178,
#  'Bar': 179,
#  'Special': 180,
#  'coconut': 181,
#  'included': 182,
#  'surprised': 183,
#  'reading': 184,
#  'gratuity': 185,
#  'Please': 186,
#  'set': 187,
#  'breakfast/lunch': 188,
#  'meatballs': 189,
#  'small': 190,
#  'might': 191,
#  'fella': 192,
#  'figured': 193,
#  'lived': 194,
#  'authentic': 195,
#  'extensive': 196,
#  'from': 197,
#  'order': 198,
#  'Las': 199,
#  'untoasted': 200,
#  'baby': 201,
#  'somethat': 202,
#  'Philadelphia': 203,
#  'Same': 204,
#  'Left': 205,
#  'industry': 206,
#  'version': 207,
#  'hot': 208,
#  'absolutley': 209,
#  'Baba': 210,
#  'descriptions': 211,
#  "ya'all": 212,
#  'provides': 213,
#  'downside': 214,
#  'returning': 215,
#  'LOVED': 216,
#  'me..Bunch': 217,
#  'gyro': 218,
#  'mouthful': 219,
#  'Plater': 220,
#  'But': 221,
#  'outrageously': 222,
#  'Anyways': 223,
#  'via': 224,
#  'later': 225,
#  'at': 226,
#  'douchey': 227,
#  'drenched': 228,
#  'refrained': 229,
#  'arrived': 230,
#  'effort': 231,
#  'charcoal': 232,
#  'enjoy': 233,
#  '3/4ths': 234,
#  'hello': 235,
#  'That': 236,
#  'appealing': 237,
#  'trap': 238,
#  'focused': 239,
#  'Classy/warm': 240,
#  '..ohhh': 241,
#  'Ryan': 242,
#  'rushed': 243,
#  'live': 244,
#  'sauces': 245,
#  'anyone': 246,
#  'blame': 247,
#  'looks': 248,
#  'begin': 249,
#  'funny': 250,
#  'expert/connisseur': 251,
#  'sergeant': 252,
#  'Honestly': 253,
#  'First': 254,
#  'shall': 255,
#  'leftover': 256,
#  'deep': 257,
#  'restaurants': 258,
#  'caring': 259,
#  'rancheros': 260,
#  'cream': 261,
#  'choose': 262,
#  'Tigerlilly': 263,
#  'blanket': 264,
#  'bacon': 265,
#  'BBQ': 266,
#  'brownish': 267,
#  'HAPPENED': 268,
#  'works': 269,
#  'bowl': 270,
#  'WEAK': 271,
#  'until': 272,
#  'menu': 273,
#  'Prices': 274,
#  'speedy': 275,
#  'shopping': 276,
#  'binge': 277,
#  'tartar': 278,
#  'Fridays': 279,
#  'styrofoam': 280,
#  'eat': 281,
#  'actual': 282,
#  'wave': 283,
#  'receives': 284,
#  'reason': 285,
#  'so': 286,
#  'cow': 287,
#  'salt': 288,
#  'Bean': 289,
#  'gold': 290,
#  'Long': 291,
#  'almost': 292,
#  'pneumatic': 293,
#  'stupid': 294,
#  'unsatisfying': 295,
#  'Salad': 296,
#  'dry': 297,
#  'talk': 298,
#  'OK': 299,
#  'number': 300,
#  'WORST': 301,
#  'email': 302,
#  'will': 303,
#  'thick': 304,
#  'disgraceful': 305,
#  'CONCLUSION': 306,
#  'fo': 307,
#  'full': 308,
#  'May': 309,
#  'sub': 310,
#  'coziness': 311,
#  'Maria': 312,
#  'mouths': 313,
#  'oysters': 314,
#  'Probably': 315,
#  'venture': 316,
#  'connoisseur': 317,
#  '!': 318,
#  'Dessert': 319,
#  'roast': 320,
#  'On': 321,
#  'loves': 322,
#  'attention': 323,
#  'Salads': 324,
#  'Now': 325,
#  'behind': 326,
#  'blue': 327,
#  '?': 328,
#  '30': 329,
#  'now': 330,
#  'fried': 331,
#  'Green': 332,
#  'Then': 333,
#  'rice': 334,
#  'largely': 335,
#  'tell': 336,
#  'dreamed': 337,
#  'overhaul': 338,
#  'lunch': 339,
#  'wasted': 340,
#  'times': 341,
#  'wait': 342,
#  'Main': 343,
#  'must': 344,
#  'bucks': 345,
#  'unexperienced': 346,
#  'twice': 347,
#  'Google': 348,
#  'who': 349,
#  'ask': 350,
#  'expensive': 351,
#  'FS': 352,
#  'ripped': 353,
#  'plantains': 354,
#  'in': 355,
#  'proclaimed': 356,
#  'Crostini': 357,
#  'hip': 358,
#  'deal': 359,
#  'hours': 360,
#  'rest': 361,
#  '4.00': 362,
#  'operation': 363,
#  'means': 364,
#  'Kind': 365,
#  'imagined': 366,
#  'butter': 367,
#  '1': 368,
#  'replenished': 369,
#  'person': 370,
#  'TOTAL': 371,
#  'IT': 372,
#  'where': 373,
#  'Must': 374,
#  'outta': 375,
#  'profound': 376,
#  'when': 377,
#  'other': 378,
#  'over': 379,
#  'poorly': 380,
#  'yourself': 381,
#  'reminded': 382,
#  'website': 383,
#  'apologize': 384,
#  'passed': 385,
#  "n't": 386,
#  'pack': 387,
#  'Pita': 388,
#  'Hawaiian': 389,
#  'Hell': 390,
#  'few': 391,
#  'condiment': 392,
#  'healthy': 393,
#  'yucky': 394,
#  'served': 395,
#  'daily': 396,
#  'job': 397,
#  'Disappointing': 398,
#  'Mango': 399,
#  'tepid': 400,
#  '..there': 401,
#  'together': 402,
#  'legs': 403,
#  'thru': 404,
#  'juries': 405,
#  'round': 406,
#  'HAVE': 407,
#  'medium': 408,
#  'likes': 409,
#  'least': 410,
#  'dessert': 411,
#  'awesome': 412,
#  'Weird': 413,
#  'Only': 414,
#  'patio': 415,
#  'Sour': 416,
#  'menus': 417,
#  'bland': 418,
#  'Delicious': 419,
#  'sure': 420,
#  'Cod': 421,
#  'providing': 422,
#  'satisfied': 423,
#  'Waitress': 424,
#  'apology': 425,
#  'tea': 426,
#  'Hunan': 427,
#  'indoor': 428,
#  'date': 429,
#  'AGAIN': 430,
#  'item': 431,
#  'treat': 432,
#  'words': 433,
#  'Bussell': 434,
#  'new': 435,
#  'ache': 436,
#  'Excalibur': 437,
#  '1979': 438,
#  'fare': 439,
#  'choux': 440,
#  'eggplant': 441,
#  'water': 442,
#  'cafe': 443,
#  'gets': 444,
#  'eating': 445,
#  'bad': 446,
#  'ethic': 447,
#  'ambiance': 448,
#  'INCONSIDERATE': 449,
#  'crispy': 450,
#  'something': 451,
#  'hooked': 452,
#  'Give': 453,
#  'cheated': 454,
#  'pretty': 455,
#  'weekend': 456,
#  'cavier': 457,
#  'closed': 458,
#  'here': 459,
#  'tip': 460,
#  'rubber': 461,
#  'Jamaican': 462,
#  'head': 463,
#  'because': 464,
#  'Gringos': 465,
#  'OMG': 466,
#  'watered': 467,
#  'terrific': 468,
#  'bigger': 469,
#  'prepare': 470,
#  'recommending': 471,
#  'Loved': 472,
#  'reduction': 473,
#  'angry': 474,
#  'has': 475,
#  'absolute': 476,
#  'today': 477,
#  'rowdy': 478,
#  'day': 479,
#  'Despite': 480,
#  'power': 481,
#  'disappoint': 482,
#  'over-priced': 483,
#  'tiny': 484,
#  'martini': 485,
#  'loudly': 486,
#  'flat': 487,
#  'workers': 488,
#  'Japanese': 489,
#  'store': 490,
#  'inviting': 491,
#  'themselves': 492,
#  'AND': 493,
#  'Bad': 494,
#  'dining': 495,
#  'Frenchman': 496,
#  'waste': 497,
#  'biscuit': 498,
#  'corn': 499,
#  'pan': 500,
#  'building': 501,
#  'Soups': 502,
#  'Chipotle': 503,
#  'personally': 504,
#  'teamwork': 505,
#  'place': 506,
#  'Lobster': 507,
#  'dont': 508,
#  'clue': 509,
#  'Noca': 510,
#  'be': 511,
#  'anticipated': 512,
#  'nothing': 513,
#  'Joey': 514,
#  'salads': 515,
#  'Jenni': 516,
#  'first': 517,
#  '--': 518,
#  'staying': 519,
#  'bamboo': 520,
#  'received': 521,
#  'anytime': 522,
#  'started': 523,
#  'pita': 524,
#  'Vegetarian': 525,
#  'summarize': 526,
#  'cannoli': 527,
#  'GC': 528,
#  'gave': 529,
#  'any': 530,
#  'mostly': 531,
#  'refused': 532,
#  'living': 533,
#  'their': 534,
#  'sore': 535,
#  'worker': 536,
#  'lawyers': 537,
#  'airline': 538,
#  '-': 539,
#  'traditional': 540,
#  'Buldogis': 541,
#  'menu/': 542,
#  'paper': 543,
#  'wontons': 544,
#  'covers': 545,
#  'signs': 546,
#  'Delight': 547,
#  'bartender': 548,
#  'accident': 549,
#  'Ninja': 550,
#  'hamburger': 551,
#  'toasted': 552,
#  'VERY': 553,
#  'fillet': 554,
#  'dropped': 555,
#  'liking': 556,
#  'bar': 557,
#  'whole': 558,
#  'chips': 559,
#  'brings': 560,
#  'owners': 561,
#  'close': 562,
#  'tater': 563,
#  'GREAT': 564,
#  'hair': 565,
#  'sals': 566,
#  'dusted': 567,
#  'Overall': 568,
#  'Took': 569,
#  'brick': 570,
#  'Wienerschnitzel': 571,
#  'elsewhere': 572,
#  'lovers': 573,
#  'past': 574,
#  'bit': 575,
#  'shops': 576,
#  'specials': 577,
#  'Host': 578,
#  'is': 579,
#  'as': 580,
#  'Similarly': 581,
#  'mussels': 582,
#  'spicy': 583,
#  'meal': 584,
#  'disaster': 585,
#  'dinners': 586,
#  'vegan/veggie': 587,
#  'almonds': 588,
#  'describing': 589,
#  'reasonable': 590,
#  'oil': 591,
#  'songs': 592,
#  'seen': 593,
#  'juice..': 594,
#  'stay': 595,
#  'BACK': 596,
#  'HOUR': 597,
#  'judge': 598,
#  'Do': 599,
#  'constructed': 600,
#  'grease': 601,
#  'amount': 602,
#  'One': 603,
#  '.THE': 604,
#  'pepper': 605,
#  'average': 606,
#  'selection': 607,
#  'doing': 608,
#  'fair': 609,
#  'grandmother': 610,
#  'wrap': 611,
#  'succulent': 612,
#  'Waited': 613,
#  'WHAT': 614,
#  'servers': 615,
#  'sat': 616,
#  'eggs': 617,
#  'meh': 618,
#  'jalapeno': 619,
#  'burgers': 620,
#  "'m": 621,
#  'Great': 622,
#  'Server': 623,
#  'Spend': 624,
#  'Palm': 625,
#  'capers': 626,
#  'struck': 627,
#  'neat': 628,
#  'Which': 629,
#  'cold': 630,
#  'could': 631,
#  'half': 632,
#  'made': 633,
#  'Of': 634,
#  'shirt': 635,
#  'hour': 636,
#  'relocated': 637,
#  'honestly': 638,
#  'So': 639,
#  'glass': 640,
#  'seasoned': 641,
#  'performed': 642,
#  'gas': 643,
#  'instantly': 644,
#  'end': 645,
#  'guy': 646,
#  'military': 647,
#  'came': 648,
#  'interior': 649,
#  'whether': 650,
#  'management': 651,
#  'visited': 652,
#  'outside': 653,
#  'slaw': 654,
#  'disgusted': 655,
#  'hardly': 656,
#  'across': 657,
#  'empty': 658,
#  'dripping': 659,
#  'are': 660,
#  'sunglasses': 661,
#  'yummy': 662,
#  'M': 663,
#  'Generous': 664,
#  'Perfect': 665,
#  'Pretty': 666,
#  'mean': 667,
#  'Han': 668,
#  'chains': 669,
#  'busy': 670,
#  'free': 671,
#  'An': 672,
#  'buffets': 673,
#  'did': 674,
#  'sense': 675,
#  'Soggy': 676,
#  'professional': 677,
#  'restaurant': 678,
#  'cheese': 679,
#  'Otto': 680,
#  'Nice': 681,
#  'buying': 682,
#  'decided': 683,
#  'fairly': 684,
#  'SCREAMS': 685,
#  'Del': 686,
#  'BITCHES': 687,
#  'teeth': 688,
#  'Highly': 689,
#  'thinly': 690,
#  'Favorite': 691,
#  'people': 692,
#  'missed': 693,
#  'group': 694,
#  'tastings': 695,
#  'leaves': 696,
#  'poop': 697,
#  'hurry': 698,
#  'third': 699,
#  'Definitely': 700,
#  'skimp': 701,
#  'count': 702,
#  'publicly': 703,
#  'sound': 704,
#  'wire': 705,
#  'bellies': 706,
#  'told': 707,
#  'besides': 708,
#  'heart': 709,
#  'insulted': 710,
#  'outshining': 711,
#  'movies': 712,
#  'again': 713,
#  'No': 714,
#  'beef': 715,
#  'They': 716,
#  'space': 717,
#  'insanely': 718,
#  'lot': 719,
#  'very': 720,
#  'All': 721,
#  'blandest': 722,
#  'cuisine': 723,
#  "'d": 724,
#  'if': 725,
#  'Update': 726,
#  'Carly': 727,
#  'glance': 728,
#  'dark': 729,
#  'or': 730,
#  'Toast': 731,
#  'mind': 732,
#  'andddd': 733,
#  'regular': 734,
#  'flavors': 735,
#  'weekly': 736,
#  'trippy': 737,
#  'venturing': 738,
#  'Customer': 739,
#  'upgrading': 740,
#  'than': 741,
#  'whatsoever': 742,
#  'you': 743,
#  'check': 744,
#  'Cooked': 745,
#  'fuzzy': 746,
#  'hottest': 747,
#  'hits': 748,
#  'definately': 749,
#  'vomited': 750,
#  'dish': 751,
#  'Although': 752,
#  'Pros': 753,
#  'marrow': 754,
#  'ourselves': 755,
#  'town': 756,
#  'touch': 757,
#  'claimed': 758,
#  'Steve': 759,
#  'over-hip': 760,
#  'blow': 761,
#  'Food': 762,
#  'another': 763,
#  'she': 764,
#  'real': 765,
#  'desserts': 766,
#  'rinse': 767,
#  'delicate': 768,
#  'awkward': 769,
#  'sandwich': 770,
#  'usual': 771,
#  'indicate': 772,
#  'San': 773,
#  'owner/chef': 774,
#  'hoping': 775,
#  'WAY': 776,
#  'those': 777,
#  'kitchen': 778,
#  'EXPERIENCE': 779,
#  'mood': 780,
#  'Are': 781,
#  '1/2': 782,
#  'cook': 783,
#  'must-stop': 784,
#  'refill': 785,
#  'Outstanding': 786,
#  'sign': 787,
#  'Our': 788,
#  'chip': 789,
#  'From': 790,
#  'dirty-': 791,
#  'feels': 792,
#  'this': 793,
#  'THIS': 794,
#  'pub': 795,
#  'absolutely': 796,
#  'unbelievable': 797,
#  'honest': 798,
#  'crowd': 799,
#  'smelled': 800,
#  'LEGIT': 801,
#  'consider': 802,
#  'apparently': 803,
#  'although': 804,
#  'wrong': 805,
#  'relationship': 806,
#  'For': 807,
#  'DELICIOUS': 808,
#  'Would': 809,
#  'At': 810,
#  'avoided': 811,
#  'touched': 812,
#  'Egg': 813,
#  'checked': 814,
#  'Bay': 815,
#  'dedicated': 816,
#  'discount': 817,
#  'during': 818,
#  'calligraphy': 819,
#  'complete': 820,
#  'below': 821,
#  'Ha': 822,
#  'veal': 823,
#  'warmer': 824,
#  'Place': 825,
#  '.': 826,
#  'hearts': 827,
#  'Kids': 828,
#  'takeout': 829,
#  'one': 830,
#  'cooked': 831,
#  'cheap': 832,
#  'subpar': 833,
#  'money': 834,
#  'big': 835,
#  'Standard': 836,
#  'beyond': 837,
#  'greedy': 838,
#  'egg': 839,
#  'pile': 840,
#  'looking': 841,
#  'somewhat': 842,
#  'folks': 843,
#  'human': 844,
#  'Madison': 845,
#  'inexpensive': 846,
#  'inflate': 847,
#  'ignore': 848,
#  'want': 849,
#  'salad': 850,
#  'sugar': 851,
#  'thats': 852,
#  'seafood': 853,
#  'Awful': 854,
#  'Mmmm': 855,
#  'arrives': 856,
#  'creamy': 857,
#  'decent': 858,
#  'beans': 859,
#  'grocery': 860,
#  'shocked': 861,
#  'plus': 862,
#  'extraordinary': 863,
#  'Con': 864,
#  'college': 865,
#  'pucks': 866,
#  'reasons': 867,
#  'establishment': 868,
#  'talking': 869,
#  'hi': 870,
#  'Gyros': 871,
#  'bartenders': 872,
#  'got': 873,
#  'accountant': 874,
#  'simply': 875,
#  'officially': 876,
#  'mention': 877,
#  'yellow': 878,
#  'appetizer': 879,
#  'brunch': 880,
#  'awful': 881,
#  'Gave': 882,
#  'sweet': 883,
#  'selections': 884,
#  'T.': 885,
#  'belly': 886,
#  'exactly': 887,
#  'non-fancy': 888,
#  'fat': 889,
#  'known': 890,
#  'door': 891,
#  'dead': 892,
#  'the': 893,
#  'always': 894,
#  'huevos': 895,
#  'contained': 896,
#  'continue': 897,
#  'moist': 898,
#  'seal': 899,
#  'deuchebaggery': 900,
#  'Honeslty': 901,
#  'undercooked': 902,
#  'mall': 903,
#  'Always': 904,
#  'believe': 905,
#  'law': 906,
#  'attentive': 907,
#  'Casino': 908,
#  'hungry': 909,
#  '10+': 910,
#  'chickens': 911,
#  'they': 912,
#  'cool': 913,
#  'decor': 914,
#  'writing': 915,
#  'Furthermore': 916,
#  'High-quality': 917,
#  'burger': 918,
#  'Rick': 919,
#  'warnings': 920,
#  'palate': 921,
#  'leave': 922,
#  'temp.I': 923,
#  'company': 924,
#  'wine': 925,
#  'rib': 926,
#  'me': 927,
#  'son': 928,
#  'mess': 929,
#  'trying': 930,
#  'delish': 931,
#  'decorated': 932,
#  'disrespected': 933,
#  'wife': 934,
#  'Christmas': 935,
#  '-My': 936,
#  'Gourmet': 937,
#  'looked': 938,
#  'Eclectic': 939,
#  'strange': 940,
#  'large': 941,
#  'generic': 942,
#  'mac': 943,
#  'goat': 944,
#  'If': 945,
#  'Indian': 946,
#  'nut': 947,
#  'Café': 948,
#  'hella': 949,
#  'dealing': 950,
#  'Nobu': 951,
#  'revisiting': 952,
#  'Over': 953,
#  'tapas': 954,
#  'AYCE': 955,
#  'most': 956,
#  'frustrated': 957,
#  'MUST': 958,
#  'cover': 959,
#  'after': 960,
#  'sever': 961,
#  'wings': 962,
#  'pizza': 963,
#  'perpared': 964,
#  'waited': 965,
#  'similar': 966,
#  'seated': 967,
#  'A': 968,
#  'fabulous': 969,
#  'Those': 970,
#  'smooth': 971,
#  'chipolte': 972,
#  'summer': 973,
#  'point': 974,
#  'nigiri': 975,
#  'boiled': 976,
#  'Aria': 977,
#  'thirty': 978,
#  'have': 979,
#  'However': 980,
#  'exceeding': 981,
#  'Up': 982,
#  'work': 983,
#  'market': 984,
#  'chocolate': 985,
#  'boot': 986,
#  'spinach': 987,
#  'saving': 988,
#  'What': 989,
#  'friendly': 990,
#  'chef': 991,
#  'relax': 992,
#  'Caballero': 993,
#  'WAAAAAAyyyyyyyyyy': 994,
#  'much': 995,
#  'petrified': 996,
#  'falafels': 997,
#  'service': 998,
#  'humiliated': 999,
#  ...}

# %%
index_word
# Out:
# {0: 'cash',
#  1: 'covered',
#  2: 'curry',
#  3: 'elegantly',
#  4: 'foot',
#  5: 'onion',
#  6: 'beateous',
#  7: 'heat',
#  8: 'Tucson',
#  9: 'typical',
#  10: 'lacked',
#  11: 'And',
#  12: '*heart*',
#  13: 'dishes',
#  14: 'apart',
#  15: 'disbelief',
#  16: 'steakhouse',
#  17: 'guest',
#  18: 'between',
#  19: 'wash',
#  20: 'common',
#  21: '.very',
#  22: 'soundtrack',
#  23: 'course',
#  24: 'shower',
#  25: 'par',
#  26: 'guess',
#  27: 'oh',
#  28: 'tried',
#  29: 'use',
#  30: 'price',
#  31: 'Coming',
#  32: 'quantity',
#  33: 'towards',
#  34: 'warm',
#  35: 'shrimp',
#  36: 'overcooked',
#  37: 'Oh',
#  38: 'ate',
#  39: 'guys',
#  40: 'Be',
#  41: 'Ample',
#  42: 'since',
#  43: 'craving',
#  44: 'walls',
#  45: 'stuff',
#  46: 'luck',
#  47: 'six',
#  48: 'raspberry',
#  49: 'kids',
#  50: 'roasted',
#  51: 'meet',
#  52: 'Bacon',
#  53: 'fact',
#  54: 'highlights',
#  55: 'offered',
#  56: 'Wonderful',
#  57: 'sangria',
#  58: 'cake',
#  59: 'finger',
#  60: 'peanut',
#  61: 'Tasty',
#  62: 'How',
#  63: 'these',
#  64: 'Big',
#  65: 'missing',
#  66: 'inspired',
#  67: 'us',
#  68: 'Hut',
#  69: 'homemade',
#  70: 'crêpe',
#  71: 'crazy',
#  72: 'swung',
#  73: 'ended',
#  74: 'gluten',
#  75: 'Ambience',
#  76: 'Subway',
#  77: 'walked',
#  78: '2',
#  79: 'lacking',
#  80: 'generous',
#  81: 'single',
#  82: 'can',
#  83: 'Mushroom',
#  84: 'lost',
#  85: 'immediately',
#  86: 'totally',
#  87: 'EVER',
#  88: 'bye',
#  89: 'under',
#  90: 'Things',
#  91: 'tots',
#  92: 'Blah',
#  93: 'disappointment',
#  94: 'Caesar',
#  95: 'Edinburgh',
#  96: 'longer',
#  97: 'Join',
#  98: 'try',
#  99: 'companions',
#  100: 'Ians',
#  101: 'pay',
#  102: 'dressing',
#  103: 'letdown',
#  104: 'baklava',
#  105: 'portion',
#  106: 'Phoenix',
#  107: 'caught',
#  108: 'pastry',
#  109: 'circumstances',
#  110: 'added',
#  111: 'self',
#  112: 'side',
#  113: 'Burger',
#  114: 'driest',
#  115: 'lots',
#  116: 'uninspired',
#  117: 'sashimi',
#  118: 'then',
#  119: 'dipping',
#  120: 'couple',
#  121: 'complaints',
#  122: 'ALL',
#  123: 'love',
#  124: 'things',
#  125: 'Third',
#  126: 'deliver',
#  127: 'Awesome',
#  128: 'under-services',
#  129: 'friend',
#  130: 'worth',
#  131: 'hopes',
#  132: 'accordingly',
#  133: 'five',
#  134: 'running',
#  135: 'Best',
#  136: 'trimmed',
#  137: 'easily',
#  138: 'fast',
#  139: 'STALE',
#  140: 'happened',
#  141: 'turn',
#  142: 'flirting',
#  143: 'enthusiastic',
#  144: 'NO',
#  145: 'Elk',
#  146: 'holiday',
#  147: 'stood',
#  148: 'screwed',
#  149: 'guacamole',
#  150: 'considering',
#  151: 'eyes',
#  152: 'Francisco',
#  153: 'send',
#  154: 'Ironman',
#  155: 'joint',
#  156: 'seasonal',
#  157: 'stars',
#  158: 'away',
#  159: 'grab',
#  160: 'preparing',
#  161: 'flavor',
#  162: 'heads',
#  163: 'raving',
#  164: 'THAT',
#  165: 'tops',
#  166: 'tummy',
#  167: 'public',
#  168: 'Sun',
#  169: 'register',
#  170: 'asking',
#  171: 'boys',
#  172: 'Wife',
#  173: 'prices',
#  174: 'garlic',
#  175: 'spring',
#  176: 'positive',
#  177: 'cranberry',
#  178: 'Experience',
#  179: 'Bar',
#  180: 'Special',
#  181: 'coconut',
#  182: 'included',
#  183: 'surprised',
#  184: 'reading',
#  185: 'gratuity',
#  186: 'Please',
#  187: 'set',
#  188: 'breakfast/lunch',
#  189: 'meatballs',
#  190: 'small',
#  191: 'might',
#  192: 'fella',
#  193: 'figured',
#  194: 'lived',
#  195: 'authentic',
#  196: 'extensive',
#  197: 'from',
#  198: 'order',
#  199: 'Las',
#  200: 'untoasted',
#  201: 'baby',
#  202: 'somethat',
#  203: 'Philadelphia',
#  204: 'Same',
#  205: 'Left',
#  206: 'industry',
#  207: 'version',
#  208: 'hot',
#  209: 'absolutley',
#  210: 'Baba',
#  211: 'descriptions',
#  212: "ya'all",
#  213: 'provides',
#  214: 'downside',
#  215: 'returning',
#  216: 'LOVED',
#  217: 'me..Bunch',
#  218: 'gyro',
#  219: 'mouthful',
#  220: 'Plater',
#  221: 'But',
#  222: 'outrageously',
#  223: 'Anyways',
#  224: 'via',
#  225: 'later',
#  226: 'at',
#  227: 'douchey',
#  228: 'drenched',
#  229: 'refrained',
#  230: 'arrived',
#  231: 'effort',
#  232: 'charcoal',
#  233: 'enjoy',
#  234: '3/4ths',
#  235: 'hello',
#  236: 'That',
#  237: 'appealing',
#  238: 'trap',
#  239: 'focused',
#  240: 'Classy/warm',
#  241: '..ohhh',
#  242: 'Ryan',
#  243: 'rushed',
#  244: 'live',
#  245: 'sauces',
#  246: 'anyone',
#  247: 'blame',
#  248: 'looks',
#  249: 'begin',
#  250: 'funny',
#  251: 'expert/connisseur',
#  252: 'sergeant',
#  253: 'Honestly',
#  254: 'First',
#  255: 'shall',
#  256: 'leftover',
#  257: 'deep',
#  258: 'restaurants',
#  259: 'caring',
#  260: 'rancheros',
#  261: 'cream',
#  262: 'choose',
#  263: 'Tigerlilly',
#  264: 'blanket',
#  265: 'bacon',
#  266: 'BBQ',
#  267: 'brownish',
#  268: 'HAPPENED',
#  269: 'works',
#  270: 'bowl',
#  271: 'WEAK',
#  272: 'until',
#  273: 'menu',
#  274: 'Prices',
#  275: 'speedy',
#  276: 'shopping',
#  277: 'binge',
#  278: 'tartar',
#  279: 'Fridays',
#  280: 'styrofoam',
#  281: 'eat',
#  282: 'actual',
#  283: 'wave',
#  284: 'receives',
#  285: 'reason',
#  286: 'so',
#  287: 'cow',
#  288: 'salt',
#  289: 'Bean',
#  290: 'gold',
#  291: 'Long',
#  292: 'almost',
#  293: 'pneumatic',
#  294: 'stupid',
#  295: 'unsatisfying',
#  296: 'Salad',
#  297: 'dry',
#  298: 'talk',
#  299: 'OK',
#  300: 'number',
#  301: 'WORST',
#  302: 'email',
#  303: 'will',
#  304: 'thick',
#  305: 'disgraceful',
#  306: 'CONCLUSION',
#  307: 'fo',
#  308: 'full',
#  309: 'May',
#  310: 'sub',
#  311: 'coziness',
#  312: 'Maria',
#  313: 'mouths',
#  314: 'oysters',
#  315: 'Probably',
#  316: 'venture',
#  317: 'connoisseur',
#  318: '!',
#  319: 'Dessert',
#  320: 'roast',
#  321: 'On',
#  322: 'loves',
#  323: 'attention',
#  324: 'Salads',
#  325: 'Now',
#  326: 'behind',
#  327: 'blue',
#  328: '?',
#  329: '30',
#  330: 'now',
#  331: 'fried',
#  332: 'Green',
#  333: 'Then',
#  334: 'rice',
#  335: 'largely',
#  336: 'tell',
#  337: 'dreamed',
#  338: 'overhaul',
#  339: 'lunch',
#  340: 'wasted',
#  341: 'times',
#  342: 'wait',
#  343: 'Main',
#  344: 'must',
#  345: 'bucks',
#  346: 'unexperienced',
#  347: 'twice',
#  348: 'Google',
#  349: 'who',
#  350: 'ask',
#  351: 'expensive',
#  352: 'FS',
#  353: 'ripped',
#  354: 'plantains',
#  355: 'in',
#  356: 'proclaimed',
#  357: 'Crostini',
#  358: 'hip',
#  359: 'deal',
#  360: 'hours',
#  361: 'rest',
#  362: '4.00',
#  363: 'operation',
#  364: 'means',
#  365: 'Kind',
#  366: 'imagined',
#  367: 'butter',
#  368: '1',
#  369: 'replenished',
#  370: 'person',
#  371: 'TOTAL',
#  372: 'IT',
#  373: 'where',
#  374: 'Must',
#  375: 'outta',
#  376: 'profound',
#  377: 'when',
#  378: 'other',
#  379: 'over',
#  380: 'poorly',
#  381: 'yourself',
#  382: 'reminded',
#  383: 'website',
#  384: 'apologize',
#  385: 'passed',
#  386: "n't",
#  387: 'pack',
#  388: 'Pita',
#  389: 'Hawaiian',
#  390: 'Hell',
#  391: 'few',
#  392: 'condiment',
#  393: 'healthy',
#  394: 'yucky',
#  395: 'served',
#  396: 'daily',
#  397: 'job',
#  398: 'Disappointing',
#  399: 'Mango',
#  400: 'tepid',
#  401: '..there',
#  402: 'together',
#  403: 'legs',
#  404: 'thru',
#  405: 'juries',
#  406: 'round',
#  407: 'HAVE',
#  408: 'medium',
#  409: 'likes',
#  410: 'least',
#  411: 'dessert',
#  412: 'awesome',
#  413: 'Weird',
#  414: 'Only',
#  415: 'patio',
#  416: 'Sour',
#  417: 'menus',
#  418: 'bland',
#  419: 'Delicious',
#  420: 'sure',
#  421: 'Cod',
#  422: 'providing',
#  423: 'satisfied',
#  424: 'Waitress',
#  425: 'apology',
#  426: 'tea',
#  427: 'Hunan',
#  428: 'indoor',
#  429: 'date',
#  430: 'AGAIN',
#  431: 'item',
#  432: 'treat',
#  433: 'words',
#  434: 'Bussell',
#  435: 'new',
#  436: 'ache',
#  437: 'Excalibur',
#  438: '1979',
#  439: 'fare',
#  440: 'choux',
#  441: 'eggplant',
#  442: 'water',
#  443: 'cafe',
#  444: 'gets',
#  445: 'eating',
#  446: 'bad',
#  447: 'ethic',
#  448: 'ambiance',
#  449: 'INCONSIDERATE',
#  450: 'crispy',
#  451: 'something',
#  452: 'hooked',
#  453: 'Give',
#  454: 'cheated',
#  455: 'pretty',
#  456: 'weekend',
#  457: 'cavier',
#  458: 'closed',
#  459: 'here',
#  460: 'tip',
#  461: 'rubber',
#  462: 'Jamaican',
#  463: 'head',
#  464: 'because',
#  465: 'Gringos',
#  466: 'OMG',
#  467: 'watered',
#  468: 'terrific',
#  469: 'bigger',
#  470: 'prepare',
#  471: 'recommending',
#  472: 'Loved',
#  473: 'reduction',
#  474: 'angry',
#  475: 'has',
#  476: 'absolute',
#  477: 'today',
#  478: 'rowdy',
#  479: 'day',
#  480: 'Despite',
#  481: 'power',
#  482: 'disappoint',
#  483: 'over-priced',
#  484: 'tiny',
#  485: 'martini',
#  486: 'loudly',
#  487: 'flat',
#  488: 'workers',
#  489: 'Japanese',
#  490: 'store',
#  491: 'inviting',
#  492: 'themselves',
#  493: 'AND',
#  494: 'Bad',
#  495: 'dining',
#  496: 'Frenchman',
#  497: 'waste',
#  498: 'biscuit',
#  499: 'corn',
#  500: 'pan',
#  501: 'building',
#  502: 'Soups',
#  503: 'Chipotle',
#  504: 'personally',
#  505: 'teamwork',
#  506: 'place',
#  507: 'Lobster',
#  508: 'dont',
#  509: 'clue',
#  510: 'Noca',
#  511: 'be',
#  512: 'anticipated',
#  513: 'nothing',
#  514: 'Joey',
#  515: 'salads',
#  516: 'Jenni',
#  517: 'first',
#  518: '--',
#  519: 'staying',
#  520: 'bamboo',
#  521: 'received',
#  522: 'anytime',
#  523: 'started',
#  524: 'pita',
#  525: 'Vegetarian',
#  526: 'summarize',
#  527: 'cannoli',
#  528: 'GC',
#  529: 'gave',
#  530: 'any',
#  531: 'mostly',
#  532: 'refused',
#  533: 'living',
#  534: 'their',
#  535: 'sore',
#  536: 'worker',
#  537: 'lawyers',
#  538: 'airline',
#  539: '-',
#  540: 'traditional',
#  541: 'Buldogis',
#  542: 'menu/',
#  543: 'paper',
#  544: 'wontons',
#  545: 'covers',
#  546: 'signs',
#  547: 'Delight',
#  548: 'bartender',
#  549: 'accident',
#  550: 'Ninja',
#  551: 'hamburger',
#  552: 'toasted',
#  553: 'VERY',
#  554: 'fillet',
#  555: 'dropped',
#  556: 'liking',
#  557: 'bar',
#  558: 'whole',
#  559: 'chips',
#  560: 'brings',
#  561: 'owners',
#  562: 'close',
#  563: 'tater',
#  564: 'GREAT',
#  565: 'hair',
#  566: 'sals',
#  567: 'dusted',
#  568: 'Overall',
#  569: 'Took',
#  570: 'brick',
#  571: 'Wienerschnitzel',
#  572: 'elsewhere',
#  573: 'lovers',
#  574: 'past',
#  575: 'bit',
#  576: 'shops',
#  577: 'specials',
#  578: 'Host',
#  579: 'is',
#  580: 'as',
#  581: 'Similarly',
#  582: 'mussels',
#  583: 'spicy',
#  584: 'meal',
#  585: 'disaster',
#  586: 'dinners',
#  587: 'vegan/veggie',
#  588: 'almonds',
#  589: 'describing',
#  590: 'reasonable',
#  591: 'oil',
#  592: 'songs',
#  593: 'seen',
#  594: 'juice..',
#  595: 'stay',
#  596: 'BACK',
#  597: 'HOUR',
#  598: 'judge',
#  599: 'Do',
#  600: 'constructed',
#  601: 'grease',
#  602: 'amount',
#  603: 'One',
#  604: '.THE',
#  605: 'pepper',
#  606: 'average',
#  607: 'selection',
#  608: 'doing',
#  609: 'fair',
#  610: 'grandmother',
#  611: 'wrap',
#  612: 'succulent',
#  613: 'Waited',
#  614: 'WHAT',
#  615: 'servers',
#  616: 'sat',
#  617: 'eggs',
#  618: 'meh',
#  619: 'jalapeno',
#  620: 'burgers',
#  621: "'m",
#  622: 'Great',
#  623: 'Server',
#  624: 'Spend',
#  625: 'Palm',
#  626: 'capers',
#  627: 'struck',
#  628: 'neat',
#  629: 'Which',
#  630: 'cold',
#  631: 'could',
#  632: 'half',
#  633: 'made',
#  634: 'Of',
#  635: 'shirt',
#  636: 'hour',
#  637: 'relocated',
#  638: 'honestly',
#  639: 'So',
#  640: 'glass',
#  641: 'seasoned',
#  642: 'performed',
#  643: 'gas',
#  644: 'instantly',
#  645: 'end',
#  646: 'guy',
#  647: 'military',
#  648: 'came',
#  649: 'interior',
#  650: 'whether',
#  651: 'management',
#  652: 'visited',
#  653: 'outside',
#  654: 'slaw',
#  655: 'disgusted',
#  656: 'hardly',
#  657: 'across',
#  658: 'empty',
#  659: 'dripping',
#  660: 'are',
#  661: 'sunglasses',
#  662: 'yummy',
#  663: 'M',
#  664: 'Generous',
#  665: 'Perfect',
#  666: 'Pretty',
#  667: 'mean',
#  668: 'Han',
#  669: 'chains',
#  670: 'busy',
#  671: 'free',
#  672: 'An',
#  673: 'buffets',
#  674: 'did',
#  675: 'sense',
#  676: 'Soggy',
#  677: 'professional',
#  678: 'restaurant',
#  679: 'cheese',
#  680: 'Otto',
#  681: 'Nice',
#  682: 'buying',
#  683: 'decided',
#  684: 'fairly',
#  685: 'SCREAMS',
#  686: 'Del',
#  687: 'BITCHES',
#  688: 'teeth',
#  689: 'Highly',
#  690: 'thinly',
#  691: 'Favorite',
#  692: 'people',
#  693: 'missed',
#  694: 'group',
#  695: 'tastings',
#  696: 'leaves',
#  697: 'poop',
#  698: 'hurry',
#  699: 'third',
#  700: 'Definitely',
#  701: 'skimp',
#  702: 'count',
#  703: 'publicly',
#  704: 'sound',
#  705: 'wire',
#  706: 'bellies',
#  707: 'told',
#  708: 'besides',
#  709: 'heart',
#  710: 'insulted',
#  711: 'outshining',
#  712: 'movies',
#  713: 'again',
#  714: 'No',
#  715: 'beef',
#  716: 'They',
#  717: 'space',
#  718: 'insanely',
#  719: 'lot',
#  720: 'very',
#  721: 'All',
#  722: 'blandest',
#  723: 'cuisine',
#  724: "'d",
#  725: 'if',
#  726: 'Update',
#  727: 'Carly',
#  728: 'glance',
#  729: 'dark',
#  730: 'or',
#  731: 'Toast',
#  732: 'mind',
#  733: 'andddd',
#  734: 'regular',
#  735: 'flavors',
#  736: 'weekly',
#  737: 'trippy',
#  738: 'venturing',
#  739: 'Customer',
#  740: 'upgrading',
#  741: 'than',
#  742: 'whatsoever',
#  743: 'you',
#  744: 'check',
#  745: 'Cooked',
#  746: 'fuzzy',
#  747: 'hottest',
#  748: 'hits',
#  749: 'definately',
#  750: 'vomited',
#  751: 'dish',
#  752: 'Although',
#  753: 'Pros',
#  754: 'marrow',
#  755: 'ourselves',
#  756: 'town',
#  757: 'touch',
#  758: 'claimed',
#  759: 'Steve',
#  760: 'over-hip',
#  761: 'blow',
#  762: 'Food',
#  763: 'another',
#  764: 'she',
#  765: 'real',
#  766: 'desserts',
#  767: 'rinse',
#  768: 'delicate',
#  769: 'awkward',
#  770: 'sandwich',
#  771: 'usual',
#  772: 'indicate',
#  773: 'San',
#  774: 'owner/chef',
#  775: 'hoping',
#  776: 'WAY',
#  777: 'those',
#  778: 'kitchen',
#  779: 'EXPERIENCE',
#  780: 'mood',
#  781: 'Are',
#  782: '1/2',
#  783: 'cook',
#  784: 'must-stop',
#  785: 'refill',
#  786: 'Outstanding',
#  787: 'sign',
#  788: 'Our',
#  789: 'chip',
#  790: 'From',
#  791: 'dirty-',
#  792: 'feels',
#  793: 'this',
#  794: 'THIS',
#  795: 'pub',
#  796: 'absolutely',
#  797: 'unbelievable',
#  798: 'honest',
#  799: 'crowd',
#  800: 'smelled',
#  801: 'LEGIT',
#  802: 'consider',
#  803: 'apparently',
#  804: 'although',
#  805: 'wrong',
#  806: 'relationship',
#  807: 'For',
#  808: 'DELICIOUS',
#  809: 'Would',
#  810: 'At',
#  811: 'avoided',
#  812: 'touched',
#  813: 'Egg',
#  814: 'checked',
#  815: 'Bay',
#  816: 'dedicated',
#  817: 'discount',
#  818: 'during',
#  819: 'calligraphy',
#  820: 'complete',
#  821: 'below',
#  822: 'Ha',
#  823: 'veal',
#  824: 'warmer',
#  825: 'Place',
#  826: '.',
#  827: 'hearts',
#  828: 'Kids',
#  829: 'takeout',
#  830: 'one',
#  831: 'cooked',
#  832: 'cheap',
#  833: 'subpar',
#  834: 'money',
#  835: 'big',
#  836: 'Standard',
#  837: 'beyond',
#  838: 'greedy',
#  839: 'egg',
#  840: 'pile',
#  841: 'looking',
#  842: 'somewhat',
#  843: 'folks',
#  844: 'human',
#  845: 'Madison',
#  846: 'inexpensive',
#  847: 'inflate',
#  848: 'ignore',
#  849: 'want',
#  850: 'salad',
#  851: 'sugar',
#  852: 'thats',
#  853: 'seafood',
#  854: 'Awful',
#  855: 'Mmmm',
#  856: 'arrives',
#  857: 'creamy',
#  858: 'decent',
#  859: 'beans',
#  860: 'grocery',
#  861: 'shocked',
#  862: 'plus',
#  863: 'extraordinary',
#  864: 'Con',
#  865: 'college',
#  866: 'pucks',
#  867: 'reasons',
#  868: 'establishment',
#  869: 'talking',
#  870: 'hi',
#  871: 'Gyros',
#  872: 'bartenders',
#  873: 'got',
#  874: 'accountant',
#  875: 'simply',
#  876: 'officially',
#  877: 'mention',
#  878: 'yellow',
#  879: 'appetizer',
#  880: 'brunch',
#  881: 'awful',
#  882: 'Gave',
#  883: 'sweet',
#  884: 'selections',
#  885: 'T.',
#  886: 'belly',
#  887: 'exactly',
#  888: 'non-fancy',
#  889: 'fat',
#  890: 'known',
#  891: 'door',
#  892: 'dead',
#  893: 'the',
#  894: 'always',
#  895: 'huevos',
#  896: 'contained',
#  897: 'continue',
#  898: 'moist',
#  899: 'seal',
#  900: 'deuchebaggery',
#  901: 'Honeslty',
#  902: 'undercooked',
#  903: 'mall',
#  904: 'Always',
#  905: 'believe',
#  906: 'law',
#  907: 'attentive',
#  908: 'Casino',
#  909: 'hungry',
#  910: '10+',
#  911: 'chickens',
#  912: 'they',
#  913: 'cool',
#  914: 'decor',
#  915: 'writing',
#  916: 'Furthermore',
#  917: 'High-quality',
#  918: 'burger',
#  919: 'Rick',
#  920: 'warnings',
#  921: 'palate',
#  922: 'leave',
#  923: 'temp.I',
#  924: 'company',
#  925: 'wine',
#  926: 'rib',
#  927: 'me',
#  928: 'son',
#  929: 'mess',
#  930: 'trying',
#  931: 'delish',
#  932: 'decorated',
#  933: 'disrespected',
#  934: 'wife',
#  935: 'Christmas',
#  936: '-My',
#  937: 'Gourmet',
#  938: 'looked',
#  939: 'Eclectic',
#  940: 'strange',
#  941: 'large',
#  942: 'generic',
#  943: 'mac',
#  944: 'goat',
#  945: 'If',
#  946: 'Indian',
#  947: 'nut',
#  948: 'Café',
#  949: 'hella',
#  950: 'dealing',
#  951: 'Nobu',
#  952: 'revisiting',
#  953: 'Over',
#  954: 'tapas',
#  955: 'AYCE',
#  956: 'most',
#  957: 'frustrated',
#  958: 'MUST',
#  959: 'cover',
#  960: 'after',
#  961: 'sever',
#  962: 'wings',
#  963: 'pizza',
#  964: 'perpared',
#  965: 'waited',
#  966: 'similar',
#  967: 'seated',
#  968: 'A',
#  969: 'fabulous',
#  970: 'Those',
#  971: 'smooth',
#  972: 'chipolte',
#  973: 'summer',
#  974: 'point',
#  975: 'nigiri',
#  976: 'boiled',
#  977: 'Aria',
#  978: 'thirty',
#  979: 'have',
#  980: 'However',
#  981: 'exceeding',
#  982: 'Up',
#  983: 'work',
#  984: 'market',
#  985: 'chocolate',
#  986: 'boot',
#  987: 'spinach',
#  988: 'saving',
#  989: 'What',
#  990: 'friendly',
#  991: 'chef',
#  992: 'relax',
#  993: 'Caballero',
#  994: 'WAAAAAAyyyyyyyyyy',
#  995: 'much',
#  996: 'petrified',
#  997: 'falafels',
#  998: 'service',
#  999: 'humiliated',
#  ...}

# %% [markdown]
# ## 轉換句子為bag of words型式

# %%
def _get_bag_of_words_vector(sentence, word_index_dic, whole_words):
    sentence = sentence
    '''創建一個vector'''
    vector = np.zeros(len(whole_words))
    for word in nltk.word_tokenize(sentence):
        if word in whole_words:
            '''自行填入'''
            vector[word_index[word]] += 1
    return vector

# %%
_get_bag_of_words_vector('Wow... Loved this place.', word_index, whole_words)
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
a = _get_bag_of_words_vector('Wow... Loved this place.', word_index, whole_words)

# %%
a.shape
# Out:
# (2356,)

# %%
np.where(a==1)
# Out:
# (array([ 472,  506,  793,  826, 1012, 1399]),)
